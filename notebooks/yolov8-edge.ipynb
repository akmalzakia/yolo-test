# %%
# !git clone https://github.com/akmalzakia/yolo-test.git
# !git clone --depth 1 https://github.com/ultralytics/ultralytics.git

# %%
# %cd ultralytics
# !pip install -q -e .

# %%
# import wandb

# wandb.login()

# %%
# SET PATH
dataset_path = 'D:/deep-learning/datasets/cctsdb2021-full'
yolo_repo = ".."
project_name = "YOLOv8s Traffic Detection"
output_path = f"./runs/detect/{project_name}"
yolo_mod_path = f'{yolo_repo}/custom'
ultralytics_path = "D:/deep-learning/ultralytics/ultralytics"

yolo_path = f'{yolo_repo}/cfg/es-yolo.yaml'
model_name = "ES-YOLO"

# %%
import shutil

# conv.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/conv.py', 
            f'{ultralytics_path}/nn/modules/conv.py')

# block.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/block.py', 
            f'{ultralytics_path}/nn/modules/block.py')

# __init__.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/__init__.py', 
            f'{ultralytics_path}/nn/modules/__init__.py')

# tasks.py -- ultralytics/nn/
shutil.copy(f'{yolo_mod_path}/nn/tasks.py', 
            f'{ultralytics_path}/nn/tasks.py')

# loss.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/utils/loss.py',
            f'{ultralytics_path}/utils/loss.py')

# loss_logger.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/utils/loss_logger.py',
            f'{ultralytics_path}/utils/loss_logger.py')
# Out:
# 'D:/deep-learning/ultralytics/ultralytics/utils/loss_logger.py'

# %%
from ultralytics import YOLO
from ultralytics.utils import SETTINGS
SETTINGS['wandb'] = True
SETTINGS['tensorboard'] = True

# %%
configs = {
    "data": dataset_path,
    "epochs": 100,
    "imgsz": 640,
    "batch": 16,
    "amp": True,
    "device": "0",
    "optimizer": 'SGD',
    "lr0": 0.01,
    "workers": 4,
    "patience": 15,
    "val": True,
    "project": project_name
}

# %%
import os
os.environ['YOLO_IOU_LOSS']        = 'CIoU'
os.environ['YOLO_IOU_MONOTONOUS']  = 'none'
# os.environ['YOLO_IOU_INNER_RATIO'] = '0.7'

# %% [markdown]
# ## YOLO Training

# %%
# from wandb.integration.ultralytics import add_wandb_callback
from ultralytics.utils.loss_logger import log_loss_config

# with wandb.init(project=configs["project"], name=model_name, job_type="train") as run:
model = YOLO(yolo_path, task='detect', verbose=True)
model.add_callback('on_pretrain_routine_end', log_loss_config)

model_results = model.train(
    data    = configs["data"],
    epochs  = configs["epochs"],
    imgsz   = configs["imgsz"],
    batch   = configs["batch"], 
    device  = configs["device"],
    amp     = configs["amp"],
    workers      = configs["workers"],
    optimizer    = configs["optimizer"],
    lr0          = configs["lr0"],
    project      = configs["project"],
    name         = f"{model_name}/train",
    exist_ok     = True,
    save_period  = 10,
    verbose      = True,
    patience     = configs["patience"],
    val          = configs["val"]
)
# Out:
# WARNING no model scale passed. Assuming scale='s'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2019  ultralytics.nn.modules.block.EdgeFEBlock     [3, 32, 3, 2, 1]
#   1                   0  1         0  ultralytics.nn.modules.conv.Index            [0]
#   2                   0  1         0  ultralytics.nn.modules.conv.Index            [1]
#   3              [1, 2]  1      8448  ultralytics.nn.modules.block.AFFM            [64]
#   4                   2  1    121283  ultralytics.nn.modules.block.ShapeConv       [32, 64, 3, 2, False]
#   5                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   6                   3  1     20736  ultralytics.nn.modules.block.EFE             [32, 64, 3, 2]
#   7              [5, 6]  1     33280  ultralytics.nn.modules.block.AFFM            [128]
#   8                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   9                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#  10                   6  1     82432  ultralytics.nn.modules.block.EFE             [64, 128, 3, 2]
#  11             [9, 10]  1    132096  ultralytics.nn.modules.block.AFFM            [256]
#  12                   9  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#  13                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#  14                  11  1    328704  ultralytics.nn.modules.block.EFE             [128, 256, 3, 2]
#  15            [13, 14]  1    526336  ultralytics.nn.modules.block.AFFM            [512]
#  16                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#  17                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#  18                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  19                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  20            [-1, 15]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  22                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  23            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  24                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  25                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  26             [-1, 7]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  27                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  28                  -1  1         0  ultralytics.nn.modules.block.SimAM           []
#  29                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  30            [-1, 24]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  31                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  32                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  33            [-1, 21]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  34                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  35        [28, 31, 34]  1    897664  ultralytics.nn.modules.head.Detect           [80, 16, None, [64, 128, 256]]
# es-YOLO summary: 204 layers, 8,791,462 parameters, 8,791,446 gradients, 44.2 GFLOPs
#
# New https://pypi.org/project/ultralytics/8.4.56 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:/deep-learning/datasets/cctsdb2021-full, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../cfg/es-yolo.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=YOLOv8s Traffic Detection, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\ES-YOLO\train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# TensorBoard: Start with 'tensorboard --logdir D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\ES-YOLO\train', view at http://localhost:6006/
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: zakiasmara11 (azaki-its-team) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.27.0
# Run data is saved locally in <code>D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\ES-YOLO\train\wandb\run-20260527_121331-train_20260527_121330</code>
# Syncing run <strong><a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260527_121330' target="_blank">train</a></strong> to <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection</a>
#  View run at <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260527_121330' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260527_121330</a>
# Overriding model.yaml nc=80 with nc=3
# WARNING no model scale passed. Assuming scale='s'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2019  ultralytics.nn.modules.block.EdgeFEBlock     [3, 32, 3, 2, 1]
#   1                   0  1         0  ultralytics.nn.modules.conv.Index            [0]
#   2                   0  1         0  ultralytics.nn.modules.conv.Index            [1]
#   3              [1, 2]  1      8448  ultralytics.nn.modules.block.AFFM            [64]
#   4                   2  1    121283  ultralytics.nn.modules.block.ShapeConv       [32, 64, 3, 2, False]
#   5                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   6                   3  1     20736  ultralytics.nn.modules.block.EFE             [32, 64, 3, 2]
#   7              [5, 6]  1     33280  ultralytics.nn.modules.block.AFFM            [128]
#   8                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   9                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#  10                   6  1     82432  ultralytics.nn.modules.block.EFE             [64, 128, 3, 2]
#  11             [9, 10]  1    132096  ultralytics.nn.modules.block.AFFM            [256]
#  12                   9  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#  13                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#  14                  11  1    328704  ultralytics.nn.modules.block.EFE             [128, 256, 3, 2]
#  15            [13, 14]  1    526336  ultralytics.nn.modules.block.AFFM            [512]
#  16                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#  17                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#  18                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  19                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  20            [-1, 15]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  22                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  23            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  24                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  25                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  26             [-1, 7]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  27                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  28                  -1  1         0  ultralytics.nn.modules.block.SimAM           []
#  29                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  30            [-1, 24]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  31                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  32                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  33            [-1, 21]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  34                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  35        [28, 31, 34]  1    751897  ultralytics.nn.modules.head.Detect           [3, 16, None, [64, 128, 256]]
# es-YOLO summary: 204 layers, 8,645,695 parameters, 8,645,679 gradients, 41.5 GFLOPs
#
# Freezing layer 'model.35.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 815.2385.4 MB/s, size: 58.6 KB)
# train: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\train.cache... 16356 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 16356/16356 3.6Git/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1803.6628.1 MB/s, size: 210.3 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 273.5Mit/s 0.0s
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 76 weight(decay=0.0), 87 weight(decay=0.0005), 92 bias(decay=0.0)
# Plotting labels to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\ES-YOLO\train\labels.jpg...
#
# Loss config
#   type        : CIoU
#   monotonous  : None  (v1  no focusing)
#   inner_ratio : 0.7
#
#
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\ES-YOLO\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# c:\Users\s2\anaconda3\envs\deep-learning\Lib\site-packages\torch\jit\_trace.py:1022: UserWarning: The input to trace is already a ScriptModule, tracing it is a no-op. Returning the object as is.
#   traced_func = _trace_impl(
#       1/100      8.92G      3.604      4.633      2.583          5        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:06<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.9s0.3s
#                    all       1500       3228      0.294      0.113      0.093     0.0393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      9.04G      2.008      2.092       1.47         11        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:60<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.0s0.2s
#                    all       1500       3228      0.595      0.364      0.388      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      8.89G      1.635      1.421      1.239          6        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:11<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.0it/s 15.6s0.3s
#                    all       1500       3228      0.627      0.451       0.51      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      8.95G      1.463      1.105      1.144          8        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.2s0.3s
#                    all       1500       3228      0.766      0.519      0.605       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      9.03G       1.35     0.9359      1.097          7        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:02<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.0s0.2s
#                    all       1500       3228      0.817      0.563      0.644      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      8.88G      1.278     0.8506      1.063          9        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:02<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.9s0.3s
#                    all       1500       3228      0.767       0.56      0.639      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      8.89G       1.23     0.7903      1.039          9        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:60<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.9s0.3s
#                    all       1500       3228      0.762      0.641        0.7      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      9.02G      1.177     0.7372      1.019         13        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:60<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.8s0.2s
#                    all       1500       3228      0.821       0.62      0.714      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      8.89G      1.146     0.7025      1.007         11        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:00<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.1s0.3s
#                    all       1500       3228      0.834      0.621      0.707      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      8.83G      1.123     0.6751     0.9975         14        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:55<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.1it/s 15.1s0.3s
#                    all       1500       3228      0.835      0.635      0.724       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      8.89G      1.103     0.6543     0.9882         13        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:03<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.0s0.3s
#                    all       1500       3228      0.819       0.67      0.728      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      8.87G      1.078     0.6349     0.9812         13        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:07<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.0s0.3s
#                    all       1500       3228      0.842      0.644      0.749       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      8.89G      1.066     0.6216     0.9739         27        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:01<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.7s0.3s
#                    all       1500       3228      0.844      0.661      0.752      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      8.83G      1.055      0.601     0.9703         18        640: 100% ━━━━━━━━━━━━ 1023/1023 2.0it/s 8:42<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.5s0.2s
#                    all       1500       3228      0.836      0.692      0.753      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      8.89G      1.033      0.589     0.9614          9        640: 100% ━━━━━━━━━━━━ 1023/1023 2.0it/s 8:42<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.5s0.2s
#                    all       1500       3228      0.867      0.678      0.762      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      9.15G      1.028     0.5821     0.9603          9        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:54<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.1it/s 15.0s0.3s
#                    all       1500       3228       0.82      0.684      0.762      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100         9G      1.019     0.5698     0.9594         11        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:54<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.1it/s 14.9s0.3s
#                    all       1500       3228      0.864      0.683      0.772      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      8.88G     0.9971     0.5581     0.9502         22        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:54<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.2it/s 14.9s0.3s
#                    all       1500       3228      0.854      0.695      0.765      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      8.89G     0.9889      0.548     0.9456         20        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:54<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.1it/s 14.9s0.3s
#                    all       1500       3228      0.869       0.71      0.779      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      9.03G     0.9826     0.5424     0.9447         22        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:53<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.1it/s 15.0s0.3s
#                    all       1500       3228      0.866      0.714      0.781      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      8.89G     0.9781     0.5359     0.9417         10        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:53<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.1it/s 14.9s0.3s
#                    all       1500       3228      0.896      0.694      0.782      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      8.89G     0.9593      0.523     0.9363          8        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:54<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.1it/s 15.1s0.3s
#                    all       1500       3228      0.876      0.707      0.781      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      8.88G     0.9556     0.5213     0.9342          9        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:54<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.1it/s 14.9s0.3s
#                    all       1500       3228      0.862      0.718      0.777      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      8.95G     0.9455     0.5118     0.9324         11        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:54<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.1it/s 15.0s0.3s
#                    all       1500       3228      0.874      0.705      0.776        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      8.91G     0.9429     0.5059     0.9305         15        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:60<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.0s0.3s
#                    all       1500       3228      0.879      0.711      0.786      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      8.88G      0.935        0.5      0.929          9        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:04<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.8it/s 12.2s0.3s
#                    all       1500       3228      0.881      0.729      0.793      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      8.86G      0.929     0.4966      0.926         19        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:06<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.8it/s 12.5s0.3s
#                    all       1500       3228      0.895      0.714      0.801       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      8.87G     0.9245      0.493     0.9244         15        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:05<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.1s0.3s
#                    all       1500       3228      0.875      0.722      0.788      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      8.83G     0.9223      0.488     0.9216         12        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:04<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.8it/s 12.2s0.3s
#                    all       1500       3228      0.887      0.711      0.807      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      8.88G     0.9116     0.4829     0.9217         19        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:04<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.2s0.3s
#                    all       1500       3228      0.872      0.733      0.804      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      8.89G     0.9063     0.4768     0.9189         11        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:04<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.1s0.3s
#                    all       1500       3228      0.883      0.727      0.821      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      8.89G     0.9035     0.4755     0.9163         18        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:04<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.1s0.3s
#                    all       1500       3228      0.861      0.733      0.806      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      8.89G     0.8969     0.4682     0.9161         10        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:04<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.0s0.3s
#                    all       1500       3228      0.904       0.71      0.815      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      8.89G     0.8976     0.4687     0.9159          9        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:04<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.0s0.3s
#                    all       1500       3228      0.861       0.74      0.806      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100       9.1G     0.8853     0.4628     0.9136         18        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:04<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.1s0.3s
#                    all       1500       3228      0.883      0.731      0.813       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      8.87G     0.8837     0.4591      0.911         14        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:03<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.1s0.3s
#                    all       1500       3228      0.884       0.73      0.808      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      8.83G     0.8798     0.4572     0.9085         20        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:03<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.8it/s 12.2s0.3s
#                    all       1500       3228      0.905      0.729      0.811      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      8.85G     0.8774     0.4551     0.9077         18        640: 100% ━━━━━━━━━━━━ 1023/1023 2.0it/s 8:42<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.2it/s 11.3s0.2s
#                    all       1500       3228      0.887      0.741      0.805      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100       8.9G     0.8725     0.4496     0.9067          6        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:46<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.9s0.3s
#                    all       1500       3228      0.895      0.734      0.808       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      8.94G     0.8682     0.4462     0.9037         12        640: 100% ━━━━━━━━━━━━ 1023/1023 2.0it/s 8:40<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.6s0.2s
#                    all       1500       3228      0.881      0.734      0.804       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      8.89G      0.867     0.4445      0.902          7        640: 100% ━━━━━━━━━━━━ 1023/1023 2.0it/s 8:38<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.5s0.2s
#                    all       1500       3228      0.875      0.748      0.809      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      8.93G     0.8609     0.4388     0.9033         10        640: 100% ━━━━━━━━━━━━ 1023/1023 2.0it/s 8:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.5s0.2s
#                    all       1500       3228       0.88      0.741      0.815      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      8.89G     0.8569     0.4351      0.901         12        640: 100% ━━━━━━━━━━━━ 1023/1023 2.0it/s 8:38<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.5s0.2s
#                    all       1500       3228      0.866      0.748      0.811      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      8.83G     0.8525     0.4333     0.8991         14        640: 100% ━━━━━━━━━━━━ 1023/1023 2.0it/s 8:38<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.4s0.2s
#                    all       1500       3228       0.86      0.752      0.808      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      8.89G     0.8464     0.4288     0.8963         10        640: 100% ━━━━━━━━━━━━ 1023/1023 2.0it/s 8:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.4s0.2s
#                    all       1500       3228      0.874      0.746      0.809      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      8.88G     0.8457     0.4286      0.897          4        640: 100% ━━━━━━━━━━━━ 1023/1023 2.0it/s 8:43<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.1s0.3s
#                    all       1500       3228      0.886      0.738      0.809      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100       8.9G     0.8425      0.425     0.8983         19        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.1s0.3s
#                    all       1500       3228      0.895      0.736      0.808      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      9.06G     0.8366     0.4219     0.8957          4        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:12<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.9it/s 12.0s0.3s
#                    all       1500       3228      0.895      0.739      0.809      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      8.85G     0.8297     0.4188     0.8917         12        640: 100% ━━━━━━━━━━━━ 1023/1023 1.8it/s 9:13<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 3.8it/s 12.2s0.3s
#                    all       1500       3228      0.891      0.747       0.81      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      9.03G     0.8342     0.4203      0.894         14        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:12<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.7s0.2s
#                    all       1500       3228      0.886      0.747      0.811      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      9.06G     0.8321     0.4165     0.8929          8        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 9:00<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.8s0.2s
#                    all       1500       3228      0.885      0.755      0.811      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      8.81G     0.8271     0.4147     0.8918         12        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:51<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.5s0.2s
#                    all       1500       3228      0.888      0.753      0.811      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      8.99G     0.8244     0.4108      0.889         12        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:49<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.5s0.2s
#                    all       1500       3228      0.886      0.753      0.812      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      8.88G      0.819     0.4077     0.8892         10        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:49<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.6s0.2s
#                    all       1500       3228      0.885      0.751       0.81      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      8.89G     0.8205     0.4077     0.8907          7        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:49<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.6s0.2s
#                    all       1500       3228      0.893      0.746      0.809      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      9.12G     0.8179     0.4055     0.8877          6        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:49<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.6s0.2s
#                    all       1500       3228      0.883      0.757      0.811      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      8.91G     0.8135     0.4018     0.8867         14        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:49<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.0it/s 11.6s0.2s
#                    all       1500       3228      0.888      0.757      0.811      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      8.88G     0.8122     0.4006     0.8862         16        640: 100% ━━━━━━━━━━━━ 1023/1023 1.9it/s 8:49<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.1it/s 11.6s0.2s
#                    all       1500       3228      0.891      0.757       0.81      0.526
# EarlyStopping: Training stopped early as no improvement observed in last 15 epochs. Best results observed at epoch 43, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 58 epochs completed in 8.850 hours.
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\ES-YOLO\train\weights\last.pt, 17.7MB
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\ES-YOLO\train\weights\best.pt, 17.7MB
#
# Validating D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\ES-YOLO\train\weights\best.pt...
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# es-YOLO summary: 129 layers, 8,592,927 parameters, 0 gradients, 40.8 GFLOPs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 8
#       4 # with wandb.init(project=configs["project"], name=model_name, job_type="train") as run:
#       5 model = YOLO(yolo_path, task='detect', verbose=True)
#       6 model.add_callback('on_pretrain_routine_end', log_loss_config)
#       7
# ----> 8 model_results = model.train(
#       9     data    = configs["data"],
#      10     epochs  = configs["epochs"],
#      11     imgsz   = configs["imgsz"],
#
# File D:\deep-learning\ultralytics\ultralytics\engine\model.py:792, in Model.train(self, trainer, **kwargs)
#     789     self.trainer.model = self.trainer.get_model(weights=weights, cfg=self.model.yaml)
#     790     self.model = self.trainer.model
# --> 792 self.trainer.train()
#     793 # Update model and cfg after training
#     794 if RANK in {-1, 0}:
#
# File D:\deep-learning\ultralytics\ultralytics\engine\trainer.py:246, in BaseTrainer.train(self)
#     243             ddp_cleanup(self, str(file))
#     245 else:
# --> 246     self._do_train()
#
# File D:\deep-learning\ultralytics\ultralytics\engine\trainer.py:577, in BaseTrainer._do_train(self)
#     575 LOGGER.info(f"\n{epoch - self.start_epoch + 1} epochs completed in {seconds / 3600:.3f} hours.")
#     576 # Do final val with best.pt
# --> 577 self.final_eval()
#     578 if RANK in {-1, 0}:
#     579     if self.args.plots:
#
# File D:\deep-learning\ultralytics\ultralytics\engine\trainer.py:855, in BaseTrainer.final_eval(self)
#     853 self.validator.args.plots = self.args.plots
#     854 self.validator.args.compile = False  # disable final val compile as too slow
# --> 855 self.metrics = self.validator(model=model)
#     856 self.metrics.pop("fitness", None)
#     857 self.run_callbacks("on_fit_epoch_end")
#
# File c:\Users\s2\anaconda3\envs\deep-learning\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File D:\deep-learning\ultralytics\ultralytics\engine\validator.py:194, in BaseValidator.__call__(self, trainer, model)
#     191     LOGGER.info(f"Setting batch={self.args.batch} input of shape ({self.args.batch}, 3, {imgsz}, {imgsz})")
#     193 if str(self.args.data).rsplit(".", 1)[-1] in {"yaml", "yml"}:
# --> 194     self.data = check_det_dataset(self.args.data)
#     195 elif self.args.task == "classify":
#     196     self.data = check_cls_dataset(self.args.data, split=self.args.split)
#
# File D:\deep-learning\ultralytics\ultralytics\data\utils.py:492, in check_det_dataset(dataset, autodownload)
#     490 else:
#     491     m += f"\nNote dataset download directory is '{DATASETS_DIR}'. You can update this in '{SETTINGS_FILE}'"
# --> 492     raise FileNotFoundError(m)
#     493 t = time.time()
#     494 r = None  # success
#
# FileNotFoundError: Dataset 'D://deep-learning/datasets/cctsdb2021-full/dataset.yaml' images not found, missing path 'D:\kaggle\input\datasets\akmalzaki\cctsdb2021-yolo\images\test'
# Note dataset download directory is 'D:\deep-learning\datasets'. You can update this in 'C:\Users\s2\AppData\Roaming\Ultralytics\settings.json'

# %% [markdown]
# ## Test Set Validation

# %%
import os

# Resolve best-weight paths
weights = f"{output_path}/{model_name}/train/weights/best.pt"

# Load best checkpoints
best_weights = YOLO(weights)

# Run validation on the test split
val_model = best_weights.val(
    data   = f"{configs["data"]}/dataset.yaml",
    split  = "test",
    imgsz  = configs["imgsz"],
    batch  = configs["batch"],
    device = configs["device"],
    plots  = True,
    project = configs["project"],
    name    = f"{model_name}/test",
    exist_ok = True,
    verbose  = True,
)

print(f"\n=== {model_name} — Test Set Results ===")
print(f"  mAP50   : {val_model.box.map50:.4f}")
print(f"  mAP50-95: {val_model.box.map:.4f}")
print(f"  Precision: {val_model.box.mp:.4f}")
print(f"  Recall   : {val_model.box.mr:.4f}")
# Out:
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# es-YOLO summary: 129 layers, 8,592,927 parameters, 0 gradients, 40.8 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1888.0572.8 MB/s, size: 212.0 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 484.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 5.3it/s 17.9s0.2s
#                    all       1500       3228      0.887      0.731      0.811      0.529
#              mandatory        525        718      0.867      0.655      0.739      0.492
#            prohibitory       1043       2177       0.92      0.729      0.829      0.552
#                warning        288        333      0.873      0.808      0.864      0.543
# Speed: 0.4ms preprocess, 8.8ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\ES-YOLO\test
#
# === ES-YOLO — Test Set Results ===
#   mAP50   : 0.8106
#   mAP50-95: 0.5290
#   Precision: 0.8870
#   Recall   : 0.7305

# %% [markdown]
# ## Metrics Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Helper to load results.csv produced by Ultralytics during training
def load_results(run_dir, run_name):
    csv_path = os.path.join(run_dir, run_name, "results.csv")
    df = pd.read_csv(csv_path)
    df.columns = df.columns.str.strip()  # strip whitespace from column names
    return df

df_result = load_results(output_path, f"{model_name}/train")

def plot_training_curves(df, model_name):
    metrics = [
        ("train/box_loss",  "Train Box Loss"),
        ("train/cls_loss",  "Train Cls Loss"),
        ("train/dfl_loss",  "Train DFL Loss"),
        ("metrics/mAP50(B)",    "mAP@50"),
        ("metrics/mAP50-95(B)", "mAP@50-95"),
        ("metrics/precision(B)", "Precision"),
        ("metrics/recall(B)",    "Recall"),
        ("val/box_loss",   "Val Box Loss"),
    ]

    ncols = 4
    nrows = 2
    fig, axes = plt.subplots(nrows, ncols, figsize=(20, 10))
    fig.suptitle(f"Training Curves -- {model_name}", fontsize=16, fontweight='bold')

    for ax, (col, title) in zip(axes.flat, metrics):
        epochs = df["epoch"] if "epoch" in df.columns else range(len(df))
        if col in df.columns:
            ax.plot(epochs, df[col], label=model_name, color="#1f77b4", linewidth=2)
        ax.set_title(title, fontsize=12)
        ax.set_xlabel("Epoch")
        ax.legend(fontsize=9)
        ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{output_path}/{model_name}/training_curves.png", dpi=150, bbox_inches='tight')
    plt.show()
    print("Saved → training_curves.png")

plot_training_curves(df_result, model_name)
# Out:
# Saved → training_curves.png

# %%
# ── Bar chart: Final metric comparison ──────────────────────────────────────

def get_final_metrics(val_result):
    return {
        "Precision":  val_result.box.mp,
        "Recall":     val_result.box.mr,
        "mAP@50":     val_result.box.map50,
        "mAP@50-95":  val_result.box.map,
    }

metrics_result = get_final_metrics(val_model)

labels  = list(metrics_result.keys())
vals_res = list(metrics_result.values())

x   = range(len(labels))
w   = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar([i - w/2 for i in x], vals_res, w, label=model_name, color='#1f77b4', alpha=0.85)

ax.set_xticks(list(x))
ax.set_xticklabels(labels, fontsize=13)
ax.set_ylabel("Score", fontsize=13)
ax.set_title(f"Test Set Metric {model_name}", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f"{bar.get_height():.3f}", ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/metric_bar.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → metric_bar.png")
# Out:
# Saved → metric_bar.png

# %%
# ── Per-class mAP comparison ─────────────────────────────────────────────────
import numpy as np

def get_per_class_ap(val_result):
    """Extract per-class AP50 from validation result."""
    maps  = val_result.box.maps      # per-class mAP50-95
    ap50s = val_result.box.ap50      # per-class mAP50, if available
    names = val_result.names         # {idx: class_name}
    class_names = [names[i] for i in sorted(names.keys())]
    return class_names, ap50s if ap50s is not None else maps

cls_names, ap50_model = get_per_class_ap(val_model)

x = np.arange(len(cls_names))
w = 0.35

fig, ax = plt.subplots(figsize=(max(14, len(cls_names) * 0.9), 6))
ax.bar(x - w/2, ap50_model, w, label=model_name, color='#1f77b4', alpha=0.85)
ax.set_xticks(x)
ax.set_xticklabels(cls_names, rotation=45, ha='right', fontsize=10)
ax.set_ylabel("AP@50")
ax.set_title("Per-class AP@50 — Test Set", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/per_class_ap50.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → per_class_ap50.png")
# Out:
# Saved → per_class_ap50.png

# %%
# ── Confusion matrices (saved by Ultralytics during val with plots=True) ─────
from IPython.display import Image, display

def show_image(path, title=""):
    if os.path.exists(path):
        print(f"\n{title}")
        display(Image(filename=path, width=700))
    else:
        print(f"[WARNING] Not found: {path}")

show_image(f"{output_path}/{model_name}/train/confusion_matrix_normalized.png",
           f"Confusion Matrix — {model_name} (Test Set)")
# Out:
# [WARNING] Not found: ./runs/detect/YOLOv8s Traffic Detection/ES-YOLO/train/confusion_matrix_normalized.png

# %% [markdown]
# ## Visual Inspection on Test Images

# %%
import glob
import random
from PIL import Image as PILImage
import numpy as np

# ── Gather test images ───────────────────────────────────────────────────────
test_img_dir = os.path.join(dataset_path, "images", "test")
all_test_imgs = glob.glob(os.path.join(test_img_dir, "*.jpg")) + \
                glob.glob(os.path.join(test_img_dir, "*.png"))

random.seed(42)
sample_imgs = random.sample(all_test_imgs, min(8, len(all_test_imgs)))
print(f"Selected {len(sample_imgs)} test images for visual inspection.")
# Out:
# Selected 8 test images for visual inspection.

# %%
# ── Side-by-side predictions: Baseline | ES-YOLO ────────────────────────────

def predict_and_plot(imgs, model, model_name, n_cols=2, conf=0.25, save_path=None):
    n_imgs = len(imgs)
    n_rows = n_imgs

    fig, axes = plt.subplots(n_rows, n_cols * 2 + 1, figsize=(26, n_rows * 4))
    fig.suptitle(f"Visual Inspection — {model_name}", fontsize=15, fontweight='bold')

    # Column headers
    col_titles = ["Image", model_name, "Prediction"]

    for row_idx, img_path in enumerate(imgs):
        # Run predictions
        res = model.predict(img_path, conf=conf, imgsz=640, verbose=False)[0]

        orig_img   = PILImage.open(img_path).convert("RGB")
        plotted = PILImage.fromarray(res.plot()[:, :, ::-1])

        col_data = [orig_img, plotted]
        titles   = ["Original", model_name]

        for col_idx, (img_data, title) in enumerate(zip(col_data, titles)):
            ax = axes[row_idx, col_idx] if n_rows > 1 else axes[col_idx]
            ax.imshow(img_data)
            ax.axis('off')
            if row_idx == 0:
                ax.set_title(title, fontsize=12, fontweight='bold', pad=6)

        # Hide unused subplots if any
        for c in range(len(col_data), axes.shape[1] if n_rows > 1 else len(axes)):
            extra = axes[row_idx, c] if n_rows > 1 else axes[c]
            extra.axis('off')

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=120, bbox_inches='tight')
        print(f"Saved → {save_path}")
    plt.show()

predict_and_plot(
    sample_imgs, best_weights, model_name,
    conf=0.25,
    save_path=f"{output_path}/{model_name}/visual_inspection_comparison.png"
)
# Out:
# Saved → ./runs/detect/YOLOv8s Traffic Detection/ES-YOLO/visual_inspection_comparison.png

# %%
# ── Confidence score distribution on test set ───────────────────────────────

def collect_confidences(model, img_list, conf_thresh=0.01):
    confs = []
    for p in img_list:
        res = model.predict(p, conf=conf_thresh, imgsz=640, verbose=False)[0]
        if res.boxes is not None and len(res.boxes):
            confs.extend(res.boxes.conf.cpu().numpy().tolist())
    return confs

confs_model = collect_confidences(best_weights, all_test_imgs)

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 5), sharey=False)
fig.suptitle("Detection Confidence Distribution — Test Set", fontsize=14, fontweight='bold')

axes.hist(confs_model, bins=40, color="#1f77b4", alpha=0.8, edgecolor='white')
axes.set_title(f"{model_name}  (n={len(confs_model)} detections)", fontsize=12)
axes.set_xlabel("Confidence Score")
axes.set_ylabel("Count")
axes.axvline(0.25, color='red', linestyle='--', linewidth=1.5, label='thresh=0.25')
axes.legend()
axes.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/confidence_distribution.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → confidence_distribution.png")
# Out:
# Saved → confidence_distribution.png

# %%
# ── Precision-Recall Curves (saved by Ultralytics) ──────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxPR_curve.png",
           f"PR Curve — {model_name} (Test Set)")
# Out:
# [WARNING] Not found: ./runs/detect/YOLOv8s Traffic Detection/ES-YOLO/train/BoxPR_curve.png

# %%
# ── F1 Curves (saved by Ultralytics) ─────────────────────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxF1_curve.png",
           f"F1-Confidence Curve — {model_name} (Test Set)")
# Out:
# [WARNING] Not found: ./runs/detect/YOLOv8s Traffic Detection/ES-YOLO/train/BoxF1_curve.png

# %% [markdown]
# ## Final Summary

# %%
# ── Summary comparison table ─────────────────────────────────────────────────
import pandas as pd
from IPython.display import display

summary = pd.DataFrame({
    "Model":      [model_name],
    "Precision":  [val_model.box.mp],
    "Recall":     [val_model.box.mr],
    "mAP@50":     [val_model.box.map50],
    "mAP@50-95":  [val_model.box.map],
}).set_index("Model").round(4)

# Highlight best value per column
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: #d4edda; font-weight: bold; color:#000000' if v else '' for v in is_max]

print("\n===== Test Set Performance Summary =====")
display(summary.style.apply(highlight_max, axis=0))
# Out:
# ===== Test Set Performance Summary =====
# <style type="text/css">
# #T_e3da6_row0_col0, #T_e3da6_row0_col1, #T_e3da6_row0_col2, #T_e3da6_row0_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
#   color: #000000;
# }
# </style>
# <table id="T_e3da6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3da6_level0_col0" class="col_heading level0 col0" >Precision</th>
#       <th id="T_e3da6_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_e3da6_level0_col2" class="col_heading level0 col2" >mAP@50</th>
#       <th id="T_e3da6_level0_col3" class="col_heading level0 col3" >mAP@50-95</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3da6_level0_row0" class="row_heading level0 row0" >ES-YOLO</th>
#       <td id="T_e3da6_row0_col0" class="data row0 col0" >0.887000</td>
#       <td id="T_e3da6_row0_col1" class="data row0 col1" >0.730500</td>
#       <td id="T_e3da6_row0_col2" class="data row0 col2" >0.810600</td>
#       <td id="T_e3da6_row0_col3" class="data row0 col3" >0.529000</td>
#     </tr>
#   </tbody>
# </table>
