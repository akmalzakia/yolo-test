# %%
# !git clone https://github.com/akmalzakia/yolo-test.git
# !git clone --depth 1 https://github.com/ultralytics/ultralytics.git

# %%
# %cd ultralytics
# !pip install -q -e .

# %%
# import wandb

# wandb.login()

# %%
# SET PATH
dataset_path = 'D:/deep-learning/datasets/cctsdb2021-full'
yolo_repo = ".."
yolo_path = f'{yolo_repo}/yolov8s-cbam.yaml'
output_path = "./runs/detect"
yolo_mod_path = f'{yolo_repo}/nn'
ultralytics_path = "D:/deep-learning/ultralytics/ultralytics"

# %%
import shutil

# conv.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/modules/conv.py', 
            f'{ultralytics_path}/nn/modules/conv.py')

# block.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/modules/block.py', 
            f'{ultralytics_path}/nn/modules/block.py')

# __init__.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/modules/__init__.py', 
            f'{ultralytics_path}/nn/modules/__init__.py')

# tasks.py -- ultralytics/nn/
shutil.copy(f'{yolo_mod_path}/tasks.py', 
            f'{ultralytics_path}/nn/tasks.py')

# loss.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/loss.py',
            f'{ultralytics_path}/utils/loss.py')
# Out:
# 'D:/deep-learning/ultralytics/ultralytics/utils/loss.py'

# %%
from ultralytics import YOLO
from ultralytics.utils import SETTINGS
SETTINGS['wandb'] = False

# %%
configs = {
    "data": dataset_path,
    "epochs": 100,
    "imgsz": 640,
    "batch": 16,
    "amp": True,
    "device": "0",
    "optimizer": 'SGD',
    "lr0": 0.01,
    "workers": 4,
    "patience": 15,
    "val": True,
    "project": "YOLOv8s Traffic Detection"
}

# %%
import os
os.environ['USE_WIOU'] = '0'

# %% [markdown]
# ## YOLO Training

# %%
model = YOLO(yolo_path, task='detect', verbose=True)
model_name = "YOLOv8s + CBAM"

model_results = model.train(
    data    = configs["data"],
    epochs  = configs["epochs"],
    imgsz   = configs["imgsz"],
    batch   = configs["batch"], 
    device  = configs["device"],
    amp     = configs["amp"],
    workers      = configs["workers"],
    optimizer    = configs["optimizer"],
    lr0          = configs["lr0"],
    # project      = configs["project"],
    name         = f"{model_name}/train",
    exist_ok     = True,
    save_period  = 10,
    verbose      = True,
    patience     = configs["patience"],
    val          = configs["val"]
)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    262754  ultralytics.nn.modules.conv.CBAM             [512]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  23        [16, 19, 22]  1   2147008  ultralytics.nn.modules.head.Detect           [80, 16, None, [128, 256, 512]]
# YOLOv8s-cbam summary: 135 layers, 11,429,314 parameters, 11,429,298 gradients, 29.0 GFLOPs
#
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:/deep-learning/datasets/cctsdb2021-full, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../yolov8s-cbam.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s + CBAM\train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    262754  ultralytics.nn.modules.conv.CBAM             [512]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  23        [16, 19, 22]  1   2117209  ultralytics.nn.modules.head.Detect           [3, 16, None, [128, 256, 512]]
# YOLOv8s-cbam summary: 135 layers, 11,399,515 parameters, 11,399,499 gradients, 28.9 GFLOPs
#
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 736.8332.7 MB/s, size: 58.6 KB)
# train: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\train.cache... 16356 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 16356/16356 4.0Git/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1606.5667.4 MB/s, size: 210.3 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 216.9Mit/s 0.0s
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 66 weight(decay=0.0005), 64 bias(decay=0.0)
# Plotting labels to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s + CBAM\train\labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s + CBAM\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.63G      3.761      5.086      2.045          5        640: 100% ━━━━━━━━━━━━ 1023/1023 4.8it/s 3:32<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.239      0.103     0.0696     0.0315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      3.83G      2.097      1.795      1.153         11        640: 100% ━━━━━━━━━━━━ 1023/1023 4.9it/s 3:27<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.573      0.307      0.307      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      3.83G      1.723      1.312      1.028          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.536      0.379       0.37      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      3.83G      1.551      1.064     0.9702          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.593       0.48      0.489      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      3.83G      1.412     0.9195     0.9411          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:23<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.673      0.497      0.524      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      3.83G      1.333     0.8349      0.923          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.732      0.531      0.598      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      3.83G      1.281     0.7791     0.9038          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:23<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.799      0.567      0.646      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      3.83G      1.227     0.7322     0.8944         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.799      0.614      0.676      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      3.83G      1.193     0.6985     0.8854         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.838      0.605       0.68      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      3.83G      1.166     0.6705     0.8825         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:23<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.854      0.611      0.686      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      3.83G      1.135     0.6506     0.8775         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.795      0.645      0.695       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      3.83G      1.115     0.6311     0.8748         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.7it/s 7.0s0.1s
#                    all       1500       3228      0.812      0.663      0.719      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      3.83G      1.092     0.6179      0.868         27        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.819      0.653      0.713      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      3.83G      1.075     0.5993     0.8662         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.817      0.662      0.732       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      3.83G      1.048     0.5833     0.8621          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.864      0.655      0.735      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      3.83G      1.041     0.5742     0.8583          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.869      0.666      0.735      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      3.83G      1.034     0.5655     0.8579         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.836      0.692      0.748      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      3.83G      1.022     0.5562     0.8546         22        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.868      0.699      0.767      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      3.83G      1.009     0.5493      0.852         20        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.881      0.695      0.764      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      3.83G      1.002     0.5382     0.8496         22        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.859      0.701      0.764      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      3.83G     0.9962     0.5349     0.8488         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.867      0.696       0.78      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      3.83G     0.9778     0.5236     0.8478          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.854      0.696      0.755      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      3.83G     0.9731     0.5188     0.8488          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.885        0.7       0.78      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      3.83G     0.9662     0.5137     0.8451         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.871      0.715      0.773      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      3.83G     0.9614     0.5057     0.8433         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228       0.89      0.717      0.782      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      3.83G     0.9544     0.5001      0.844          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.879      0.711      0.776      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      3.83G     0.9497     0.4975     0.8412         19        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.886      0.715      0.785       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      3.83G     0.9395     0.4902     0.8404         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.881      0.746      0.796      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      3.83G      0.938     0.4887       0.84         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.0it/s 6.7s0.1s
#                    all       1500       3228      0.884      0.729      0.787       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      3.83G     0.9267     0.4824     0.8392         19        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.875      0.734      0.787      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      3.83G     0.9251      0.479     0.8402         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228        0.9      0.724      0.794      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      3.83G     0.9202     0.4763      0.838         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.891      0.728      0.797      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      3.83G     0.9114     0.4672     0.8374         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.888      0.728      0.808      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      3.83G     0.9138     0.4677     0.8351          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.893      0.736      0.796      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      3.83G     0.8979     0.4603     0.8358         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.889      0.739      0.799      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      3.83G     0.8966      0.461     0.8346         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.871      0.751      0.801      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      3.83G     0.8937     0.4554     0.8322         20        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.893       0.74      0.801      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      3.83G     0.8891     0.4508     0.8319         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.873      0.756        0.8      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      3.83G     0.8859     0.4487     0.8317          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.901      0.734      0.798      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      3.83G     0.8826     0.4469     0.8279         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.918      0.732      0.801      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      3.83G     0.8787     0.4451     0.8272          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.2it/s 6.6s0.1s
#                    all       1500       3228      0.895      0.746      0.802      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      3.83G      0.874     0.4411     0.8314         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.879      0.745      0.799      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      3.83G     0.8688      0.438     0.8275         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.3it/s 6.4s0.1s
#                    all       1500       3228       0.88      0.758      0.803      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      3.83G     0.8666     0.4359     0.8274         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.883      0.755      0.804      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      3.83G      0.859     0.4295     0.8269         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.737      0.803      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      3.83G     0.8572     0.4288     0.8275          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.895      0.745      0.803      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      3.83G     0.8558     0.4261     0.8279         19        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.898      0.749      0.806      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      3.83G     0.8495     0.4209     0.8265          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.911      0.742      0.807      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      3.83G      0.846     0.4203     0.8246         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228       0.89      0.755      0.806      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      3.83G     0.8402      0.418     0.8241         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.899      0.754      0.807      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.83G     0.8427     0.4141     0.8247          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.896      0.756      0.806      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.83G     0.8355     0.4133     0.8234         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.896      0.761      0.806      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      3.83G     0.8391     0.4124     0.8206         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.897      0.757      0.806      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      3.83G     0.8286     0.4061     0.8216         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.895       0.76      0.807      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      3.83G     0.8275     0.4066     0.8245          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.893      0.764      0.809      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      3.83G     0.8264     0.4039     0.8212          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.758      0.808      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      3.83G     0.8192      0.399     0.8211         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.757      0.809      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      3.83G     0.8203     0.4004     0.8178         16        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.0it/s 6.7s0.1s
#                    all       1500       3228      0.904      0.757      0.807      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      3.83G     0.8119     0.3959       0.82          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.901      0.756      0.808      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      3.83G     0.8097     0.3945     0.8192          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.903      0.756      0.808      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      3.83G      0.803     0.3893     0.8169         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.903       0.76      0.809      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      3.83G     0.8011     0.3885      0.818         21        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.903      0.761      0.809      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      3.83G     0.8057     0.3891     0.8162          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.906      0.761       0.81      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      3.83G     0.8028     0.3869      0.817         24        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.761       0.81      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      3.83G     0.7938     0.3832     0.8173         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.905       0.76       0.81      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      3.83G     0.7911     0.3803     0.8166         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.903       0.76       0.81      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      3.83G     0.7928     0.3807     0.8158         24        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.906      0.757       0.81       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      3.83G     0.7948     0.3808     0.8175         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.905      0.758      0.811      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      3.83G     0.7773     0.3738     0.8137         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.906      0.756      0.812      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      3.83G     0.7822     0.3752     0.8129          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.2it/s 6.6s0.2s
#                    all       1500       3228      0.904      0.759      0.813       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      3.83G     0.7825     0.3713     0.8146          5        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.903      0.759      0.813       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      3.83G      0.774     0.3692     0.8124         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.904      0.759      0.812       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      3.83G     0.7682      0.365     0.8098         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.902      0.758      0.812       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      3.83G     0.7659     0.3644     0.8109         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.904      0.759      0.812       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      3.83G     0.7601     0.3614     0.8122         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.904      0.759      0.813       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      3.83G     0.7636     0.3614     0.8115         17        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.904      0.757      0.812       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      3.83G     0.7573     0.3582     0.8091         16        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.899      0.762      0.813      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      3.83G     0.7557     0.3561      0.808          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.899      0.758      0.812      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      3.83G     0.7496     0.3543     0.8121          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.898      0.759      0.813      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      3.83G      0.752     0.3527     0.8101          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.897      0.759      0.812      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      3.83G     0.7466     0.3521      0.809          3        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.899      0.759      0.812      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      3.83G     0.7431     0.3472     0.8073          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228        0.9       0.76      0.812       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      3.83G     0.7349     0.3444     0.8062         16        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.901      0.758      0.812      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      3.83G     0.7349     0.3441     0.8071         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.901       0.76      0.812      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      3.83G     0.7293     0.3409     0.8057         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.899      0.763      0.814      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      3.83G     0.7308     0.3398     0.8072         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228        0.9      0.763      0.813      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      3.83G     0.7205     0.3367     0.8046         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228        0.9      0.763      0.814      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      3.83G     0.7229     0.3353     0.8049         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228        0.9      0.764      0.814      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      3.83G     0.7221     0.3352     0.8036         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.894      0.767      0.814      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      3.83G     0.7129     0.3303     0.8027          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:18<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.893      0.767      0.814      0.522
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      3.83G     0.6907     0.3155     0.8052          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.3it/s 3:14<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.0it/s 5.9s0.1s
#                    all       1500       3228      0.893      0.765      0.815      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      3.83G     0.6805     0.3098     0.8035          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.3it/s 3:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.894      0.765      0.815      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      3.83G     0.6759     0.3094     0.8008          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.3it/s 3:14<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.0it/s 5.9s0.1s
#                    all       1500       3228       0.89      0.767      0.815      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      3.83G     0.6692     0.3054     0.8017          5        640: 100% ━━━━━━━━━━━━ 1023/1023 5.3it/s 3:12<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.0it/s 6.7s0.1s
#                    all       1500       3228      0.888      0.768      0.815      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      3.83G      0.666     0.3048     0.8019          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.3it/s 3:14<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.894      0.764      0.814      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      3.83G     0.6602     0.3011     0.8002          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.3it/s 3:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.889      0.767      0.814      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      3.83G      0.656     0.2975     0.8008          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.3it/s 3:13<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.892      0.766      0.814      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      3.83G     0.6542      0.297     0.8001          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:18<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.893      0.765      0.814      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      3.83G     0.6495     0.2943     0.7991          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:23<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.893      0.766      0.813      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      3.83G     0.6413     0.2913     0.7967          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.894      0.766      0.813      0.523
#
# 100 epochs completed in 5.839 hours.
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s + CBAM\train\weights\last.pt, 23.0MB
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s + CBAM\train\weights\best.pt, 23.0MB
#
# Validating D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s + CBAM\train\weights\best.pt...
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8s-cbam summary (fused): 78 layers, 11,389,499 parameters, 0 gradients, 28.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.1s
#                    all       1500       3228      0.892      0.767      0.813      0.524
#              mandatory        525        718      0.882      0.682      0.735      0.483
#            prohibitory       1043       2177      0.909      0.762       0.83      0.544
#                warning        288        333      0.887      0.856      0.874      0.544
# Speed: 0.1ms preprocess, 2.0ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s + CBAM\train

# %% [markdown]
# ## Test Set Validation

# %%
import os

# Resolve best-weight paths
weights = f"{output_path}/{model_name}/train/weights/best.pt"

# Load best checkpoints
best_weights = YOLO(weights)

# Run validation on the test split
val_model = best_weights.val(
    data   = f"{configs["data"]}/dataset.yaml",
    split  = "test",
    imgsz  = configs["imgsz"],
    batch  = configs["batch"],
    device = configs["device"],
    plots  = True,
    name    = f"{model_name}/test",
    exist_ok = True,
    verbose  = True,
)

print(f"\n=== {model_name} — Test Set Results ===")
print(f"  mAP50   : {val_model.box.map50:.4f}")
print(f"  mAP50-95: {val_model.box.map:.4f}")
print(f"  Precision: {val_model.box.mp:.4f}")
print(f"  Recall   : {val_model.box.mr:.4f}")
# Out:
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8s-cbam summary (fused): 78 layers, 11,389,499 parameters, 0 gradients, 28.7 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 2463.4740.0 MB/s, size: 212.0 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 699.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 9.9it/s 9.5s<0.2s
#                    all       1500       3228      0.891      0.765      0.811      0.526
#              mandatory        525        718      0.881      0.681      0.733      0.485
#            prohibitory       1043       2177      0.907      0.762      0.831      0.548
#                warning        288        333      0.884      0.853       0.87      0.543
# Speed: 0.4ms preprocess, 3.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s + CBAM\test
#
# === YOLOv8s + CBAM — Test Set Results ===
#   mAP50   : 0.8111
#   mAP50-95: 0.5255
#   Precision: 0.8907
#   Recall   : 0.7652

# %% [markdown]
# ## Metrics Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Helper to load results.csv produced by Ultralytics during training
def load_results(run_dir, run_name):
    csv_path = os.path.join(run_dir, run_name, "results.csv")
    df = pd.read_csv(csv_path)
    df.columns = df.columns.str.strip()  # strip whitespace from column names
    return df

df_result = load_results(output_path, f"{model_name}/train")

def plot_training_curves(df, model_name):
    metrics = [
        ("train/box_loss",  "Train Box Loss"),
        ("train/cls_loss",  "Train Cls Loss"),
        ("train/dfl_loss",  "Train DFL Loss"),
        ("metrics/mAP50(B)",    "mAP@50"),
        ("metrics/mAP50-95(B)", "mAP@50-95"),
        ("metrics/precision(B)", "Precision"),
        ("metrics/recall(B)",    "Recall"),
        ("val/box_loss",   "Val Box Loss"),
    ]

    ncols = 4
    nrows = 2
    fig, axes = plt.subplots(nrows, ncols, figsize=(20, 10))
    fig.suptitle(f"Training Curves -- {model_name}", fontsize=16, fontweight='bold')

    for ax, (col, title) in zip(axes.flat, metrics):
        epochs = df["epoch"] if "epoch" in df.columns else range(len(df))
        if col in df.columns:
            ax.plot(epochs, df[col], label=model_name, color="#1f77b4", linewidth=2)
        ax.set_title(title, fontsize=12)
        ax.set_xlabel("Epoch")
        ax.legend(fontsize=9)
        ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{output_path}/{model_name}/training_curves.png", dpi=150, bbox_inches='tight')
    plt.show()
    print("Saved → training_curves.png")

plot_training_curves(df_result, model_name)
# Out:
# Saved → training_curves.png

# %%
# ── Bar chart: Final metric comparison ──────────────────────────────────────

def get_final_metrics(val_result):
    return {
        "Precision":  val_result.box.mp,
        "Recall":     val_result.box.mr,
        "mAP@50":     val_result.box.map50,
        "mAP@50-95":  val_result.box.map,
    }

metrics_result = get_final_metrics(val_model)

labels  = list(metrics_result.keys())
vals_res = list(metrics_result.values())

x   = range(len(labels))
w   = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar([i - w/2 for i in x], vals_res, w, label=model_name, color='#1f77b4', alpha=0.85)

ax.set_xticks(list(x))
ax.set_xticklabels(labels, fontsize=13)
ax.set_ylabel("Score", fontsize=13)
ax.set_title(f"Test Set Metric {model_name}", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f"{bar.get_height():.3f}", ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/metric_bar.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → metric_bar.png")
# Out:
# Saved → metric_bar.png

# %%
# ── Per-class mAP comparison ─────────────────────────────────────────────────
import numpy as np

def get_per_class_ap(val_result):
    """Extract per-class AP50 from validation result."""
    maps  = val_result.box.maps      # per-class mAP50-95
    ap50s = val_result.box.ap50      # per-class mAP50, if available
    names = val_result.names         # {idx: class_name}
    class_names = [names[i] for i in sorted(names.keys())]
    return class_names, ap50s if ap50s is not None else maps

cls_names, ap50_model = get_per_class_ap(val_model)

x = np.arange(len(cls_names))
w = 0.35

fig, ax = plt.subplots(figsize=(max(14, len(cls_names) * 0.9), 6))
ax.bar(x - w/2, ap50_model, w, label=model_name, color='#1f77b4', alpha=0.85)
ax.set_xticks(x)
ax.set_xticklabels(cls_names, rotation=45, ha='right', fontsize=10)
ax.set_ylabel("AP@50")
ax.set_title("Per-class AP@50 — Test Set", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/per_class_ap50.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → per_class_ap50.png")
# Out:
# Saved → per_class_ap50.png

# %%
# ── Confusion matrices (saved by Ultralytics during val with plots=True) ─────
from IPython.display import Image, display

def show_image(path, title=""):
    if os.path.exists(path):
        print(f"\n{title}")
        display(Image(filename=path, width=700))
    else:
        print(f"[WARNING] Not found: {path}")

show_image(f"{output_path}/{model_name}/train/confusion_matrix_normalized.png",
           f"Confusion Matrix — {model_name} (Test Set)")
# Out:
# Confusion Matrix — YOLOv8s + CBAM (Test Set)

# %% [markdown]
# ## Visual Inspection on Test Images

# %%
import glob
import random
from PIL import Image as PILImage
import numpy as np

# ── Gather test images ───────────────────────────────────────────────────────
test_img_dir = os.path.join(dataset_path, "images", "test")
all_test_imgs = glob.glob(os.path.join(test_img_dir, "*.jpg")) + \
                glob.glob(os.path.join(test_img_dir, "*.png"))

random.seed(42)
sample_imgs = random.sample(all_test_imgs, min(8, len(all_test_imgs)))
print(f"Selected {len(sample_imgs)} test images for visual inspection.")
# Out:
# Selected 8 test images for visual inspection.

# %%
# ── Side-by-side predictions: Baseline | ES-YOLO ────────────────────────────

def predict_and_plot(imgs, model, model_name, n_cols=2, conf=0.25, save_path=None):
    n_imgs = len(imgs)
    n_rows = n_imgs

    fig, axes = plt.subplots(n_rows, n_cols * 2 + 1, figsize=(26, n_rows * 4))
    fig.suptitle(f"Visual Inspection — {model_name}", fontsize=15, fontweight='bold')

    # Column headers
    col_titles = ["Image", model_name, "Prediction"]

    for row_idx, img_path in enumerate(imgs):
        # Run predictions
        res = model.predict(img_path, conf=conf, imgsz=640, verbose=False)[0]

        orig_img   = PILImage.open(img_path).convert("RGB")
        plotted = PILImage.fromarray(res.plot()[:, :, ::-1])

        col_data = [orig_img, plotted]
        titles   = ["Original", model_name]

        for col_idx, (img_data, title) in enumerate(zip(col_data, titles)):
            ax = axes[row_idx, col_idx] if n_rows > 1 else axes[col_idx]
            ax.imshow(img_data)
            ax.axis('off')
            if row_idx == 0:
                ax.set_title(title, fontsize=12, fontweight='bold', pad=6)

        # Hide unused subplots if any
        for c in range(len(col_data), axes.shape[1] if n_rows > 1 else len(axes)):
            extra = axes[row_idx, c] if n_rows > 1 else axes[c]
            extra.axis('off')

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=120, bbox_inches='tight')
        print(f"Saved → {save_path}")
    plt.show()

predict_and_plot(
    sample_imgs, best_weights, model_name,
    conf=0.25,
    save_path=f"{output_path}/{model_name}/visual_inspection_comparison.png"
)
# Out:
# Saved → ./runs/detect/YOLOv8s + CBAM/visual_inspection_comparison.png

# %%
# ── Confidence score distribution on test set ───────────────────────────────

def collect_confidences(model, img_list, conf_thresh=0.01):
    confs = []
    for p in img_list:
        res = model.predict(p, conf=conf_thresh, imgsz=640, verbose=False)[0]
        if res.boxes is not None and len(res.boxes):
            confs.extend(res.boxes.conf.cpu().numpy().tolist())
    return confs

confs_model = collect_confidences(best_weights, all_test_imgs)

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 5), sharey=False)
fig.suptitle("Detection Confidence Distribution — Test Set", fontsize=14, fontweight='bold')

axes.hist(confs_model, bins=40, color="#1f77b4", alpha=0.8, edgecolor='white')
axes.set_title(f"{model_name}  (n={len(confs_model)} detections)", fontsize=12)
axes.set_xlabel("Confidence Score")
axes.set_ylabel("Count")
axes.axvline(0.25, color='red', linestyle='--', linewidth=1.5, label='thresh=0.25')
axes.legend()
axes.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/confidence_distribution.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → confidence_distribution.png")
# Out:
# Saved → confidence_distribution.png

# %%
# ── Precision-Recall Curves (saved by Ultralytics) ──────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxPR_curve.png",
           f"PR Curve — {model_name} (Test Set)")
# Out:
# PR Curve — YOLOv8s + CBAM (Test Set)

# %%
# ── F1 Curves (saved by Ultralytics) ─────────────────────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxF1_curve.png",
           f"F1-Confidence Curve — {model_name} (Test Set)")
# Out:
# F1-Confidence Curve — YOLOv8s + CBAM (Test Set)

# %% [markdown]
# ## Final Summary

# %%
# ── Summary comparison table ─────────────────────────────────────────────────
import pandas as pd
from IPython.display import display

summary = pd.DataFrame({
    "Model":      [model_name],
    "Precision":  [val_model.box.mp],
    "Recall":     [val_model.box.mr],
    "mAP@50":     [val_model.box.map50],
    "mAP@50-95":  [val_model.box.map],
}).set_index("Model").round(4)

# Highlight best value per column
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: #d4edda; font-weight: bold; color:#000000' if v else '' for v in is_max]

print("\n===== Test Set Performance Summary =====")
display(summary.style.apply(highlight_max, axis=0))
# Out:
# ===== Test Set Performance Summary =====
# <style type="text/css">
# #T_83017_row0_col0, #T_83017_row0_col1, #T_83017_row0_col2, #T_83017_row0_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
#   color: #000000;
# }
# </style>
# <table id="T_83017">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83017_level0_col0" class="col_heading level0 col0" >Precision</th>
#       <th id="T_83017_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_83017_level0_col2" class="col_heading level0 col2" >mAP@50</th>
#       <th id="T_83017_level0_col3" class="col_heading level0 col3" >mAP@50-95</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83017_level0_row0" class="row_heading level0 row0" >YOLOv8s + CBAM</th>
#       <td id="T_83017_row0_col0" class="data row0 col0" >0.890700</td>
#       <td id="T_83017_row0_col1" class="data row0 col1" >0.765200</td>
#       <td id="T_83017_row0_col2" class="data row0 col2" >0.811100</td>
#       <td id="T_83017_row0_col3" class="data row0 col3" >0.525500</td>
#     </tr>
#   </tbody>
# </table>
