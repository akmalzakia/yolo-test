# %%
# !git clone https://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@github.com/akmalzakia/yolo-test.git
# !git clone --depth 1 https://github.com/ultralytics/ultralytics.git

# %%
# %cd ultralytics
# !pip install -q -e .

# %%
# import wandb

# wandb.login()

# %%
# SET PATH
dataset_path = 'D:/deep-learning/datasets/cctsdb2021-full'
yolo_repo = ".."
project_name = "YOLOv8s Traffic Detection"
output_path = f"./runs/detect/{project_name}"
yolo_mod_path = f'{yolo_repo}/custom'
ultralytics_path = "D:/deep-learning/ultralytics/ultralytics"

yolo_path = f'{yolo_repo}/cfg/yolov8s-p2_2.yaml'
model_name = "YOLOv8s + P2 v2"

# %%
import shutil

# conv.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/conv.py', 
            f'{ultralytics_path}/nn/modules/conv.py')

# block.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/block.py', 
            f'{ultralytics_path}/nn/modules/block.py')

# __init__.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/__init__.py', 
            f'{ultralytics_path}/nn/modules/__init__.py')

# tasks.py -- ultralytics/nn/
shutil.copy(f'{yolo_mod_path}/nn/tasks.py', 
            f'{ultralytics_path}/nn/tasks.py')

# loss.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/utils/loss.py',
            f'{ultralytics_path}/utils/loss.py')

# loss_logger.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/utils/loss_logger.py',
            f'{ultralytics_path}/utils/loss_logger.py')
# Out:
# 'D:/deep-learning/ultralytics/ultralytics/utils/loss_logger.py'

# %%
from ultralytics import YOLO
from ultralytics.utils import SETTINGS
SETTINGS['wandb'] = True
SETTINGS['tensorboard'] = True

# %%
configs = {
    "data": dataset_path,
    "epochs": 100,
    "imgsz": 640,
    "batch": 16,
    "amp": True,
    "device": "0",
    "optimizer": 'SGD',
    "lr0": 0.01,
    "workers": 4,
    "patience": 15,
    "val": True,
    "project": project_name
}

# %%
import os
os.environ['YOLO_IOU_LOSS']        = 'CIoU'
os.environ['YOLO_IOU_MONOTONOUS']  = 'none'
# os.environ['YOLO_IOU_INNER_RATIO'] = '0.7'

# %% [markdown]
# ## YOLO Training

# %%
# from wandb.integration.ultralytics import add_wandb_callback
from ultralytics.utils.loss_logger import log_loss_config

# with wandb.init(project=configs["project"], name=model_name, job_type="train") as run:
model = YOLO(yolo_path, task='detect', verbose=True)
model.add_callback('on_pretrain_routine_end', log_loss_config)
model_results = model.train(
    data    = configs["data"],
    epochs  = configs["epochs"],
    imgsz   = configs["imgsz"],
    batch   = configs["batch"], 
    device  = configs["device"],
    amp     = configs["amp"],
    workers      = configs["workers"],
    optimizer    = configs["optimizer"],
    lr0          = configs["lr0"],
    project      = configs["project"],
    name         = f"{model_name}/train",
    exist_ok     = True,
    save_period  = 10,
    verbose      = True,
    patience     = configs["patience"],
    val          = configs["val"]
)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#   8                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#   9             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  10                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 2]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  14                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  15            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18             [-1, 7]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  20        [13, 16, 19]  1    897664  ultralytics.nn.modules.head.Detect           [80, 16, None, [64, 128, 256]]
# YOLOv8s-p2_2 summary: 120 layers, 3,453,216 parameters, 3,453,200 gradients, 32.7 GFLOPs
#
# New https://pypi.org/project/ultralytics/8.4.53 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:/deep-learning/datasets/cctsdb2021-full, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../cfg/yolov8s-p2_2.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=YOLOv8s Traffic Detection, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# TensorBoard: Start with 'tensorboard --logdir D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\train', view at http://localhost:6006/
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: zakiasmara11 (azaki-its-team) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.27.0
# Run data is saved locally in <code>D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\train\wandb\run-20260523_063652-train_20260523_063652</code>
# Syncing run <strong><a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260523_063652' target="_blank">train</a></strong> to <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection</a>
#  View run at <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260523_063652' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260523_063652</a>
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#   8                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#   9             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  10                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 2]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  14                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  15            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18             [-1, 7]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  20        [13, 16, 19]  1    751897  ultralytics.nn.modules.head.Detect           [3, 16, None, [64, 128, 256]]
# YOLOv8s-p2_2 summary: 120 layers, 3,307,449 parameters, 3,307,433 gradients, 30.1 GFLOPs
#
# Freezing layer 'model.20.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 704.3312.9 MB/s, size: 58.6 KB)
# train: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\train.cache... 16356 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 16356/16356 4.3Git/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1960.6735.5 MB/s, size: 210.3 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 331.1Mit/s 0.0s
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 52 weight(decay=0.0), 59 weight(decay=0.0005), 58 bias(decay=0.0)
# Plotting labels to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\train\labels.jpg...
#
# Loss config
#   type        : CIoU
#   monotonous  : None  (v1  no focusing)
#   inner_ratio : 0.7
#
#
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# c:\Users\s2\anaconda3\envs\deep-learning\Lib\site-packages\torch\jit\_trace.py:1022: UserWarning: The input to trace is already a ScriptModule, tracing it is a no-op. Returning the object as is.
#   traced_func = _trace_impl(
#       1/100      4.83G      3.261      4.112      2.411          5        640: 100% ━━━━━━━━━━━━ 1023/1023 3.7it/s 4:38<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.336      0.208      0.142     0.0658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         5G      1.884       1.81      1.409         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:33<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.625      0.383      0.419      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         5G      1.592      1.336      1.237          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:31<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.694      0.441      0.496      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         5G      1.439      1.075       1.15          8        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:31<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228       0.77      0.533      0.591      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100       5.2G      1.324     0.9175      1.105          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:31<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.794      0.554       0.64      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100       5.2G      1.261     0.8344      1.072          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:31<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.726      0.638      0.691      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100       5.2G       1.22     0.7833       1.05          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:26<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.822      0.581      0.669      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100       5.2G      1.179     0.7403      1.034         13        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.815      0.623      0.719      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100       5.2G      1.146     0.7032      1.022         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.866      0.628      0.715      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100       5.2G       1.13     0.6773      1.013         14        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.856      0.667      0.757      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100       5.2G      1.111     0.6603      1.006         13        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.811      0.707      0.775      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100       5.2G       1.09     0.6406     0.9971         13        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.5s0.2s
#                    all       1500       3228      0.832      0.689      0.767      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100       5.2G      1.071     0.6319     0.9896         27        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228       0.86      0.655      0.774      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100       5.2G      1.064     0.6114     0.9868         18        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.836      0.702      0.785      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100       5.2G      1.045     0.5982      0.978          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.1s
#                    all       1500       3228      0.854      0.696      0.789      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100       5.2G       1.04     0.5913     0.9762          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228       0.83      0.735      0.804      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100       5.2G      1.029     0.5783     0.9751         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.856      0.709      0.798      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100       5.2G      1.017     0.5703     0.9697         22        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.1it/s 7.7s0.2s
#                    all       1500       3228      0.848      0.708      0.792      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100       5.2G       1.01     0.5644     0.9659         20        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228       0.86      0.715      0.807      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100       5.2G      1.001     0.5557     0.9622         22        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:24<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.865       0.72      0.814      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100       5.2G     0.9964     0.5489     0.9603         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.834      0.717      0.803      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100       5.2G     0.9811     0.5371     0.9546          8        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.868      0.712      0.813       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100       5.2G     0.9777     0.5383      0.953          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.874      0.723      0.825      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100       5.2G     0.9698     0.5279     0.9524         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.847      0.757      0.832      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100       5.2G     0.9621      0.521     0.9475         15        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.893      0.698      0.813      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100       5.2G     0.9584     0.5165     0.9484          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.861      0.775      0.846      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100       5.2G     0.9535     0.5138     0.9455         19        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.838       0.79      0.848      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100       5.2G     0.9492     0.5079     0.9436         15        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.864      0.765      0.843      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100       5.2G     0.9476      0.507     0.9409         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228       0.86      0.766      0.842      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100       5.2G     0.9376     0.4995     0.9407         19        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228       0.86      0.762      0.845      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100       5.2G     0.9338     0.4947     0.9388         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.853      0.756      0.835      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100       5.2G     0.9303     0.4927     0.9362         18        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.855      0.777      0.839      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100       5.2G      0.925     0.4876     0.9356         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.867      0.758      0.838      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100       5.2G     0.9269      0.487      0.935          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:26<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.865       0.75      0.826      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      5.41G      0.912     0.4807     0.9331         18        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:31<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.882      0.754      0.837      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      5.41G      0.913     0.4789     0.9316         14        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:31<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228       0.87      0.761      0.848      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      5.41G     0.9044     0.4712     0.9268         20        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:31<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.878      0.769      0.844      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      5.41G     0.8996     0.4706     0.9258         18        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:31<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.892      0.764      0.851      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      5.41G     0.9018     0.4693     0.9275          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.858      0.774      0.837      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      5.41G     0.8976     0.4683     0.9223         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.5s0.2s
#                    all       1500       3228      0.889      0.752      0.843      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      5.41G     0.8938     0.4616     0.9204          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.887      0.769      0.854      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      5.41G     0.8907     0.4605     0.9236         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228       0.89      0.761      0.853      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      5.41G     0.8848     0.4558       0.92         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.895      0.763      0.852      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      5.41G     0.8793      0.451     0.9177         14        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.898      0.767      0.849       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      5.41G     0.8762       0.45     0.9152         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.886      0.766      0.842      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      5.41G     0.8771     0.4495     0.9165          4        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.883      0.772      0.842      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      5.41G     0.8714     0.4463     0.9175         19        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228       0.89      0.771      0.846      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      5.41G     0.8676      0.442     0.9148          4        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.872      0.778      0.851      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      5.41G     0.8593      0.439     0.9112         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.888      0.774      0.853      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      5.41G     0.8607     0.4394     0.9128         14        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228       0.86      0.791      0.851      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      5.41G      0.861     0.4359     0.9121          8        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.1s
#                    all       1500       3228      0.867      0.784      0.845      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      5.41G     0.8593     0.4364     0.9108         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.871      0.783       0.84      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      5.41G     0.8538     0.4314     0.9069         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.875      0.781      0.844      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      5.41G     0.8485     0.4272     0.9079         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.874      0.781      0.842      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      5.41G     0.8494     0.4283     0.9094          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.874      0.783      0.843      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      5.41G     0.8459     0.4252     0.9075          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228       0.87      0.781      0.841      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      5.41G      0.842     0.4222     0.9057         14        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.873      0.775      0.841      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      5.41G     0.8401     0.4204     0.9053         16        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.876      0.764      0.837      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      5.41G     0.8337     0.4167      0.902          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.874      0.759      0.834       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      5.41G     0.8316      0.415     0.9025          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228       0.88       0.75      0.831       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      5.41G     0.8264     0.4125     0.8999         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.878      0.751      0.831      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      5.41G     0.8237     0.4112     0.9007         21        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.888      0.743      0.831      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      5.41G     0.8256     0.4107     0.9002          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.905      0.732      0.831       0.54
# EarlyStopping: Training stopped early as no improvement observed in last 15 epochs. Best results observed at epoch 48, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 63 epochs completed in 4.730 hours.
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\train\weights\last.pt, 6.9MB
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\train\weights\best.pt, 6.9MB
#
# Validating D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\train\weights\best.pt...
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8s-p2_2 summary (fused): 68 layers, 3,302,169 parameters, 0 gradients, 29.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 5.9it/s 7.9s0.2s
#                    all       1500       3228      0.872      0.778      0.851      0.554
#              mandatory        525        718      0.856      0.745      0.844      0.576
#            prohibitory       1043       2177      0.911      0.752      0.844      0.561
#                warning        288        333      0.848      0.838      0.864      0.524
# Speed: 0.1ms preprocess, 2.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\train
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 63 that is less than the current step 64. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>▄██▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>lr/pg1</td><td>▁▅███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂</td></tr><tr><td>lr/pg2</td><td>█▅▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/mAP50(B)</td><td>▁▄▅▆▇▇▇▇▇███████████████████████████████</td></tr><tr><td>metrics/mAP50-95(B)</td><td>▁▂▄▅▅▆▆▇▇▇▇▇▇█▇██████▇██████████████████</td></tr><tr><td>metrics/precision(B)</td><td>▁▅▆▇▆▇█▇▇▇▇▇▇▇▇▇██▇▇▇██████████▇████████</td></tr><tr><td>metrics/recall(B)</td><td>▁▃▄▅▅▆▆▇▇▇▇▇▇▇▇▇███████████████████████▇</td></tr><tr><td>model/GFLOPs</td><td>▁</td></tr><tr><td>model/parameters</td><td>▁</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>▁</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>0.00386</td></tr><tr><td>lr/pg1</td><td>0.00386</td></tr><tr><td>lr/pg2</td><td>0.00386</td></tr><tr><td>metrics/mAP50(B)</td><td>0.83143</td></tr><tr><td>metrics/mAP50-95(B)</td><td>0.5399</td></tr><tr><td>metrics/precision(B)</td><td>0.90502</td></tr><tr><td>metrics/recall(B)</td><td>0.73193</td></tr><tr><td>model/GFLOPs</td><td>30.056</td></tr><tr><td>model/parameters</td><td>3307449</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>2.678</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">train</strong> at: <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260523_063652' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260523_063652</a><br> View project at: <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection</a><br>Synced 5 W&B file(s), 20 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\train\wandb\run-20260523_063652-train_20260523_063652\logs</code>

# %% [markdown]
# ## Test Set Validation

# %%
import os

# Resolve best-weight paths
weights = f"{output_path}/{model_name}/train/weights/best.pt"

# Load best checkpoints
best_weights = YOLO(weights)

# Run validation on the test split
val_model = best_weights.val(
    data   = f"{configs["data"]}/dataset.yaml",
    split  = "test",
    imgsz  = configs["imgsz"],
    batch  = configs["batch"],
    device = configs["device"],
    plots  = True,
    project = configs["project"],
    name    = f"{model_name}/test",
    exist_ok = True,
    verbose  = True,
)

print(f"\n=== {model_name} — Test Set Results ===")
print(f"  mAP50   : {val_model.box.map50:.4f}")
print(f"  mAP50-95: {val_model.box.map:.4f}")
print(f"  Precision: {val_model.box.mp:.4f}")
print(f"  Recall   : {val_model.box.mr:.4f}")
# Out:
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8s-p2_2 summary (fused): 68 layers, 3,302,169 parameters, 0 gradients, 29.8 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 2473.4774.6 MB/s, size: 212.0 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 699.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 8.8it/s 10.7s0.1s
#                    all       1500       3228      0.872      0.778       0.85      0.555
#              mandatory        525        718      0.854      0.744      0.843      0.577
#            prohibitory       1043       2177      0.911      0.752      0.844      0.562
#                warning        288        333      0.851      0.839      0.864      0.525
# Speed: 0.4ms preprocess, 4.2ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + P2 v2\test
#
# === YOLOv8s + P2 v2 — Test Set Results ===
#   mAP50   : 0.8504
#   mAP50-95: 0.5545
#   Precision: 0.8720
#   Recall   : 0.7784

# %% [markdown]
# ## Metrics Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Helper to load results.csv produced by Ultralytics during training
def load_results(run_dir, run_name):
    csv_path = os.path.join(run_dir, run_name, "results.csv")
    df = pd.read_csv(csv_path)
    df.columns = df.columns.str.strip()  # strip whitespace from column names
    return df

df_result = load_results(output_path, f"{model_name}/train")

def plot_training_curves(df, model_name):
    metrics = [
        ("train/box_loss",  "Train Box Loss"),
        ("train/cls_loss",  "Train Cls Loss"),
        ("train/dfl_loss",  "Train DFL Loss"),
        ("metrics/mAP50(B)",    "mAP@50"),
        ("metrics/mAP50-95(B)", "mAP@50-95"),
        ("metrics/precision(B)", "Precision"),
        ("metrics/recall(B)",    "Recall"),
        ("val/box_loss",   "Val Box Loss"),
    ]

    ncols = 4
    nrows = 2
    fig, axes = plt.subplots(nrows, ncols, figsize=(20, 10))
    fig.suptitle(f"Training Curves -- {model_name}", fontsize=16, fontweight='bold')

    for ax, (col, title) in zip(axes.flat, metrics):
        epochs = df["epoch"] if "epoch" in df.columns else range(len(df))
        if col in df.columns:
            ax.plot(epochs, df[col], label=model_name, color="#1f77b4", linewidth=2)
        ax.set_title(title, fontsize=12)
        ax.set_xlabel("Epoch")
        ax.legend(fontsize=9)
        ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{output_path}/{model_name}/training_curves.png", dpi=150, bbox_inches='tight')
    plt.show()
    print("Saved → training_curves.png")

plot_training_curves(df_result, model_name)
# Out:
# Saved → training_curves.png

# %%
# ── Bar chart: Final metric comparison ──────────────────────────────────────

def get_final_metrics(val_result):
    return {
        "Precision":  val_result.box.mp,
        "Recall":     val_result.box.mr,
        "mAP@50":     val_result.box.map50,
        "mAP@50-95":  val_result.box.map,
    }

metrics_result = get_final_metrics(val_model)

labels  = list(metrics_result.keys())
vals_res = list(metrics_result.values())

x   = range(len(labels))
w   = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar([i - w/2 for i in x], vals_res, w, label=model_name, color='#1f77b4', alpha=0.85)

ax.set_xticks(list(x))
ax.set_xticklabels(labels, fontsize=13)
ax.set_ylabel("Score", fontsize=13)
ax.set_title(f"Test Set Metric {model_name}", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f"{bar.get_height():.3f}", ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/metric_bar.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → metric_bar.png")
# Out:
# Saved → metric_bar.png

# %%
# ── Per-class mAP comparison ─────────────────────────────────────────────────
import numpy as np

def get_per_class_ap(val_result):
    """Extract per-class AP50 from validation result."""
    maps  = val_result.box.maps      # per-class mAP50-95
    ap50s = val_result.box.ap50      # per-class mAP50, if available
    names = val_result.names         # {idx: class_name}
    class_names = [names[i] for i in sorted(names.keys())]
    return class_names, ap50s if ap50s is not None else maps

cls_names, ap50_model = get_per_class_ap(val_model)

x = np.arange(len(cls_names))
w = 0.35

fig, ax = plt.subplots(figsize=(max(14, len(cls_names) * 0.9), 6))
ax.bar(x - w/2, ap50_model, w, label=model_name, color='#1f77b4', alpha=0.85)
ax.set_xticks(x)
ax.set_xticklabels(cls_names, rotation=45, ha='right', fontsize=10)
ax.set_ylabel("AP@50")
ax.set_title("Per-class AP@50 — Test Set", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/per_class_ap50.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → per_class_ap50.png")
# Out:
# Saved → per_class_ap50.png

# %%
# ── Confusion matrices (saved by Ultralytics during val with plots=True) ─────
from IPython.display import Image, display

def show_image(path, title=""):
    if os.path.exists(path):
        print(f"\n{title}")
        display(Image(filename=path, width=700))
    else:
        print(f"[WARNING] Not found: {path}")

show_image(f"{output_path}/{model_name}/train/confusion_matrix_normalized.png",
           f"Confusion Matrix — {model_name} (Test Set)")
# Out:
# Confusion Matrix — YOLOv8s + P2 v2 (Test Set)

# %% [markdown]
# ## Visual Inspection on Test Images

# %%
import glob
import random
from PIL import Image as PILImage
import numpy as np

# ── Gather test images ───────────────────────────────────────────────────────
test_img_dir = os.path.join(dataset_path, "images", "test")
all_test_imgs = glob.glob(os.path.join(test_img_dir, "*.jpg")) + \
                glob.glob(os.path.join(test_img_dir, "*.png"))

random.seed(42)
sample_imgs = random.sample(all_test_imgs, min(8, len(all_test_imgs)))
print(f"Selected {len(sample_imgs)} test images for visual inspection.")
# Out:
# Selected 8 test images for visual inspection.

# %%
# ── Side-by-side predictions: Baseline | ES-YOLO ────────────────────────────

def predict_and_plot(imgs, model, model_name, n_cols=2, conf=0.25, save_path=None):
    n_imgs = len(imgs)
    n_rows = n_imgs

    fig, axes = plt.subplots(n_rows, n_cols * 2 + 1, figsize=(26, n_rows * 4))
    fig.suptitle(f"Visual Inspection — {model_name}", fontsize=15, fontweight='bold')

    # Column headers
    col_titles = ["Image", model_name, "Prediction"]

    for row_idx, img_path in enumerate(imgs):
        # Run predictions
        res = model.predict(img_path, conf=conf, imgsz=640, verbose=False)[0]

        orig_img   = PILImage.open(img_path).convert("RGB")
        plotted = PILImage.fromarray(res.plot()[:, :, ::-1])

        col_data = [orig_img, plotted]
        titles   = ["Original", model_name]

        for col_idx, (img_data, title) in enumerate(zip(col_data, titles)):
            ax = axes[row_idx, col_idx] if n_rows > 1 else axes[col_idx]
            ax.imshow(img_data)
            ax.axis('off')
            if row_idx == 0:
                ax.set_title(title, fontsize=12, fontweight='bold', pad=6)

        # Hide unused subplots if any
        for c in range(len(col_data), axes.shape[1] if n_rows > 1 else len(axes)):
            extra = axes[row_idx, c] if n_rows > 1 else axes[c]
            extra.axis('off')

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=120, bbox_inches='tight')
        print(f"Saved → {save_path}")
    plt.show()

predict_and_plot(
    sample_imgs, best_weights, model_name,
    conf=0.25,
    save_path=f"{output_path}/{model_name}/visual_inspection_comparison.png"
)
# Out:
# Saved → ./runs/detect/YOLOv8s Traffic Detection/YOLOv8s + P2 v2/visual_inspection_comparison.png

# %%
# ── Confidence score distribution on test set ───────────────────────────────

def collect_confidences(model, img_list, conf_thresh=0.01):
    confs = []
    for p in img_list:
        res = model.predict(p, conf=conf_thresh, imgsz=640, verbose=False)[0]
        if res.boxes is not None and len(res.boxes):
            confs.extend(res.boxes.conf.cpu().numpy().tolist())
    return confs

confs_model = collect_confidences(best_weights, all_test_imgs)

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 5), sharey=False)
fig.suptitle("Detection Confidence Distribution — Test Set", fontsize=14, fontweight='bold')

axes.hist(confs_model, bins=40, color="#1f77b4", alpha=0.8, edgecolor='white')
axes.set_title(f"{model_name}  (n={len(confs_model)} detections)", fontsize=12)
axes.set_xlabel("Confidence Score")
axes.set_ylabel("Count")
axes.axvline(0.25, color='red', linestyle='--', linewidth=1.5, label='thresh=0.25')
axes.legend()
axes.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/confidence_distribution.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → confidence_distribution.png")
# Out:
# Saved → confidence_distribution.png

# %%
# ── Precision-Recall Curves (saved by Ultralytics) ──────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxPR_curve.png",
           f"PR Curve — {model_name} (Test Set)")
# Out:
# PR Curve — YOLOv8s + P2 v2 (Test Set)

# %%
# ── F1 Curves (saved by Ultralytics) ─────────────────────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxF1_curve.png",
           f"F1-Confidence Curve — {model_name} (Test Set)")
# Out:
# F1-Confidence Curve — YOLOv8s + P2 v2 (Test Set)

# %% [markdown]
# ## Final Summary

# %%
# ── Summary comparison table ─────────────────────────────────────────────────
import pandas as pd
from IPython.display import display

summary = pd.DataFrame({
    "Model":      [model_name],
    "Precision":  [val_model.box.mp],
    "Recall":     [val_model.box.mr],
    "mAP@50":     [val_model.box.map50],
    "mAP@50-95":  [val_model.box.map],
}).set_index("Model").round(4)

# Highlight best value per column
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: #d4edda; font-weight: bold; color:#000000' if v else '' for v in is_max]

print("\n===== Test Set Performance Summary =====")
display(summary.style.apply(highlight_max, axis=0))
# Out:
# ===== Test Set Performance Summary =====
# <style type="text/css">
# #T_a218d_row0_col0, #T_a218d_row0_col1, #T_a218d_row0_col2, #T_a218d_row0_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
#   color: #000000;
# }
# </style>
# <table id="T_a218d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a218d_level0_col0" class="col_heading level0 col0" >Precision</th>
#       <th id="T_a218d_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_a218d_level0_col2" class="col_heading level0 col2" >mAP@50</th>
#       <th id="T_a218d_level0_col3" class="col_heading level0 col3" >mAP@50-95</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a218d_level0_row0" class="row_heading level0 row0" >YOLOv8s + P2 v2</th>
#       <td id="T_a218d_row0_col0" class="data row0 col0" >0.872000</td>
#       <td id="T_a218d_row0_col1" class="data row0 col1" >0.778400</td>
#       <td id="T_a218d_row0_col2" class="data row0 col2" >0.850400</td>
#       <td id="T_a218d_row0_col3" class="data row0 col3" >0.554500</td>
#     </tr>
#   </tbody>
# </table>
