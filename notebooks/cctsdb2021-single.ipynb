# %%
# !git clone https://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@github.com/akmalzakia/yolo-test.git
# !git clone --depth 1 https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'yolo-test'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 95 (delta 47), reused 75 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (95/95), 85.20 KiB | 7.75 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 1048, done.
# remote: Counting objects: 100% (1048/1048), done.
# remote: Compressing objects: 100% (797/797), done.
# remote: Total 1048 (delta 253), reused 647 (delta 236), pack-reused 0 (from 0)
# Receiving objects: 100% (1048/1048), 2.57 MiB | 19.08 MiB/s, done.
# Resolving deltas: 100% (253/253), done.

# %%
# %cd ultralytics
# !pip install -q -e .
# Out:
# /kaggle/working/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
# SET PATH
dataset_path = 'D:/deep-learning/datasets/cctsdb2021'
base_output = "/runs/detect"
output_path = 'D:\\deep-learning\\yolo-test\\notebooks\\runs\\detect\\output'
yolo_repo = ".."
yolo_path = f'{yolo_repo}/yolov8-p2.yaml'
yolo_mod_path = f'{yolo_repo}/nn'
ultralytics_path = "D:/deep-learning/ultralytics/ultralytics"

# %%
import shutil

# conv.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/modules/conv.py', 
            f'{ultralytics_path}/nn/modules/conv.py')

# block.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/modules/block.py', 
            f'{ultralytics_path}/nn/modules/block.py')

# __init__.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/modules/__init__.py', 
            f'{ultralytics_path}/nn/modules/__init__.py')

# tasks.py -- ultralytics/nn/
shutil.copy(f'{yolo_mod_path}/tasks.py', 
            f'{ultralytics_path}/nn/tasks.py')

# loss.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/loss.py',
            f'{ultralytics_path}/utils/loss.py')
# Out:
# 'D:/deep-learning/ultralytics/ultralytics/utils/loss.py'

# %%
from ultralytics import YOLO

# %%
configs = {
    "data": dataset_path,
    "epochs": 100,
    "imgsz": 640,
    "batch": 16,
    "amp": True,
    "device": "0",
    "optimizer": 'SGD',
    "lr0": 0.01,
    "workers": 4
}

# %%
import os

os.environ['USE_WIOU'] = '0'

# %% [markdown]
# ## YOLO Training

# %%
model = YOLO(yolo_path, task='detect', verbose=True)
model_name = "YOLOv8s + P2"

model_results = model.train(
    data    = configs["data"],
    epochs  = configs["epochs"],
    imgsz   = configs["imgsz"],
    batch   = configs["batch"], 
    device  = configs["device"],
    amp     = configs["amp"],
    workers      = configs["workers"],
    optimizer    = configs["optimizer"],
    lr0          = configs["lr0"],
    project      = f"{output_path}/runs/{model_name}",
    name         = model_name,
    exist_ok     = True,
    save_period  = 10,
    verbose      = True,
)
# Out:
# WARNING no model scale passed. Assuming scale='s'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  17             [-1, 2]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  19                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  20            [-1, 15]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  22                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  23            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  24                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  25        [18, 21, 24]  1    897664  ultralytics.nn.modules.head.Detect           [80, 16, None, [64, 128, 256]]
# YOLOv8-p2 summary: 140 layers, 7,555,616 parameters, 7,555,600 gradients, 37.0 GFLOPs
#
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:/deep-learning/datasets/cctsdb2021, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../yolov8-p2.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=YOLOv8s + P2, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=./output/runs/YOLOv8s + P2, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\deep-learning\yolo-test\notebooks\runs\detect\output\runs\YOLOv8s + P2\YOLOv8s + P2, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\s2\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 7.6MB/s 0.1s
# Overriding model.yaml nc=80 with nc=3
# WARNING no model scale passed. Assuming scale='s'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  17             [-1, 2]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  19                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  20            [-1, 15]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  22                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  23            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  24                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  25        [18, 21, 24]  1    751897  ultralytics.nn.modules.head.Detect           [3, 16, None, [64, 128, 256]]
# YOLOv8-p2 summary: 140 layers, 7,409,849 parameters, 7,409,833 gradients, 34.4 GFLOPs
#
# Freezing layer 'model.25.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 19.4MB/s 0.3s.2s<0.1s0s
# AMP: checks passed
# train: Fast image access  (ping: 0.10.1 ms, read: 276.679.6 MB/s, size: 89.0 KB)
# train: Scanning D:\deep-learning\datasets\cctsdb2021\labels\train... 14721 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 14721/14721 2.7Kit/s 5.4s0.1s
# train: New cache created: D:\deep-learning\datasets\cctsdb2021\labels\train.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 180.339.2 MB/s, size: 64.4 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021\labels\val... 1635 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1635/1635 1.7Kit/s 1.0s0.1s
# val: New cache created: D:\deep-learning\datasets\cctsdb2021\labels\val.cache
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 61 weight(decay=0.0), 68 weight(decay=0.0005), 67 bias(decay=0.0)
# Plotting labels to D:\deep-learning\yolo-test\notebooks\runs\detect\output\runs\YOLOv8s + P2\YOLOv8s + P2\labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to D:\deep-learning\yolo-test\notebooks\runs\detect\output\runs\YOLOv8s + P2\YOLOv8s + P2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      5.24G      3.511       4.53      2.588          6        640: 100% ━━━━━━━━━━━━ 921/921 3.6it/s 4:19<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.9s0.2s
#                    all       1635       2704      0.469      0.347      0.314      0.132
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      5.81G      1.941      1.944       1.42          1        640: 100% ━━━━━━━━━━━━ 921/921 3.6it/s 4:13<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.9it/s 7.5s0.2s
#                    all       1635       2704       0.76      0.554      0.642      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      5.81G      1.636      1.421      1.228          5        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.6s0.2s
#                    all       1635       2704      0.793       0.69      0.752      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      5.81G      1.474      1.135       1.14          2        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:12<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.3it/s 8.2s0.2s
#                    all       1635       2704      0.862      0.736      0.821      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      5.81G       1.36      0.964      1.096          1        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.9it/s 7.6s0.2s
#                    all       1635       2704      0.861      0.788      0.854      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      5.81G      1.287     0.8766      1.062          1        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704      0.885      0.838      0.898      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      5.81G      1.229     0.8024      1.039          5        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.9s0.2s
#                    all       1635       2704      0.903      0.836       0.91      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      5.81G      1.191     0.7583      1.024          6        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.894      0.872      0.929       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      5.81G      1.153     0.7268      1.012          5        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.6s0.2s
#                    all       1635       2704      0.899      0.879      0.932      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      5.81G      1.128     0.6974      1.001          4        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.904      0.876      0.927       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      5.81G      1.114     0.6812     0.9948          7        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.0it/s 7.4s0.2s
#                    all       1635       2704       0.92      0.883      0.945      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      5.81G      1.096     0.6573     0.9864          3        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.0it/s 7.5s0.2s
#                    all       1635       2704      0.926       0.88      0.944      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      5.81G      1.072     0.6363      0.979          1        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.1it/s 7.3s0.2s
#                    all       1635       2704      0.905        0.9      0.945      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      5.81G      1.065     0.6276     0.9766          1        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.1it/s 7.3s0.2s
#                    all       1635       2704       0.93      0.913      0.959      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      5.81G      1.051     0.6102     0.9709          4        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.1it/s 7.3s0.2s
#                    all       1635       2704       0.93      0.899      0.956      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      5.81G      1.044     0.6042     0.9693          5        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:11<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.9it/s 7.6s0.2s
#                    all       1635       2704      0.942      0.905      0.962      0.703
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      5.81G      1.035     0.5929     0.9643          1        640: 100% ━━━━━━━━━━━━ 921/921 3.6it/s 4:14<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.1s0.2s
#                    all       1635       2704       0.93      0.922      0.964      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      5.81G      1.018     0.5807     0.9569          0        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:33<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 5.1it/s 10.1s0.3s
#                    all       1635       2704      0.936      0.928      0.968      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      5.81G      1.012     0.5777     0.9567          1        640: 100% ━━━━━━━━━━━━ 921/921 3.6it/s 4:15<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.4it/s 7.0s0.2s
#                    all       1635       2704      0.937      0.929      0.969      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      5.81G      1.002     0.5639     0.9539          4        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:07<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.4it/s 7.0s0.2s
#                    all       1635       2704      0.936      0.922       0.97      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      5.81G     0.9921     0.5577     0.9525          2        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:07<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.0it/s 7.4s0.2s
#                    all       1635       2704       0.94       0.93      0.972       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      5.81G      0.983     0.5508     0.9462          2        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:07<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.0it/s 7.4s0.2s
#                    all       1635       2704      0.938      0.937      0.972      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      5.81G     0.9819     0.5439     0.9455          1        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:07<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.5it/s 7.0s0.2s
#                    all       1635       2704      0.948      0.932      0.972      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      5.81G     0.9714     0.5361     0.9431          2        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:07<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.1it/s 7.3s0.2s
#                    all       1635       2704      0.942      0.937      0.973      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      5.81G     0.9667     0.5313     0.9399          1        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:07<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 7.0it/s 7.4s0.2s
#                    all       1635       2704      0.944       0.95      0.978      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      5.81G     0.9573     0.5245      0.937          4        640: 100% ━━━━━━━━━━━━ 921/921 3.7it/s 4:07<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704      0.953      0.935      0.976      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      5.81G     0.9546     0.5213     0.9363          1        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:30<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704      0.945       0.95      0.979      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      5.81G     0.9497     0.5166     0.9338          6        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.951      0.949      0.979      0.746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      5.81G     0.9389      0.506     0.9298          3        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.3it/s 8.3s0.2s
#                    all       1635       2704      0.955      0.948      0.981      0.746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      5.81G     0.9341      0.505     0.9289          1        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704      0.954      0.952       0.98      0.746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      5.81G       0.93     0.5016     0.9299          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.953      0.955      0.981      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      5.81G     0.9223     0.5012     0.9258          3        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.948      0.958      0.981      0.753
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      5.81G     0.9209     0.4954     0.9246          3        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704      0.946      0.957      0.982      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      5.81G     0.9122     0.4863     0.9249          1        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.4it/s 8.2s0.2s
#                    all       1635       2704      0.948      0.962      0.982      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      5.81G     0.9077     0.4833     0.9215          5        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.6s0.2s
#                    all       1635       2704      0.955      0.954      0.984      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      5.81G     0.9108     0.4826     0.9205          1        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.951      0.964      0.984      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      5.81G     0.9016     0.4755     0.9171          4        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.954      0.964      0.985      0.759
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      5.81G     0.8999     0.4728     0.9168          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.956      0.963      0.984      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      5.81G     0.8951     0.4691     0.9155          1        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.959      0.959      0.986      0.762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      5.81G     0.8885     0.4655     0.9144          3        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704      0.957      0.961      0.985      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      5.81G     0.8892      0.465     0.9155          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704       0.96      0.965      0.985      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      5.81G     0.8837      0.462     0.9129          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.9s0.2s
#                    all       1635       2704      0.953      0.972      0.985      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      5.81G     0.8777     0.4589     0.9109          5        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704      0.957      0.969      0.986      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      5.81G     0.8768     0.4553     0.9083          3        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.8s0.2s
#                    all       1635       2704      0.959      0.966      0.986      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      5.82G     0.8751     0.4562     0.9083          7        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.963      0.968      0.986      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      5.82G     0.8665     0.4472     0.9064          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704       0.96       0.97      0.986      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      5.82G     0.8618     0.4451     0.9042          0        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.966      0.966      0.987      0.772
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      5.82G     0.8582     0.4428     0.9026          6        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704      0.964      0.969      0.988      0.772
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      5.82G     0.8546     0.4427     0.9017          6        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704      0.965      0.968      0.988      0.773
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      5.82G     0.8539     0.4364     0.9006          4        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.972       0.96      0.989      0.773
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      5.82G     0.8434     0.4341     0.8994          6        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.3it/s 8.3s0.2s
#                    all       1635       2704      0.971       0.96      0.988      0.772
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      5.82G     0.8464     0.4326     0.8993          2        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.971      0.961      0.988      0.774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      5.82G     0.8465     0.4343     0.8999          1        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.963      0.969      0.988      0.774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      5.82G     0.8403     0.4269     0.8977         10        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.963      0.973      0.989      0.774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      5.82G     0.8336     0.4222     0.8971          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704      0.963      0.971      0.989      0.776
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      5.82G     0.8331     0.4222     0.8957          3        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.969       0.97      0.989      0.779
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      5.82G     0.8303     0.4218     0.8961          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.969      0.969      0.989      0.779
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      5.82G     0.8288     0.4184     0.8947          8        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.966      0.973      0.989      0.779
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      5.82G     0.8262     0.4166     0.8927          7        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 7.9s0.2s
#                    all       1635       2704      0.966      0.975      0.989      0.779
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      5.82G     0.8215     0.4139     0.8913          3        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:22<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704      0.964      0.976      0.989       0.78
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      5.82G     0.8192     0.4153     0.8931          4        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.9s0.2s
#                    all       1635       2704      0.965      0.976      0.989      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      5.82G     0.8167     0.4124     0.8902          4        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.9s0.2s
#                    all       1635       2704      0.963      0.977      0.989      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      5.82G     0.8161      0.409      0.889          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.3it/s 8.2s0.2s
#                    all       1635       2704      0.962      0.978      0.989      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      5.82G     0.8121     0.4064     0.8875          8        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.2it/s 8.4s0.2s
#                    all       1635       2704      0.961      0.979      0.989      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      5.82G     0.8086     0.4037     0.8896          4        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.9s0.2s
#                    all       1635       2704      0.966      0.974      0.989      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      5.82G      0.806     0.4018     0.8852          5        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.9s0.2s
#                    all       1635       2704      0.965      0.976      0.989      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      5.82G     0.8051     0.3996     0.8872          4        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704      0.966      0.975       0.99      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      5.82G     0.7977      0.395     0.8853          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704      0.967      0.975      0.989      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      5.82G      0.801     0.3987      0.885          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704      0.965      0.977       0.99      0.783
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      5.82G      0.795     0.3943     0.8841          4        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704      0.965      0.978       0.99      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      5.82G     0.7925     0.3922     0.8825          5        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.9s0.2s
#                    all       1635       2704      0.966      0.978       0.99      0.783
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      5.82G     0.7879     0.3894     0.8823          4        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.9s0.2s
#                    all       1635       2704      0.967      0.978       0.99      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      5.82G     0.7876     0.3887     0.8829          3        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.967      0.977       0.99      0.785
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      5.82G     0.7826     0.3855     0.8794          3        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.966      0.978       0.99      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      5.82G     0.7787     0.3842      0.879          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704      0.966      0.978       0.99      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      5.82G       0.78     0.3813     0.8784          5        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.4it/s 8.2s0.2s
#                    all       1635       2704      0.966      0.978       0.99      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      5.82G     0.7759     0.3784      0.876          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.6it/s 7.9s0.2s
#                    all       1635       2704      0.966      0.978       0.99      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      5.82G      0.771     0.3763     0.8753          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.967      0.978       0.99      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      5.82G     0.7651     0.3739     0.8743          5        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.1s0.2s
#                    all       1635       2704      0.968      0.977       0.99      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      5.82G     0.7695     0.3744     0.8768          4        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.969      0.977       0.99      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      5.82G     0.7589     0.3706     0.8742          4        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.3it/s 8.3s0.2s
#                    all       1635       2704      0.969      0.977       0.99      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      5.82G     0.7601     0.3686     0.8734          3        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:30<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 7.9s0.2s
#                    all       1635       2704      0.969      0.977       0.99      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      5.82G     0.7526     0.3651     0.8705          5        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704       0.97      0.977       0.99      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      5.82G     0.7524      0.364     0.8717          2        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:30<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704       0.97      0.978       0.99      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      5.82G     0.7522     0.3645     0.8701          1        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:29<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704      0.971      0.977       0.99      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      5.82G     0.7477     0.3601     0.8702          7        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704       0.97      0.978       0.99      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      5.82G     0.7464     0.3596       0.87          1        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704       0.97      0.978       0.99      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      5.82G      0.741     0.3571     0.8676          5        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704       0.97      0.977       0.99      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      5.82G     0.7368     0.3547     0.8655          5        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.5it/s 8.0s0.2s
#                    all       1635       2704      0.969      0.978       0.99      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      5.82G     0.7366     0.3558     0.8668          1        640: 100% ━━━━━━━━━━━━ 921/921 3.4it/s 4:28<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704       0.97      0.978       0.99      0.788
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      5.82G     0.7145     0.3365     0.8682          4        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:27<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704       0.97      0.978       0.99      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      5.82G     0.7087     0.3301     0.8663          2        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:26<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704       0.97      0.978       0.99      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      5.82G     0.7054     0.3282     0.8667          3        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:26<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704       0.97      0.978       0.99      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      5.82G     0.6987     0.3241     0.8644          2        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:26<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.1it/s 8.5s0.2s
#                    all       1635       2704      0.969      0.979       0.99       0.79
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      5.82G     0.6974     0.3233     0.8637          1        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:26<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.969      0.979       0.99       0.79
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      5.82G     0.6956     0.3216     0.8647          1        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:26<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.969       0.98       0.99       0.79
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      5.82G     0.6912     0.3196     0.8636          1        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:26<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.969       0.98       0.99       0.79
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      5.82G     0.6852     0.3174      0.862          2        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:26<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.8s0.2s
#                    all       1635       2704      0.969      0.979       0.99      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      5.82G     0.6829     0.3144     0.8602          1        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:26<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.7it/s 7.7s0.2s
#                    all       1635       2704       0.97      0.979       0.99       0.79
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      5.82G     0.6766     0.3124     0.8581          1        640: 100% ━━━━━━━━━━━━ 921/921 3.5it/s 4:26<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 6.8it/s 7.7s0.2s
#                    all       1635       2704       0.97      0.979       0.99      0.791
#
# 100 epochs completed in 7.547 hours.
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\output\runs\YOLOv8s + P2\YOLOv8s + P2\weights\last.pt, 15.1MB
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\output\runs\YOLOv8s + P2\YOLOv8s + P2\weights\best.pt, 15.1MB
#
# Validating D:\deep-learning\yolo-test\notebooks\runs\detect\output\runs\YOLOv8s + P2\YOLOv8s + P2\weights\best.pt...
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8-p2 summary (fused): 79 layers, 7,401,369 parameters, 0 gradients, 34.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 52/52 5.9it/s 8.7s0.2s
#                    all       1635       2704       0.97      0.979       0.99      0.791
#              mandatory        613        853      0.965      0.988       0.99      0.797
#            prohibitory        935       1416       0.97      0.967      0.988      0.791
#                warning        367        435      0.975      0.983      0.994      0.785
# Speed: 0.1ms preprocess, 2.4ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\output\runs\YOLOv8s + P2\YOLOv8s + P2

# %% [markdown]
# ## Test Set Validation

# %%
import os

# Resolve best-weight paths
weights = f"{output_path}/runs/{model_name}/{model_name}/weights/best.pt"

# Load best checkpoints
best_weights = YOLO(weights)

# Run validation on the test split
val_model = best_weights.val(
    data   = f"{configs["data"]}/dataset.yaml",
    split  = "test",
    imgsz  = configs["imgsz"],
    batch  = configs["batch"],
    device = configs["device"],
    plots  = True,
    project = f"{output_path}/val/{model_name}",
    name    = "test",
    exist_ok = True,
    verbose  = True,
)

print(f"\n=== {model_name} — Test Set Results ===")
print(f"  mAP50   : {val_model.box.map50:.4f}")
print(f"  mAP50-95: {val_model.box.map:.4f}")
print(f"  Precision: {val_model.box.mp:.4f}")
print(f"  Recall   : {val_model.box.mr:.4f}")
# Out:
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8-p2 summary (fused): 79 layers, 7,401,369 parameters, 0 gradients, 34.1 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 2063.7755.0 MB/s, size: 203.5 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 629.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 7.9it/s 11.9s0.1s
#                    all       1500       3228      0.899      0.747      0.818      0.541
#              mandatory        525        718      0.865      0.652      0.721      0.489
#            prohibitory       1043       2177      0.952      0.745      0.844      0.571
#                warning        288        333      0.881      0.845       0.89      0.563
# Speed: 0.6ms preprocess, 4.8ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\output\val\YOLOv8s + P2\test
#
# === YOLOv8s + P2 — Test Set Results ===
#   mAP50   : 0.8180
#   mAP50-95: 0.5411
#   Precision: 0.8992
#   Recall   : 0.7470

# %% [markdown]
# ## Metrics Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Helper to load results.csv produced by Ultralytics during training
def load_results(run_dir, run_name):
    csv_path = os.path.join(run_dir, run_name, "results.csv")
    df = pd.read_csv(csv_path)
    df.columns = df.columns.str.strip()  # strip whitespace from column names
    return df

df_result = load_results(f"{output_path}/runs/{model_name}", model_name)

def plot_training_curves(df, model_name):
    metrics = [
        ("train/box_loss",  "Train Box Loss"),
        ("train/cls_loss",  "Train Cls Loss"),
        ("train/dfl_loss",  "Train DFL Loss"),
        ("metrics/mAP50(B)",    "mAP@50"),
        ("metrics/mAP50-95(B)", "mAP@50-95"),
        ("metrics/precision(B)", "Precision"),
        ("metrics/recall(B)",    "Recall"),
        ("val/box_loss",   "Val Box Loss"),
    ]

    ncols = 4
    nrows = 2
    fig, axes = plt.subplots(nrows, ncols, figsize=(20, 10))
    fig.suptitle(f"Training Curves -- {model_name}", fontsize=16, fontweight='bold')

    for ax, (col, title) in zip(axes.flat, metrics):
        epochs = df["epoch"] if "epoch" in df.columns else range(len(df))
        if col in df.columns:
            ax.plot(epochs, df[col], label=model_name, color="#1f77b4", linewidth=2)
        ax.set_title(title, fontsize=12)
        ax.set_xlabel("Epoch")
        ax.legend(fontsize=9)
        ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{output_path}/training_curves.png", dpi=150, bbox_inches='tight')
    plt.show()
    print("Saved → training_curves.png")

plot_training_curves(df_result, model_name)
# Out:
# Saved → training_curves.png

# %%
# ── Bar chart: Final metric comparison ──────────────────────────────────────

def get_final_metrics(val_result):
    return {
        "Precision":  val_result.box.mp,
        "Recall":     val_result.box.mr,
        "mAP@50":     val_result.box.map50,
        "mAP@50-95":  val_result.box.map,
    }

metrics_result = get_final_metrics(val_model)

labels  = list(metrics_result.keys())
vals_res = list(metrics_result.values())

x   = range(len(labels))
w   = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar([i - w/2 for i in x], vals_res, w, label=model_name, color='#1f77b4', alpha=0.85)

ax.set_xticks(list(x))
ax.set_xticklabels(labels, fontsize=13)
ax.set_ylabel("Score", fontsize=13)
ax.set_title(f"Test Set Metric {model_name}", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f"{bar.get_height():.3f}", ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig(f"{output_path}/metric_bar.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → metric_bar.png")
# Out:
# Saved → metric_bar.png

# %%
# ── Per-class mAP comparison ─────────────────────────────────────────────────
import numpy as np

def get_per_class_ap(val_result):
    """Extract per-class AP50 from validation result."""
    maps  = val_result.box.maps      # per-class mAP50-95
    ap50s = val_result.box.ap50      # per-class mAP50, if available
    names = val_result.names         # {idx: class_name}
    class_names = [names[i] for i in sorted(names.keys())]
    return class_names, ap50s if ap50s is not None else maps

cls_names, ap50_model = get_per_class_ap(val_model)

x = np.arange(len(cls_names))
w = 0.35

fig, ax = plt.subplots(figsize=(max(14, len(cls_names) * 0.9), 6))
ax.bar(x - w/2, ap50_model, w, label=model_name, color='#1f77b4', alpha=0.85)
ax.set_xticks(x)
ax.set_xticklabels(cls_names, rotation=45, ha='right', fontsize=10)
ax.set_ylabel("AP@50")
ax.set_title("Per-class AP@50 — Test Set", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(f"{output_path}/per_class_ap50.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → per_class_ap50.png")
# Out:
# Saved → per_class_ap50.png

# %%
# ── Confusion matrices (saved by Ultralytics during val with plots=True) ─────
from IPython.display import Image, display

def show_image(path, title=""):
    if os.path.exists(path):
        print(f"\n{title}")
        display(Image(filename=path, width=700))
    else:
        print(f"[WARNING] Not found: {path}")

show_image(f"{output_path}/val/{model_name}/test/confusion_matrix_normalized.png",
           f"Confusion Matrix — {model_name} (Test Set)")
# Out:
# Confusion Matrix — YOLOv8s + P2 (Test Set)

# %% [markdown]
# ## Visual Inspection on Test Images

# %%
import glob
import random
from PIL import Image as PILImage
import numpy as np

# ── Gather test images ───────────────────────────────────────────────────────
test_img_dir = os.path.join(dataset_path, "images", "val")
all_test_imgs = glob.glob(os.path.join(test_img_dir, "*.jpg")) + \
                glob.glob(os.path.join(test_img_dir, "*.png"))

random.seed(42)
sample_imgs = random.sample(all_test_imgs, min(8, len(all_test_imgs)))
print(f"Selected {len(sample_imgs)} test images for visual inspection.")
# Out:
# Selected 8 test images for visual inspection.

# %%
# ── Side-by-side predictions: Baseline | ES-YOLO ────────────────────────────

def predict_and_plot(imgs, model, model_name, n_cols=2, conf=0.25, save_path=None):
    n_imgs = len(imgs)
    n_rows = n_imgs

    fig, axes = plt.subplots(n_rows, n_cols * 2 + 1, figsize=(26, n_rows * 4))
    fig.suptitle(f"Visual Inspection — {model_name}", fontsize=15, fontweight='bold')

    # Column headers
    col_titles = ["Image", model_name, "Prediction"]

    for row_idx, img_path in enumerate(imgs):
        # Run predictions
        res = model.predict(img_path, conf=conf, imgsz=640, verbose=False)[0]

        orig_img   = PILImage.open(img_path).convert("RGB")
        plotted = PILImage.fromarray(res.plot()[:, :, ::-1])

        col_data = [orig_img, plotted]
        titles   = ["Original", model_name]

        for col_idx, (img_data, title) in enumerate(zip(col_data, titles)):
            ax = axes[row_idx, col_idx] if n_rows > 1 else axes[col_idx]
            ax.imshow(img_data)
            ax.axis('off')
            if row_idx == 0:
                ax.set_title(title, fontsize=12, fontweight='bold', pad=6)

        # Hide unused subplots if any
        for c in range(len(col_data), axes.shape[1] if n_rows > 1 else len(axes)):
            extra = axes[row_idx, c] if n_rows > 1 else axes[c]
            extra.axis('off')

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=120, bbox_inches='tight')
        print(f"Saved → {save_path}")
    plt.show()

predict_and_plot(
    sample_imgs, best_weights, model_name,
    conf=0.25,
    save_path=f"{output_path}/visual_inspection_comparison.png"
)
# Out:
# Saved → D:\deep-learning\yolo-test\notebooks\runs\detect\output/visual_inspection_comparison.png

# %%
# ── Confidence score distribution on test set ───────────────────────────────

def collect_confidences(model, img_list, conf_thresh=0.01):
    confs = []
    for p in img_list:
        res = model.predict(p, conf=conf_thresh, imgsz=640, verbose=False)[0]
        if res.boxes is not None and len(res.boxes):
            confs.extend(res.boxes.conf.cpu().numpy().tolist())
    return confs

confs_model = collect_confidences(best_weights, all_test_imgs)

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 5), sharey=False)
fig.suptitle("Detection Confidence Distribution — Test Set", fontsize=14, fontweight='bold')

axes.hist(confs_model, bins=40, color="#1f77b4", alpha=0.8, edgecolor='white')
axes.set_title(f"{model_name}  (n={len(confs_model)} detections)", fontsize=12)
axes.set_xlabel("Confidence Score")
axes.set_ylabel("Count")
axes.axvline(0.25, color='red', linestyle='--', linewidth=1.5, label='thresh=0.25')
axes.legend()
axes.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f"{output_path}/confidence_distribution.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → confidence_distribution.png")
# Out:
# Saved → confidence_distribution.png

# %%
# ── Precision-Recall Curves (saved by Ultralytics) ──────────────────────────

show_image(f"{output_path}/val/{model_name}/test/BoxPR_curve.png",
           f"PR Curve — {model_name} (Test Set)")
# Out:
# PR Curve — YOLOv8s + P2 (Test Set)

# %%
# ── F1 Curves (saved by Ultralytics) ─────────────────────────────────────────

show_image(f"{output_path}/val/{model_name}/test/BoxF1_curve.png",
           f"F1-Confidence Curve — {model_name} (Test Set)")
# Out:
# F1-Confidence Curve — YOLOv8s + P2 (Test Set)

# %% [markdown]
# ## Final Summary

# %%
# ── Summary comparison table ─────────────────────────────────────────────────
import pandas as pd
from IPython.display import display

summary = pd.DataFrame({
    "Model":      [model_name],
    "Precision":  [val_model.box.mp],
    "Recall":     [val_model.box.mr],
    "mAP@50":     [val_model.box.map50],
    "mAP@50-95":  [val_model.box.map],
}).set_index("Model").round(4)

# Highlight best value per column
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: #d4edda; font-weight: bold; color:#000000' if v else '' for v in is_max]

print("\n===== Test Set Performance Summary =====")
display(summary.style.apply(highlight_max, axis=0))
# Out:
# ===== Test Set Performance Summary =====
# <style type="text/css">
# #T_ef138_row0_col0, #T_ef138_row0_col1, #T_ef138_row0_col2, #T_ef138_row0_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
#   color: #000000;
# }
# </style>
# <table id="T_ef138">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef138_level0_col0" class="col_heading level0 col0" >Precision</th>
#       <th id="T_ef138_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_ef138_level0_col2" class="col_heading level0 col2" >mAP@50</th>
#       <th id="T_ef138_level0_col3" class="col_heading level0 col3" >mAP@50-95</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef138_level0_row0" class="row_heading level0 row0" >YOLOv8s + P2</th>
#       <td id="T_ef138_row0_col0" class="data row0 col0" >0.899200</td>
#       <td id="T_ef138_row0_col1" class="data row0 col1" >0.747000</td>
#       <td id="T_ef138_row0_col2" class="data row0 col2" >0.818000</td>
#       <td id="T_ef138_row0_col3" class="data row0 col3" >0.541100</td>
#     </tr>
#   </tbody>
# </table>
