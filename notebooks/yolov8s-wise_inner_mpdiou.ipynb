# %%
# !git clone https://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@github.com/akmalzakia/yolo-test.git
# !git clone --depth 1 https://github.com/ultralytics/ultralytics.git

# %%
# %cd ultralytics
# !pip install -q -e .

# %%
# import wandb

# wandb.login()

# %%
# SET PATH
dataset_path = 'D:/deep-learning/datasets/cctsdb2021-full'
yolo_repo = ".."
yolo_path = f'{yolo_repo}/cfg/yolov8s.yaml'
project_name = "YOLOv8s Traffic Detection"
output_path = f"./runs/detect/{project_name}"
yolo_mod_path = f'{yolo_repo}/custom'
ultralytics_path = "D:/deep-learning/ultralytics/ultralytics"

# %%
import shutil

# conv.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/conv.py', 
            f'{ultralytics_path}/nn/modules/conv.py')

# block.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/block.py', 
            f'{ultralytics_path}/nn/modules/block.py')

# __init__.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/__init__.py', 
            f'{ultralytics_path}/nn/modules/__init__.py')

# tasks.py -- ultralytics/nn/
shutil.copy(f'{yolo_mod_path}/nn/tasks.py', 
            f'{ultralytics_path}/nn/tasks.py')

# loss.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/utils/loss.py',
            f'{ultralytics_path}/utils/loss.py')

# loss_logger.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/utils/loss_logger.py',
            f'{ultralytics_path}/utils/loss_logger.py')
# Out:
# 'D:/deep-learning/ultralytics/ultralytics/utils/loss_logger.py'

# %%
from ultralytics import YOLO
from ultralytics.utils import SETTINGS
SETTINGS['wandb'] = True
SETTINGS['tensorboard'] = True

# %%
configs = {
    "data": dataset_path,
    "epochs": 100,
    "imgsz": 640,
    "batch": 16,
    "amp": True,
    "device": "0",
    "optimizer": 'SGD',
    "lr0": 0.01,
    "workers": 4,
    "patience": 15,
    "val": True,
    "project": project_name
}

# %%
import os
os.environ['YOLO_IOU_LOSS']        = 'WiseInnerMPDIoU'
os.environ['YOLO_IOU_MONOTONOUS']  = 'false'
os.environ['YOLO_IOU_INNER_RATIO'] = '0.7'

# %% [markdown]
# ## YOLO Training

# %%
# from wandb.integration.ultralytics import add_wandb_callback
from ultralytics.utils.loss_logger import log_loss_config

model_name = "YOLOv8s + Wise-Inner-MPDIoU"

# with wandb.init(project=configs["project"], name=model_name, job_type="train") as run:
model = YOLO(yolo_path, task='detect', verbose=True)
model.add_callback('on_pretrain_routine_end', log_loss_config)
model_results = model.train(
    data    = configs["data"],
    epochs  = configs["epochs"],
    imgsz   = configs["imgsz"],
    batch   = configs["batch"], 
    device  = configs["device"],
    amp     = configs["amp"],
    workers      = configs["workers"],
    optimizer    = configs["optimizer"],
    lr0          = configs["lr0"],
    project      = configs["project"],
    name         = f"{model_name}/train",
    exist_ok     = True,
    save_period  = 10,
    verbose      = True,
    patience     = configs["patience"],
    val          = configs["val"]
)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2147008  ultralytics.nn.modules.head.Detect           [80, 16, None, [128, 256, 512]]
# YOLOv8s summary: 130 layers, 11,166,560 parameters, 11,166,544 gradients, 28.8 GFLOPs
#
# New https://pypi.org/project/ultralytics/8.4.53 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:/deep-learning/datasets/cctsdb2021-full, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../cfg/yolov8s.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=YOLOv8s Traffic Detection, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# TensorBoard: Start with 'tensorboard --logdir D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\train', view at http://localhost:6006/
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: zakiasmara11 (azaki-its-team) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.27.0
# Run data is saved locally in <code>D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\train\wandb\run-20260522_165921-train_20260522_165921</code>
# Syncing run <strong><a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260522_165921' target="_blank">train</a></strong> to <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection</a>
#  View run at <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260522_165921' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260522_165921</a>
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.head.Detect           [3, 16, None, [128, 256, 512]]
# YOLOv8s summary: 130 layers, 11,136,761 parameters, 11,136,745 gradients, 28.7 GFLOPs
#
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 815.3380.3 MB/s, size: 58.6 KB)
# train: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\train.cache... 16356 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 16356/16356 3.4Git/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 2176.0983.4 MB/s, size: 210.3 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 251.7Mit/s 0.0s
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\train\labels.jpg...
#
# Loss config
#   type        : WiseInnerMPDIoU
#   monotonous  : False (v3  non-monotonic FM)
#   inner_ratio : 0.7
#
#
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# c:\Users\s2\anaconda3\envs\deep-learning\Lib\site-packages\torch\jit\_trace.py:1022: UserWarning: The input to trace is already a ScriptModule, tracing it is a no-op. Returning the object as is.
#   traced_func = _trace_impl(
#       1/100      3.67G        3.6      4.797      2.053          5        640: 100% ━━━━━━━━━━━━ 1023/1023 4.9it/s 3:29<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.194      0.148     0.0722     0.0285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      3.89G      1.885      1.831      1.151         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.496      0.323      0.306       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      3.89G      1.513      1.314      1.027          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228        0.6      0.377       0.41      0.203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      3.89G      1.331      1.055     0.9682          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.648      0.462      0.508      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      3.89G      1.194     0.9064     0.9395          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.769      0.518      0.607      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      3.89G      1.106     0.8216     0.9193          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.712      0.576       0.64       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      3.89G      1.052     0.7715     0.9024          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228       0.76      0.608      0.672      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      3.89G      1.001     0.7298     0.8929         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.791      0.593      0.654      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      3.89G     0.9652     0.6943     0.8852         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.3it/s 6.4s0.1s
#                    all       1500       3228      0.814      0.641      0.698      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      3.89G     0.9419     0.6697     0.8827         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:23<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.833      0.628      0.703      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      3.89G     0.9131      0.652     0.8793         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.819      0.644      0.713      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      3.89G     0.8884     0.6323     0.8741         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.808      0.673      0.732      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      3.89G     0.8756     0.6191     0.8689         27        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.848      0.679      0.753      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      3.89G     0.8602     0.6053     0.8678         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.9it/s 6.8s0.1s
#                    all       1500       3228      0.857       0.68      0.749       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      3.89G     0.8397     0.5931     0.8648          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.1it/s 3:22<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.855       0.67      0.744      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      3.89G     0.8349     0.5847     0.8612          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:18<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.828      0.684      0.741      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      3.89G      0.826     0.5744     0.8604         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.886      0.676      0.752      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      3.89G     0.8092     0.5625     0.8567         22        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:18<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.874      0.704      0.766      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      3.89G     0.8015     0.5583     0.8547         20        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.868       0.68      0.761      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      3.89G     0.7925     0.5453     0.8518         22        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:18<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.893      0.689      0.764      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      3.89G     0.7883     0.5419     0.8511         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.897      0.693      0.771      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      3.89G     0.7694      0.531     0.8506          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.866      0.696      0.768      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      3.89G     0.7636     0.5297     0.8516          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.7it/s 6.1s0.1s
#                    all       1500       3228      0.875      0.707      0.775      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      3.89G     0.7567     0.5211     0.8481         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.871      0.723      0.789      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      3.89G     0.7522     0.5148     0.8461         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:17<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.7it/s 6.1s0.1s
#                    all       1500       3228      0.905        0.7      0.789      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      3.89G     0.7441     0.5078     0.8463          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.1it/s 3:21<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.888      0.705      0.784      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      3.89G     0.7421     0.5062     0.8437         19        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.911      0.711      0.789      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      3.89G     0.7358     0.4983     0.8431         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.1it/s 6.6s0.1s
#                    all       1500       3228      0.896      0.723      0.794      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      3.89G     0.7303     0.4961     0.8421         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.903      0.717       0.79      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      3.89G     0.7255     0.4898     0.8424         19        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.896      0.728        0.8      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      3.89G     0.7199     0.4883     0.8428         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228       0.89      0.726      0.795      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      3.89G     0.7094     0.4816     0.8403         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.898      0.719      0.793      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      3.89G     0.7121     0.4766     0.8403         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.2it/s 3:16<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.903      0.727      0.794      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      3.89G     0.7143     0.4732     0.8375          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.884      0.738      0.799        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      3.89G     0.6978     0.4704     0.8386         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228        0.9      0.732      0.797        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      3.89G     0.6984     0.4671     0.8368         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.3it/s 3:14<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.0it/s 5.9s0.1s
#                    all       1500       3228      0.909      0.735      0.802      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      3.89G     0.6919     0.4657     0.8351         20        640: 100% ━━━━━━━━━━━━ 1023/1023 5.1it/s 3:19<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.908       0.73      0.803      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      3.89G     0.6897     0.4618     0.8334         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.885      0.752      0.801      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      3.89G     0.6804     0.4585     0.8338          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.908      0.746      0.808      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      3.89G     0.6802     0.4566     0.8312         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.908      0.736      0.816      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      3.89G      0.673     0.4528     0.8291          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.899      0.749      0.816      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      3.89G     0.6656     0.4473     0.8329         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.1it/s 3:22<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.0it/s 5.9s0.1s
#                    all       1500       3228      0.922       0.73      0.816      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      3.89G      0.664     0.4445     0.8301         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.3it/s 3:15<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.0it/s 5.9s0.1s
#                    all       1500       3228      0.905      0.734      0.813      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      3.89G     0.6617     0.4457      0.829         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.1it/s 3:19<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.883      0.747      0.813      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      3.89G     0.6539     0.4392     0.8295         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.894      0.737      0.815      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      3.89G     0.6534     0.4367     0.8298          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.898       0.74      0.811      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      3.89G     0.6514     0.4352     0.8302         19        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.3it/s 6.5s0.1s
#                    all       1500       3228      0.881      0.752      0.813      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      3.89G      0.644      0.429     0.8292          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.2s0.1s
#                    all       1500       3228      0.882      0.757      0.815      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      3.89G     0.6361     0.4265      0.826         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.892      0.752      0.817       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      3.89G     0.6356     0.4274      0.826         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.894      0.755      0.818      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.89G      0.634     0.4225     0.8266          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228       0.89      0.766       0.82      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.89G     0.6306     0.4213     0.8259         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.889      0.765      0.822      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      3.89G       0.63     0.4215     0.8228         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.891      0.762      0.822      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      3.89G     0.6235     0.4164     0.8237         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.892      0.762      0.821      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      3.89G      0.628      0.417     0.8276          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.887       0.77      0.821      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      3.89G     0.6201     0.4125     0.8228          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.884      0.772      0.823      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      3.89G     0.6134     0.4096     0.8231         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.886       0.77      0.821      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      3.89G     0.6149     0.4079     0.8197         16        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.891      0.767      0.821      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      3.89G     0.6076     0.4038     0.8222          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.887      0.768      0.823      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      3.89G     0.6054     0.4026     0.8213          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.897      0.766      0.823      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      3.89G     0.6002      0.401     0.8189         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.899      0.767      0.824      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      3.89G     0.5994     0.3976     0.8201         21        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.903      0.764      0.825      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      3.89G     0.5981     0.3981     0.8189          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.901      0.767      0.824      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      3.89G     0.5993     0.3965     0.8186         24        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.905      0.764      0.824      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      3.89G      0.586     0.3924     0.8189         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.904      0.766      0.825      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      3.89G     0.5871     0.3886     0.8188         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.766      0.825      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      3.89G      0.585     0.3906     0.8172         24        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.909      0.763      0.825      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      3.89G     0.5875      0.389     0.8189         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.907      0.765      0.826      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      3.89G     0.5743     0.3825     0.8157         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.765      0.827      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      3.89G     0.5773      0.384     0.8144          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.903      0.766      0.827      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      3.89G     0.5717     0.3806     0.8164          5        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.907      0.765      0.829       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      3.89G     0.5697      0.378     0.8138         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.906      0.767      0.829      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      3.89G     0.5655     0.3757     0.8116         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.768       0.83      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      3.89G     0.5593     0.3719     0.8126         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.904      0.769       0.83       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      3.89G     0.5555     0.3699     0.8135         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.906       0.77      0.829       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      3.89G     0.5623     0.3704     0.8134         17        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.3it/s 6.4s0.1s
#                    all       1500       3228      0.907      0.771      0.831      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      3.89G     0.5532     0.3669     0.8107         16        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.906      0.771       0.83      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      3.89G     0.5533     0.3652     0.8099          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.907      0.771       0.83       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      3.89G     0.5482     0.3632     0.8137          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.907      0.771       0.83      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      3.89G     0.5497     0.3611     0.8107          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.908       0.77      0.831      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      3.89G     0.5462     0.3588     0.8109          3        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.2it/s 6.5s0.1s
#                    all       1500       3228      0.908      0.772      0.832      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      3.89G     0.5395     0.3549      0.809          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.906      0.773      0.832      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      3.89G     0.5349     0.3522     0.8079         16        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.772      0.832      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      3.89G     0.5354     0.3525     0.8088         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.906      0.772      0.832      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      3.89G     0.5306     0.3487     0.8073         11        640: 100% ━━━━━━━━━━━━ 1023/1023 4.9it/s 3:28<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.773      0.832      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      3.89G     0.5301     0.3494     0.8086         15        640: 100% ━━━━━━━━━━━━ 1023/1023 4.6it/s 3:41<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 4.6it/s 10.2s0.2s
#                    all       1500       3228      0.904      0.773      0.833      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      3.89G     0.5233     0.3457     0.8072         10        640: 100% ━━━━━━━━━━━━ 1023/1023 4.6it/s 3:41<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.904      0.773      0.833      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      3.89G     0.5239     0.3455     0.8059         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.772      0.832      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      3.89G     0.5204     0.3434     0.8048         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.906      0.773      0.832      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      3.89G     0.5136     0.3399      0.804          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:26<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.907      0.773      0.832      0.534
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      3.89G     0.4968     0.3238      0.806          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.3it/s 6.4s0.1s
#                    all       1500       3228      0.904      0.773      0.832      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      3.89G      0.487     0.3164     0.8043          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.906      0.773      0.831      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      3.89G     0.4898     0.3177     0.8023          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.906      0.772      0.831      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      3.89G     0.4781     0.3121      0.803          5        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:24<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.907      0.772      0.831      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      3.89G       0.48     0.3108     0.8032          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228      0.905      0.772      0.831      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      3.89G     0.4713     0.3082     0.8016          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.1it/s 6.6s0.1s
#                    all       1500       3228      0.906      0.772      0.831      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      3.89G     0.4698     0.3043     0.8024          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.904      0.773      0.831      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      3.89G     0.4688     0.3033     0.8015          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.4s0.1s
#                    all       1500       3228      0.907      0.772      0.831      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      3.89G     0.4626     0.3014        0.8          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.905      0.774      0.831      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      3.89G     0.4561     0.2982     0.7978          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.0it/s 3:25<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.4it/s 6.3s0.1s
#                    all       1500       3228      0.904      0.774      0.831      0.535
#
# 100 epochs completed in 5.859 hours.
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\train\weights\last.pt, 22.5MB
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\train\weights\best.pt, 22.5MB
#
# Validating D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\train\weights\best.pt...
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8s summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.1s
#                    all       1500       3228      0.907      0.773      0.831      0.535
#              mandatory        525        718      0.892      0.687      0.744      0.487
#            prohibitory       1043       2177      0.935      0.763      0.846       0.56
#                warning        288        333      0.893      0.871      0.902      0.558
# Speed: 0.1ms preprocess, 1.9ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\train
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>▃█▇▇▇▇▇▇▇▇▆▆▆▆▆▆▆▅▅▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▁▁▁</td></tr><tr><td>lr/pg1</td><td>▆████▇▇▇▇▇▆▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▂▂▂▂▁▁</td></tr><tr><td>lr/pg2</td><td>█████▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▁▁▁</td></tr><tr><td>metrics/mAP50(B)</td><td>▁▃▅▆▆▇▇▆▇▇▇▇▇▇▇▇▇▇▇█████████████████████</td></tr><tr><td>metrics/mAP50-95(B)</td><td>▁▂▄▅▅▆▆▆▇▇▇▇▇█▇█████████████████████████</td></tr><tr><td>metrics/precision(B)</td><td>▁▃▂▃▆▇▅▅▅▇▆▇▇▇▆█▇▇▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>metrics/recall(B)</td><td>▁▆▆▇▆▇▇▇▇▇▇█▇▇██████████████████████████</td></tr><tr><td>model/GFLOPs</td><td>▁</td></tr><tr><td>model/parameters</td><td>▁</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>▁</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>0.0002</td></tr><tr><td>lr/pg1</td><td>0.0002</td></tr><tr><td>lr/pg2</td><td>0.0002</td></tr><tr><td>metrics/mAP50(B)</td><td>0.83055</td></tr><tr><td>metrics/mAP50-95(B)</td><td>0.53479</td></tr><tr><td>metrics/precision(B)</td><td>0.90438</td></tr><tr><td>metrics/recall(B)</td><td>0.77391</td></tr><tr><td>model/GFLOPs</td><td>28.651</td></tr><tr><td>model/parameters</td><td>11136761</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>2.058</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">train</strong> at: <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260522_165921' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260522_165921</a><br> View project at: <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection</a><br>Synced 5 W&B file(s), 23 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\train\wandb\run-20260522_165921-train_20260522_165921\logs</code>

# %% [markdown]
# ## Test Set Validation

# %%
import os

# Resolve best-weight paths
weights = f"{output_path}/{model_name}/train/weights/best.pt"

# Load best checkpoints
best_weights = YOLO(weights)

# Run validation on the test split
val_model = best_weights.val(
    data   = f"{configs["data"]}/dataset.yaml",
    split  = "test",
    imgsz  = configs["imgsz"],
    batch  = configs["batch"],
    device = configs["device"],
    plots  = True,
    project = configs["project"],
    name    = f"{model_name}/test",
    exist_ok = True,
    verbose  = True,
)

print(f"\n=== {model_name} — Test Set Results ===")
print(f"  mAP50   : {val_model.box.map50:.4f}")
print(f"  mAP50-95: {val_model.box.map:.4f}")
print(f"  Precision: {val_model.box.mp:.4f}")
print(f"  Recall   : {val_model.box.mr:.4f}")
# Out:
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8s summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 2117.2603.8 MB/s, size: 210.8 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 699.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 9.8it/s 9.6s0.2ss
#                    all       1500       3228      0.905      0.774      0.831      0.538
#              mandatory        525        718      0.889      0.688      0.746       0.49
#            prohibitory       1043       2177      0.934      0.763      0.846      0.563
#                warning        288        333      0.893      0.871      0.902      0.561
# Speed: 0.4ms preprocess, 3.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Wise-Inner-MPDIoU\test
#
# === YOLOv8s + Wise-Inner-MPDIoU — Test Set Results ===
#   mAP50   : 0.8314
#   mAP50-95: 0.5380
#   Precision: 0.9052
#   Recall   : 0.7741

# %% [markdown]
# ## Metrics Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Helper to load results.csv produced by Ultralytics during training
def load_results(run_dir, run_name):
    csv_path = os.path.join(run_dir, run_name, "results.csv")
    df = pd.read_csv(csv_path)
    df.columns = df.columns.str.strip()  # strip whitespace from column names
    return df

df_result = load_results(output_path, f"{model_name}/train")

def plot_training_curves(df, model_name):
    metrics = [
        ("train/box_loss",  "Train Box Loss"),
        ("train/cls_loss",  "Train Cls Loss"),
        ("train/dfl_loss",  "Train DFL Loss"),
        ("metrics/mAP50(B)",    "mAP@50"),
        ("metrics/mAP50-95(B)", "mAP@50-95"),
        ("metrics/precision(B)", "Precision"),
        ("metrics/recall(B)",    "Recall"),
        ("val/box_loss",   "Val Box Loss"),
    ]

    ncols = 4
    nrows = 2
    fig, axes = plt.subplots(nrows, ncols, figsize=(20, 10))
    fig.suptitle(f"Training Curves -- {model_name}", fontsize=16, fontweight='bold')

    for ax, (col, title) in zip(axes.flat, metrics):
        epochs = df["epoch"] if "epoch" in df.columns else range(len(df))
        if col in df.columns:
            ax.plot(epochs, df[col], label=model_name, color="#1f77b4", linewidth=2)
        ax.set_title(title, fontsize=12)
        ax.set_xlabel("Epoch")
        ax.legend(fontsize=9)
        ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{output_path}/{model_name}/training_curves.png", dpi=150, bbox_inches='tight')
    plt.show()
    print("Saved → training_curves.png")

plot_training_curves(df_result, model_name)
# Out:
# Saved → training_curves.png

# %%
# ── Bar chart: Final metric comparison ──────────────────────────────────────

def get_final_metrics(val_result):
    return {
        "Precision":  val_result.box.mp,
        "Recall":     val_result.box.mr,
        "mAP@50":     val_result.box.map50,
        "mAP@50-95":  val_result.box.map,
    }

metrics_result = get_final_metrics(val_model)

labels  = list(metrics_result.keys())
vals_res = list(metrics_result.values())

x   = range(len(labels))
w   = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar([i - w/2 for i in x], vals_res, w, label=model_name, color='#1f77b4', alpha=0.85)

ax.set_xticks(list(x))
ax.set_xticklabels(labels, fontsize=13)
ax.set_ylabel("Score", fontsize=13)
ax.set_title(f"Test Set Metric {model_name}", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f"{bar.get_height():.3f}", ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/metric_bar.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → metric_bar.png")
# Out:
# Saved → metric_bar.png

# %%
# ── Per-class mAP comparison ─────────────────────────────────────────────────
import numpy as np

def get_per_class_ap(val_result):
    """Extract per-class AP50 from validation result."""
    maps  = val_result.box.maps      # per-class mAP50-95
    ap50s = val_result.box.ap50      # per-class mAP50, if available
    names = val_result.names         # {idx: class_name}
    class_names = [names[i] for i in sorted(names.keys())]
    return class_names, ap50s if ap50s is not None else maps

cls_names, ap50_model = get_per_class_ap(val_model)

x = np.arange(len(cls_names))
w = 0.35

fig, ax = plt.subplots(figsize=(max(14, len(cls_names) * 0.9), 6))
ax.bar(x - w/2, ap50_model, w, label=model_name, color='#1f77b4', alpha=0.85)
ax.set_xticks(x)
ax.set_xticklabels(cls_names, rotation=45, ha='right', fontsize=10)
ax.set_ylabel("AP@50")
ax.set_title("Per-class AP@50 — Test Set", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/per_class_ap50.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → per_class_ap50.png")
# Out:
# Saved → per_class_ap50.png

# %%
# ── Confusion matrices (saved by Ultralytics during val with plots=True) ─────
from IPython.display import Image, display

def show_image(path, title=""):
    if os.path.exists(path):
        print(f"\n{title}")
        display(Image(filename=path, width=700))
    else:
        print(f"[WARNING] Not found: {path}")

show_image(f"{output_path}/{model_name}/train/confusion_matrix_normalized.png",
           f"Confusion Matrix — {model_name} (Test Set)")
# Out:
# Confusion Matrix — YOLOv8s + Wise-Inner-MPDIoU (Test Set)

# %% [markdown]
# ## Visual Inspection on Test Images

# %%
import glob
import random
from PIL import Image as PILImage
import numpy as np

# ── Gather test images ───────────────────────────────────────────────────────
test_img_dir = os.path.join(dataset_path, "images", "test")
all_test_imgs = glob.glob(os.path.join(test_img_dir, "*.jpg")) + \
                glob.glob(os.path.join(test_img_dir, "*.png"))

random.seed(42)
sample_imgs = random.sample(all_test_imgs, min(8, len(all_test_imgs)))
print(f"Selected {len(sample_imgs)} test images for visual inspection.")
# Out:
# Selected 8 test images for visual inspection.

# %%
# ── Side-by-side predictions: Baseline | ES-YOLO ────────────────────────────

def predict_and_plot(imgs, model, model_name, n_cols=2, conf=0.25, save_path=None):
    n_imgs = len(imgs)
    n_rows = n_imgs

    fig, axes = plt.subplots(n_rows, n_cols * 2 + 1, figsize=(26, n_rows * 4))
    fig.suptitle(f"Visual Inspection — {model_name}", fontsize=15, fontweight='bold')

    # Column headers
    col_titles = ["Image", model_name, "Prediction"]

    for row_idx, img_path in enumerate(imgs):
        # Run predictions
        res = model.predict(img_path, conf=conf, imgsz=640, verbose=False)[0]

        orig_img   = PILImage.open(img_path).convert("RGB")
        plotted = PILImage.fromarray(res.plot()[:, :, ::-1])

        col_data = [orig_img, plotted]
        titles   = ["Original", model_name]

        for col_idx, (img_data, title) in enumerate(zip(col_data, titles)):
            ax = axes[row_idx, col_idx] if n_rows > 1 else axes[col_idx]
            ax.imshow(img_data)
            ax.axis('off')
            if row_idx == 0:
                ax.set_title(title, fontsize=12, fontweight='bold', pad=6)

        # Hide unused subplots if any
        for c in range(len(col_data), axes.shape[1] if n_rows > 1 else len(axes)):
            extra = axes[row_idx, c] if n_rows > 1 else axes[c]
            extra.axis('off')

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=120, bbox_inches='tight')
        print(f"Saved → {save_path}")
    plt.show()

predict_and_plot(
    sample_imgs, best_weights, model_name,
    conf=0.25,
    save_path=f"{output_path}/{model_name}/visual_inspection_comparison.png"
)
# Out:
# Saved → ./runs/detect/YOLOv8s Traffic Detection/YOLOv8s + Wise-Inner-MPDIoU/visual_inspection_comparison.png

# %%
# ── Confidence score distribution on test set ───────────────────────────────

def collect_confidences(model, img_list, conf_thresh=0.01):
    confs = []
    for p in img_list:
        res = model.predict(p, conf=conf_thresh, imgsz=640, verbose=False)[0]
        if res.boxes is not None and len(res.boxes):
            confs.extend(res.boxes.conf.cpu().numpy().tolist())
    return confs

confs_model = collect_confidences(best_weights, all_test_imgs)

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 5), sharey=False)
fig.suptitle("Detection Confidence Distribution — Test Set", fontsize=14, fontweight='bold')

axes.hist(confs_model, bins=40, color="#1f77b4", alpha=0.8, edgecolor='white')
axes.set_title(f"{model_name}  (n={len(confs_model)} detections)", fontsize=12)
axes.set_xlabel("Confidence Score")
axes.set_ylabel("Count")
axes.axvline(0.25, color='red', linestyle='--', linewidth=1.5, label='thresh=0.25')
axes.legend()
axes.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/confidence_distribution.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → confidence_distribution.png")
# Out:
# Saved → confidence_distribution.png

# %%
# ── Precision-Recall Curves (saved by Ultralytics) ──────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxPR_curve.png",
           f"PR Curve — {model_name} (Test Set)")
# Out:
# PR Curve — YOLOv8s + Wise-Inner-MPDIoU (Test Set)

# %%
# ── F1 Curves (saved by Ultralytics) ─────────────────────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxF1_curve.png",
           f"F1-Confidence Curve — {model_name} (Test Set)")
# Out:
# F1-Confidence Curve — YOLOv8s + Wise-Inner-MPDIoU (Test Set)

# %% [markdown]
# ## Final Summary

# %%
# ── Summary comparison table ─────────────────────────────────────────────────
import pandas as pd
from IPython.display import display

summary = pd.DataFrame({
    "Model":      [model_name],
    "Precision":  [val_model.box.mp],
    "Recall":     [val_model.box.mr],
    "mAP@50":     [val_model.box.map50],
    "mAP@50-95":  [val_model.box.map],
}).set_index("Model").round(4)

# Highlight best value per column
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: #d4edda; font-weight: bold; color:#000000' if v else '' for v in is_max]

print("\n===== Test Set Performance Summary =====")
display(summary.style.apply(highlight_max, axis=0))
# Out:
# ===== Test Set Performance Summary =====
# <style type="text/css">
# #T_0102e_row0_col0, #T_0102e_row0_col1, #T_0102e_row0_col2, #T_0102e_row0_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
#   color: #000000;
# }
# </style>
# <table id="T_0102e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0102e_level0_col0" class="col_heading level0 col0" >Precision</th>
#       <th id="T_0102e_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_0102e_level0_col2" class="col_heading level0 col2" >mAP@50</th>
#       <th id="T_0102e_level0_col3" class="col_heading level0 col3" >mAP@50-95</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0102e_level0_row0" class="row_heading level0 row0" >YOLOv8s + Wise-Inner-MPDIoU</th>
#       <td id="T_0102e_row0_col0" class="data row0 col0" >0.905200</td>
#       <td id="T_0102e_row0_col1" class="data row0 col1" >0.774100</td>
#       <td id="T_0102e_row0_col2" class="data row0 col2" >0.831400</td>
#       <td id="T_0102e_row0_col3" class="data row0 col3" >0.538000</td>
#     </tr>
#   </tbody>
# </table>
