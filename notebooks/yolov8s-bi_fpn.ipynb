# %%
# !git clone https://github.com/akmalzakia/yolo-test.git
# !git clone --depth 1 https://github.com/ultralytics/ultralytics.git

# %%
# %cd ultralytics
# !pip install -q -e .

# %%
# import wandb

# wandb.login()

# %%
# SET PATH
dataset_path = 'D:/deep-learning/datasets/cctsdb2021-full'
yolo_repo = ".."
project_name = "YOLOv8s Traffic Detection"
output_path = f"./runs/detect/{project_name}"
yolo_mod_path = f'{yolo_repo}/custom'
ultralytics_path = "D:/deep-learning/ultralytics/ultralytics"

yolo_path = f'{yolo_repo}/cfg/yolov8s-bi_fpn.yaml'
model_name = "YOLOv8s + Bi-FPN"

# %%
import shutil

# conv.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/conv.py', 
            f'{ultralytics_path}/nn/modules/conv.py')

# block.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/block.py', 
            f'{ultralytics_path}/nn/modules/block.py')

# __init__.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/__init__.py', 
            f'{ultralytics_path}/nn/modules/__init__.py')

# tasks.py -- ultralytics/nn/
shutil.copy(f'{yolo_mod_path}/nn/tasks.py', 
            f'{ultralytics_path}/nn/tasks.py')

# loss.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/utils/loss.py',
            f'{ultralytics_path}/utils/loss.py')

# loss_logger.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/utils/loss_logger.py',
            f'{ultralytics_path}/utils/loss_logger.py')
# Out:
# 'D:/deep-learning/ultralytics/ultralytics/utils/loss_logger.py'

# %%
from ultralytics import YOLO
from ultralytics.utils import SETTINGS
SETTINGS['wandb'] = True
SETTINGS['tensorboard'] = True

# %%
configs = {
    "data": dataset_path,
    "epochs": 100,
    "imgsz": 640,
    "batch": 16,
    "amp": True,
    "device": "0",
    "optimizer": 'SGD',
    "lr0": 0.01,
    "workers": 4,
    "patience": 15,
    "val": True,
    "project": project_name
}

# %%
import os
os.environ['YOLO_IOU_LOSS']        = 'CIoU'
os.environ['YOLO_IOU_MONOTONOUS']  = 'none'
# os.environ['YOLO_IOU_INNER_RATIO'] = '0.7'

# %% [markdown]
# ## YOLO Training

# %%
# from wandb.integration.ultralytics import add_wandb_callback
from ultralytics.utils.loss_logger import log_loss_config

# with wandb.init(project=configs["project"], name=model_name, job_type="train") as run:
model = YOLO(yolo_path, task='detect', verbose=True)
model.add_callback('on_pretrain_routine_end', log_loss_config)
model_results = model.train(
    data    = configs["data"],
    epochs  = configs["epochs"],
    imgsz   = configs["imgsz"],
    batch   = configs["batch"], 
    device  = configs["device"],
    amp     = configs["amp"],
    workers      = configs["workers"],
    optimizer    = configs["optimizer"],
    lr0          = configs["lr0"],
    project      = configs["project"],
    name         = f"{model_name}/train",
    exist_ok     = True,
    save_period  = 10,
    verbose      = True,
    patience     = configs["patience"],
    val          = configs["val"]
)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                   4  1     16640  ultralytics.nn.modules.conv.Conv             [128, 128, 1, 1]
#  11                   6  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  12                   9  1     65792  ultralytics.nn.modules.conv.Conv             [512, 128, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14            [-1, 11]  1         2  ultralytics.nn.modules.block.BiFPNAdd        [2]
#  15                  -1  1    115456  ultralytics.nn.modules.block.C2f             [128, 128, 1]
#  16                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  17            [-1, 10]  1         2  ultralytics.nn.modules.block.BiFPNAdd        [2]
#  18                  -1  1    115456  ultralytics.nn.modules.block.C2f             [128, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20        [-1, 11, 15]  1         3  ultralytics.nn.modules.block.BiFPNAdd        [3]
#  21                  -1  1    115456  ultralytics.nn.modules.block.C2f             [128, 128, 1]
#  22                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  23            [-1, 12]  1         2  ultralytics.nn.modules.block.BiFPNAdd        [2]
#  24                  -1  1    115456  ultralytics.nn.modules.block.C2f             [128, 128, 1]
#  25        [18, 21, 24]  1   1262272  ultralytics.nn.modules.head.Detect           [80, 16, None, [128, 128, 128]]
# YOLOv8s-bi_fpn summary: 136 layers, 7,214,697 parameters, 7,214,681 gradients, 23.0 GFLOPs
#
# New https://pypi.org/project/ultralytics/8.4.53 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:/deep-learning/datasets/cctsdb2021-full, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../cfg/yolov8s-bi_fpn.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=YOLOv8s Traffic Detection, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# TensorBoard: Start with 'tensorboard --logdir D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\train', view at http://localhost:6006/
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: zakiasmara11 (azaki-its-team) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.27.0
# Run data is saved locally in <code>D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\train\wandb\run-20260524_123902-train_20260524_123902</code>
# Syncing run <strong><a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260524_123902' target="_blank">train</a></strong> to <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection</a>
#  View run at <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260524_123902' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260524_123902</a>
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                   4  1     16640  ultralytics.nn.modules.conv.Conv             [128, 128, 1, 1]
#  11                   6  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  12                   9  1     65792  ultralytics.nn.modules.conv.Conv             [512, 128, 1, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14            [-1, 11]  1         2  ultralytics.nn.modules.block.BiFPNAdd        [2]
#  15                  -1  1    115456  ultralytics.nn.modules.block.C2f             [128, 128, 1]
#  16                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  17            [-1, 10]  1         2  ultralytics.nn.modules.block.BiFPNAdd        [2]
#  18                  -1  1    115456  ultralytics.nn.modules.block.C2f             [128, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20        [-1, 11, 15]  1         3  ultralytics.nn.modules.block.BiFPNAdd        [3]
#  21                  -1  1    115456  ultralytics.nn.modules.block.C2f             [128, 128, 1]
#  22                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  23            [-1, 12]  1         2  ultralytics.nn.modules.block.BiFPNAdd        [2]
#  24                  -1  1    115456  ultralytics.nn.modules.block.C2f             [128, 128, 1]
#  25        [18, 21, 24]  1   1232473  ultralytics.nn.modules.head.Detect           [3, 16, None, [128, 128, 128]]
# YOLOv8s-bi_fpn summary: 136 layers, 7,184,898 parameters, 7,184,882 gradients, 22.8 GFLOPs
#
# Freezing layer 'model.25.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 819.2390.9 MB/s, size: 58.6 KB)
# train: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\train.cache... 16356 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 16356/16356 3.8Git/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 2046.5712.0 MB/s, size: 210.3 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 370.1Mit/s 0.0s
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 60 weight(decay=0.0), 71 weight(decay=0.0005), 66 bias(decay=0.0)
# Plotting labels to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\train\labels.jpg...
#
# Loss config
#   type        : CIoU
#   monotonous  : None  (v1  no focusing)
#   inner_ratio : 0.7
#
#
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# c:\Users\s2\anaconda3\envs\deep-learning\Lib\site-packages\torch\jit\_trace.py:1022: UserWarning: The input to trace is already a ScriptModule, tracing it is a no-op. Returning the object as is.
#   traced_func = _trace_impl(
#       1/100      3.45G      3.869      5.507      2.046          5        640: 100% ━━━━━━━━━━━━ 1023/1023 5.4it/s 3:11<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.7it/s 6.1s0.1s
#                    all       1500       3228      0.182      0.152     0.0776     0.0306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      3.66G      2.163      1.865      1.154         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.442      0.359      0.298      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      3.66G      1.733      1.324      1.029          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.7it/s 6.1s0.1s
#                    all       1500       3228      0.607      0.381      0.427      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      3.66G      1.551      1.057     0.9676          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.7it/s 6.1s0.1s
#                    all       1500       3228      0.633      0.462      0.506      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      3.66G       1.42     0.9161      0.943          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:60<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.2s0.1s
#                    all       1500       3228       0.75      0.467      0.559      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      3.66G      1.344     0.8402     0.9218          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.8it/s 2:57<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.2it/s 5.8s0.1s
#                    all       1500       3228      0.692      0.543      0.592      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      3.66G      1.296     0.7895      0.905          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228       0.78      0.621      0.675      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      3.66G      1.241      0.739     0.8953         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:59<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.0it/s 5.9s0.1s
#                    all       1500       3228      0.809      0.601      0.673      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      3.66G      1.206     0.7056      0.888         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 3:01<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.0it/s 5.9s0.1s
#                    all       1500       3228      0.795      0.604      0.667      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      3.66G      1.185     0.6829     0.8852         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:60<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.777      0.624      0.688      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      3.66G      1.159     0.6648     0.8814         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.815      0.634      0.699      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      3.66G      1.137     0.6428     0.8766         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:59<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.848       0.65      0.716      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      3.66G      1.121       0.63     0.8722         27        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.834      0.654      0.725      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      3.66G      1.105     0.6156     0.8704         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:59<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.857      0.674      0.732       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      3.66G      1.082     0.5996      0.867          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:60<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.0it/s 5.9s0.1s
#                    all       1500       3228      0.862      0.675      0.741      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      3.66G      1.075     0.5912     0.8635          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.2it/s 5.8s0.1s
#                    all       1500       3228      0.877      0.659      0.757       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      3.66G      1.064     0.5818     0.8624         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:59<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.0it/s 5.8s0.1s
#                    all       1500       3228      0.863      0.684      0.738      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      3.66G      1.052     0.5701     0.8588         22        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 3:00<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.862      0.682       0.75      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      3.66G      1.039     0.5614     0.8562         20        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.853      0.698      0.749      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      3.66G      1.035     0.5565     0.8538         22        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.2it/s 5.7s0.1s
#                    all       1500       3228      0.882      0.689       0.76      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      3.66G      1.029     0.5483     0.8526         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.2it/s 5.7s0.1s
#                    all       1500       3228      0.882      0.689      0.766      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      3.66G       1.01     0.5365     0.8517          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.8it/s 2:57<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.884       0.69      0.762      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      3.66G      1.005     0.5363     0.8526          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.865      0.707      0.766      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      3.66G     0.9929     0.5259      0.848         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.8it/s 2:57<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.2it/s 5.7s0.1s
#                    all       1500       3228      0.886      0.711       0.77      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      3.66G     0.9875     0.5202     0.8474         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.2it/s 5.7s0.1s
#                    all       1500       3228      0.884      0.708      0.769      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      3.66G      0.979     0.5152      0.848          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.8it/s 2:58<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.876      0.717      0.781      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      3.66G     0.9779     0.5116     0.8451         19        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.1it/s 5.8s0.1s
#                    all       1500       3228      0.897      0.716      0.783      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      3.66G     0.9636     0.5044     0.8432         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.8it/s 2:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.2it/s 5.7s0.1s
#                    all       1500       3228      0.884      0.709      0.779      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      3.66G     0.9629     0.5029     0.8423         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:59<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.2it/s 5.7s0.1s
#                    all       1500       3228        0.9      0.713      0.786      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      3.66G      0.952     0.4948     0.8422         19        640: 100% ━━━━━━━━━━━━ 1023/1023 5.8it/s 2:58<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 8.2it/s 5.7s0.1s
#                    all       1500       3228      0.891       0.73      0.793      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      3.66G     0.9469     0.4922     0.8426         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.7it/s 2:60<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.892      0.726      0.783       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      3.66G     0.9436     0.4874     0.8412         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.903      0.713      0.793      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      3.66G     0.9354     0.4818     0.8409         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.906      0.719      0.792      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      3.66G     0.9408     0.4813     0.8383          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.897      0.726      0.799        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      3.66G     0.9237     0.4754     0.8388         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.881      0.735      0.797        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      3.66G     0.9197     0.4736     0.8375         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:03<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.3it/s 6.4s0.1s
#                    all       1500       3228      0.898      0.736      0.802      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      3.66G     0.9148     0.4677     0.8356         20        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.887      0.738        0.8      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      3.66G     0.9116     0.4638      0.835         18        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.7it/s 6.1s0.1s
#                    all       1500       3228      0.906      0.726      0.793      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      3.66G     0.9065     0.4624      0.834          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228       0.88      0.747      0.796      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      3.66G     0.9017     0.4593     0.8302         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.907       0.74      0.806      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      3.66G     0.9001     0.4553     0.8303          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.899      0.745      0.806      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      3.66G     0.8902     0.4519     0.8338         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.896      0.744      0.804      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      3.66G     0.8901     0.4502     0.8299         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:03<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.884      0.756      0.803      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      3.66G      0.887     0.4461     0.8292         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.883      0.763      0.808       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      3.66G     0.8832     0.4446     0.8302         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.887      0.758      0.805      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      3.66G     0.8792      0.442     0.8298          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.889      0.754      0.804       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      3.66G     0.8741     0.4397     0.8299         19        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228       0.89      0.756      0.807      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      3.66G     0.8691     0.4347     0.8288          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.893      0.755      0.806      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      3.66G      0.862     0.4301     0.8257         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.1s0.1s
#                    all       1500       3228      0.876       0.77      0.808      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      3.66G     0.8611     0.4315     0.8267         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.894      0.756      0.809      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      3.66G     0.8598     0.4278     0.8267          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.891       0.76      0.811      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      3.66G      0.854     0.4243     0.8252         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.769      0.811      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      3.66G     0.8597     0.4259     0.8237         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.7it/s 6.1s0.1s
#                    all       1500       3228      0.882      0.772      0.811      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      3.66G     0.8472     0.4185     0.8236         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.882      0.766      0.811      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      3.66G      0.848     0.4189     0.8274          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.889       0.76      0.811      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      3.66G     0.8427     0.4171     0.8231          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.764      0.811      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      3.66G     0.8419     0.4141     0.8238         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.885      0.772      0.811      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      3.66G     0.8378     0.4106     0.8202         16        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.885      0.773      0.811      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      3.66G     0.8322     0.4087     0.8218          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.7it/s 6.1s0.1s
#                    all       1500       3228      0.886      0.774      0.812      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      3.66G     0.8275     0.4053     0.8215          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.882      0.774      0.811      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      3.66G     0.8241     0.4033      0.819         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.882      0.774       0.81      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      3.66G     0.8207      0.401     0.8197         21        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.884      0.773      0.811      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      3.66G      0.823     0.4009     0.8185          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.889      0.772      0.811      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      3.66G     0.8214     0.3989     0.8198         24        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.773      0.811      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      3.66G     0.8133     0.3961     0.8194         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.885      0.774      0.811      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      3.66G     0.8084      0.391     0.8187         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.776      0.813      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      3.66G     0.8111     0.3924     0.8175         24        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.884      0.775      0.813      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      3.66G     0.8132     0.3925     0.8195         12        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.775      0.813      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      3.66G     0.7985     0.3859     0.8166         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.888      0.774      0.813      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      3.66G     0.8018     0.3874     0.8152          8        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.5it/s 6.3s0.1s
#                    all       1500       3228      0.887      0.774      0.813      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      3.66G     0.7976     0.3841     0.8163          5        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.775      0.814      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      3.66G     0.7936     0.3823     0.8146         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.887      0.773      0.814      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      3.66G     0.7864     0.3783     0.8121         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.889      0.772      0.814      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      3.66G     0.7836     0.3754     0.8131         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.888      0.771      0.813      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      3.66G     0.7799      0.372     0.8145         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.887      0.773      0.813      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      3.66G      0.783     0.3723     0.8138         17        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.887      0.773      0.814      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      3.66G     0.7752     0.3698     0.8114         16        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.773      0.814      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      3.66G     0.7759     0.3689     0.8107          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.885      0.774      0.814      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      3.66G     0.7665     0.3659     0.8137          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.885      0.774      0.814      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      3.66G     0.7697     0.3642     0.8116          9        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.773      0.814       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      3.66G     0.7661     0.3637     0.8115          3        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.774      0.814       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      3.66G     0.7613     0.3575     0.8101          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 5.9s0.1s
#                    all       1500       3228      0.887      0.772      0.814       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      3.66G     0.7559     0.3571     0.8081         16        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.773      0.814       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      3.66G      0.753     0.3554     0.8091         14        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.885      0.773      0.814      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      3.66G     0.7481     0.3509     0.8074         11        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.1s0.1s
#                    all       1500       3228      0.886      0.772      0.814      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      3.66G      0.747     0.3508     0.8088         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.886      0.773      0.814      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      3.66G     0.7392     0.3468     0.8067         10        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.6it/s 6.1s0.1s
#                    all       1500       3228      0.886      0.773      0.814       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      3.66G     0.7418     0.3469     0.8069         15        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.888      0.774      0.815      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      3.66G     0.7404     0.3457     0.8057         13        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.888      0.773      0.815       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      3.66G     0.7327     0.3422     0.8051          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.7it/s 6.1s0.1s
#                    all       1500       3228      0.889      0.774      0.815       0.52
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      3.66G     0.7016     0.3239     0.8058          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.889      0.773      0.815      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      3.66G     0.6923     0.3187      0.804          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.889      0.772      0.815      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      3.66G     0.6906      0.319      0.802          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228       0.89      0.772      0.815       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      3.66G     0.6847     0.3138     0.8028          5        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.891       0.77      0.814       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      3.66G     0.6804      0.312     0.8036          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.9it/s 6.0s0.1s
#                    all       1500       3228      0.891      0.769      0.815      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      3.66G     0.6751     0.3103     0.8015          7        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.891      0.769      0.814      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      3.66G     0.6717     0.3068     0.8024          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:05<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.891       0.77      0.814      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      3.66G     0.6693     0.3047     0.8017          4        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:03<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.891       0.77      0.814      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      3.66G      0.666     0.3038     0.8008          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.5it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.891       0.77      0.814      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      3.66G      0.656     0.2987     0.7981          6        640: 100% ━━━━━━━━━━━━ 1023/1023 5.6it/s 3:04<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 7.8it/s 6.0s0.1s
#                    all       1500       3228      0.892      0.769      0.814      0.521
#
# 100 epochs completed in 5.257 hours.
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\train\weights\last.pt, 14.6MB
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\train\weights\best.pt, 14.6MB
#
# Validating D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\train\weights\best.pt...
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8s-bi_fpn summary (fused): 76 layers, 7,176,546 parameters, 0 gradients, 22.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.8it/s 6.9s0.1s
#                    all       1500       3228      0.891       0.77      0.814      0.521
#              mandatory        525        718      0.876      0.702      0.729      0.482
#            prohibitory       1043       2177      0.915      0.754      0.829      0.547
#                warning        288        333      0.883      0.853      0.883      0.535
# Speed: 0.1ms preprocess, 1.7ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\train
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>lr/pg1</td><td>▆███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▄▄▃▃▃▃▃▂▂▂▁▁▁</td></tr><tr><td>lr/pg2</td><td>█▅▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/mAP50(B)</td><td>▁▂▃▅▅▇▆▇▇▇▇▇█▇██████████████████████████</td></tr><tr><td>metrics/mAP50-95(B)</td><td>▁▃▅▆▆▇▇▇▇▇▇▇▇███████████████████████████</td></tr><tr><td>metrics/precision(B)</td><td>▁▂▄▅▇█▇█████▇█▇█▇█▇▇█▇█▇████████████████</td></tr><tr><td>metrics/recall(B)</td><td>▁▄▄▅▅▆▇▇▇▇▇▇▇▇▇█████████████████████████</td></tr><tr><td>model/GFLOPs</td><td>▁</td></tr><tr><td>model/parameters</td><td>▁</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>▁</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>0.0002</td></tr><tr><td>lr/pg1</td><td>0.0002</td></tr><tr><td>lr/pg2</td><td>0.0002</td></tr><tr><td>metrics/mAP50(B)</td><td>0.81351</td></tr><tr><td>metrics/mAP50-95(B)</td><td>0.52138</td></tr><tr><td>metrics/precision(B)</td><td>0.8922</td></tr><tr><td>metrics/recall(B)</td><td>0.76891</td></tr><tr><td>model/GFLOPs</td><td>22.791</td></tr><tr><td>model/parameters</td><td>7184898</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>1.861</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">train</strong> at: <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260524_123902' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260524_123902</a><br> View project at: <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection</a><br>Synced 5 W&B file(s), 23 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\train\wandb\run-20260524_123902-train_20260524_123902\logs</code>

# %% [markdown]
# ## Test Set Validation

# %%
import os

# Resolve best-weight paths
weights = f"{output_path}/{model_name}/train/weights/best.pt"

# Load best checkpoints
best_weights = YOLO(weights)

# Run validation on the test split
val_model = best_weights.val(
    data   = f"{configs["data"]}/dataset.yaml",
    split  = "test",
    imgsz  = configs["imgsz"],
    batch  = configs["batch"],
    device = configs["device"],
    plots  = True,
    project = configs["project"],
    name    = f"{model_name}/test",
    exist_ok = True,
    verbose  = True,
)

print(f"\n=== {model_name} — Test Set Results ===")
print(f"  mAP50   : {val_model.box.map50:.4f}")
print(f"  mAP50-95: {val_model.box.map:.4f}")
print(f"  Precision: {val_model.box.mp:.4f}")
print(f"  Recall   : {val_model.box.mr:.4f}")
# Out:
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8s-bi_fpn summary (fused): 76 layers, 7,176,546 parameters, 0 gradients, 22.6 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 2038.3703.7 MB/s, size: 212.0 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 572.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 10.3it/s 9.1s0.2s
#                    all       1500       3228      0.891      0.769      0.813      0.523
#              mandatory        525        718      0.876      0.702      0.729      0.481
#            prohibitory       1043       2177      0.915      0.753      0.828      0.551
#                warning        288        333      0.883      0.853      0.883      0.536
# Speed: 0.4ms preprocess, 3.0ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + Bi-FPN\test
#
# === YOLOv8s + Bi-FPN — Test Set Results ===
#   mAP50   : 0.8135
#   mAP50-95: 0.5227
#   Precision: 0.8914
#   Recall   : 0.7693

# %% [markdown]
# ## Metrics Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Helper to load results.csv produced by Ultralytics during training
def load_results(run_dir, run_name):
    csv_path = os.path.join(run_dir, run_name, "results.csv")
    df = pd.read_csv(csv_path)
    df.columns = df.columns.str.strip()  # strip whitespace from column names
    return df

df_result = load_results(output_path, f"{model_name}/train")

def plot_training_curves(df, model_name):
    metrics = [
        ("train/box_loss",  "Train Box Loss"),
        ("train/cls_loss",  "Train Cls Loss"),
        ("train/dfl_loss",  "Train DFL Loss"),
        ("metrics/mAP50(B)",    "mAP@50"),
        ("metrics/mAP50-95(B)", "mAP@50-95"),
        ("metrics/precision(B)", "Precision"),
        ("metrics/recall(B)",    "Recall"),
        ("val/box_loss",   "Val Box Loss"),
    ]

    ncols = 4
    nrows = 2
    fig, axes = plt.subplots(nrows, ncols, figsize=(20, 10))
    fig.suptitle(f"Training Curves -- {model_name}", fontsize=16, fontweight='bold')

    for ax, (col, title) in zip(axes.flat, metrics):
        epochs = df["epoch"] if "epoch" in df.columns else range(len(df))
        if col in df.columns:
            ax.plot(epochs, df[col], label=model_name, color="#1f77b4", linewidth=2)
        ax.set_title(title, fontsize=12)
        ax.set_xlabel("Epoch")
        ax.legend(fontsize=9)
        ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{output_path}/{model_name}/training_curves.png", dpi=150, bbox_inches='tight')
    plt.show()
    print("Saved → training_curves.png")

plot_training_curves(df_result, model_name)
# Out:
# Saved → training_curves.png

# %%
# ── Bar chart: Final metric comparison ──────────────────────────────────────

def get_final_metrics(val_result):
    return {
        "Precision":  val_result.box.mp,
        "Recall":     val_result.box.mr,
        "mAP@50":     val_result.box.map50,
        "mAP@50-95":  val_result.box.map,
    }

metrics_result = get_final_metrics(val_model)

labels  = list(metrics_result.keys())
vals_res = list(metrics_result.values())

x   = range(len(labels))
w   = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar([i - w/2 for i in x], vals_res, w, label=model_name, color='#1f77b4', alpha=0.85)

ax.set_xticks(list(x))
ax.set_xticklabels(labels, fontsize=13)
ax.set_ylabel("Score", fontsize=13)
ax.set_title(f"Test Set Metric {model_name}", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f"{bar.get_height():.3f}", ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/metric_bar.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → metric_bar.png")
# Out:
# Saved → metric_bar.png

# %%
# ── Per-class mAP comparison ─────────────────────────────────────────────────
import numpy as np

def get_per_class_ap(val_result):
    """Extract per-class AP50 from validation result."""
    maps  = val_result.box.maps      # per-class mAP50-95
    ap50s = val_result.box.ap50      # per-class mAP50, if available
    names = val_result.names         # {idx: class_name}
    class_names = [names[i] for i in sorted(names.keys())]
    return class_names, ap50s if ap50s is not None else maps

cls_names, ap50_model = get_per_class_ap(val_model)

x = np.arange(len(cls_names))
w = 0.35

fig, ax = plt.subplots(figsize=(max(14, len(cls_names) * 0.9), 6))
ax.bar(x - w/2, ap50_model, w, label=model_name, color='#1f77b4', alpha=0.85)
ax.set_xticks(x)
ax.set_xticklabels(cls_names, rotation=45, ha='right', fontsize=10)
ax.set_ylabel("AP@50")
ax.set_title("Per-class AP@50 — Test Set", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/per_class_ap50.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → per_class_ap50.png")
# Out:
# Saved → per_class_ap50.png

# %%
# ── Confusion matrices (saved by Ultralytics during val with plots=True) ─────
from IPython.display import Image, display

def show_image(path, title=""):
    if os.path.exists(path):
        print(f"\n{title}")
        display(Image(filename=path, width=700))
    else:
        print(f"[WARNING] Not found: {path}")

show_image(f"{output_path}/{model_name}/train/confusion_matrix_normalized.png",
           f"Confusion Matrix — {model_name} (Test Set)")
# Out:
# Confusion Matrix — YOLOv8s + Bi-FPN (Test Set)

# %% [markdown]
# ## Visual Inspection on Test Images

# %%
import glob
import random
from PIL import Image as PILImage
import numpy as np

# ── Gather test images ───────────────────────────────────────────────────────
test_img_dir = os.path.join(dataset_path, "images", "test")
all_test_imgs = glob.glob(os.path.join(test_img_dir, "*.jpg")) + \
                glob.glob(os.path.join(test_img_dir, "*.png"))

random.seed(42)
sample_imgs = random.sample(all_test_imgs, min(8, len(all_test_imgs)))
print(f"Selected {len(sample_imgs)} test images for visual inspection.")
# Out:
# Selected 8 test images for visual inspection.

# %%
# ── Side-by-side predictions: Baseline | ES-YOLO ────────────────────────────

def predict_and_plot(imgs, model, model_name, n_cols=2, conf=0.25, save_path=None):
    n_imgs = len(imgs)
    n_rows = n_imgs

    fig, axes = plt.subplots(n_rows, n_cols * 2 + 1, figsize=(26, n_rows * 4))
    fig.suptitle(f"Visual Inspection — {model_name}", fontsize=15, fontweight='bold')

    # Column headers
    col_titles = ["Image", model_name, "Prediction"]

    for row_idx, img_path in enumerate(imgs):
        # Run predictions
        res = model.predict(img_path, conf=conf, imgsz=640, verbose=False)[0]

        orig_img   = PILImage.open(img_path).convert("RGB")
        plotted = PILImage.fromarray(res.plot()[:, :, ::-1])

        col_data = [orig_img, plotted]
        titles   = ["Original", model_name]

        for col_idx, (img_data, title) in enumerate(zip(col_data, titles)):
            ax = axes[row_idx, col_idx] if n_rows > 1 else axes[col_idx]
            ax.imshow(img_data)
            ax.axis('off')
            if row_idx == 0:
                ax.set_title(title, fontsize=12, fontweight='bold', pad=6)

        # Hide unused subplots if any
        for c in range(len(col_data), axes.shape[1] if n_rows > 1 else len(axes)):
            extra = axes[row_idx, c] if n_rows > 1 else axes[c]
            extra.axis('off')

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=120, bbox_inches='tight')
        print(f"Saved → {save_path}")
    plt.show()

predict_and_plot(
    sample_imgs, best_weights, model_name,
    conf=0.25,
    save_path=f"{output_path}/{model_name}/visual_inspection_comparison.png"
)
# Out:
# Saved → ./runs/detect/YOLOv8s Traffic Detection/YOLOv8s + Bi-FPN/visual_inspection_comparison.png

# %%
# ── Confidence score distribution on test set ───────────────────────────────

def collect_confidences(model, img_list, conf_thresh=0.01):
    confs = []
    for p in img_list:
        res = model.predict(p, conf=conf_thresh, imgsz=640, verbose=False)[0]
        if res.boxes is not None and len(res.boxes):
            confs.extend(res.boxes.conf.cpu().numpy().tolist())
    return confs

confs_model = collect_confidences(best_weights, all_test_imgs)

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 5), sharey=False)
fig.suptitle("Detection Confidence Distribution — Test Set", fontsize=14, fontweight='bold')

axes.hist(confs_model, bins=40, color="#1f77b4", alpha=0.8, edgecolor='white')
axes.set_title(f"{model_name}  (n={len(confs_model)} detections)", fontsize=12)
axes.set_xlabel("Confidence Score")
axes.set_ylabel("Count")
axes.axvline(0.25, color='red', linestyle='--', linewidth=1.5, label='thresh=0.25')
axes.legend()
axes.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/confidence_distribution.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → confidence_distribution.png")
# Out:
# Saved → confidence_distribution.png

# %%
# ── Precision-Recall Curves (saved by Ultralytics) ──────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxPR_curve.png",
           f"PR Curve — {model_name} (Test Set)")
# Out:
# PR Curve — YOLOv8s + Bi-FPN (Test Set)

# %%
# ── F1 Curves (saved by Ultralytics) ─────────────────────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxF1_curve.png",
           f"F1-Confidence Curve — {model_name} (Test Set)")
# Out:
# F1-Confidence Curve — YOLOv8s + Bi-FPN (Test Set)

# %% [markdown]
# ## Final Summary

# %%
# ── Summary comparison table ─────────────────────────────────────────────────
import pandas as pd
from IPython.display import display

summary = pd.DataFrame({
    "Model":      [model_name],
    "Precision":  [val_model.box.mp],
    "Recall":     [val_model.box.mr],
    "mAP@50":     [val_model.box.map50],
    "mAP@50-95":  [val_model.box.map],
}).set_index("Model").round(4)

# Highlight best value per column
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: #d4edda; font-weight: bold; color:#000000' if v else '' for v in is_max]

print("\n===== Test Set Performance Summary =====")
display(summary.style.apply(highlight_max, axis=0))
# Out:
# ===== Test Set Performance Summary =====
# <style type="text/css">
# #T_7afe1_row0_col0, #T_7afe1_row0_col1, #T_7afe1_row0_col2, #T_7afe1_row0_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
#   color: #000000;
# }
# </style>
# <table id="T_7afe1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7afe1_level0_col0" class="col_heading level0 col0" >Precision</th>
#       <th id="T_7afe1_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_7afe1_level0_col2" class="col_heading level0 col2" >mAP@50</th>
#       <th id="T_7afe1_level0_col3" class="col_heading level0 col3" >mAP@50-95</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7afe1_level0_row0" class="row_heading level0 row0" >YOLOv8s + Bi-FPN</th>
#       <td id="T_7afe1_row0_col0" class="data row0 col0" >0.891400</td>
#       <td id="T_7afe1_row0_col1" class="data row0 col1" >0.769300</td>
#       <td id="T_7afe1_row0_col2" class="data row0 col2" >0.813500</td>
#       <td id="T_7afe1_row0_col3" class="data row0 col3" >0.522700</td>
#     </tr>
#   </tbody>
# </table>
