# %%
# !git clone https://github.com/akmalzakia/yolo-test.git
# !git clone --depth 1 https://github.com/ultralytics/ultralytics.git

# %%
# %cd ultralytics
# !pip install -q -e .

# %%
# import wandb

# wandb.login()

# %%
# SET PATH
dataset_path = 'D:/deep-learning/datasets/cctsdb2021-full'
yolo_repo = ".."
project_name = "YOLOv8s Traffic Detection"
output_path = f"./runs/detect/{project_name}"
yolo_mod_path = f'{yolo_repo}/custom'
ultralytics_path = "D:/deep-learning/ultralytics/ultralytics"

yolo_path = f'{yolo_repo}/cfg/yolov8s-spconv.yaml'
model_name = "YOLOv8s + SPConv"

# %%
import shutil

# conv.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/conv.py', 
            f'{ultralytics_path}/nn/modules/conv.py')

# block.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/block.py', 
            f'{ultralytics_path}/nn/modules/block.py')

# __init__.py -- ultralytics/nn/modules/
shutil.copy(f'{yolo_mod_path}/nn/modules/__init__.py', 
            f'{ultralytics_path}/nn/modules/__init__.py')

# spconv.py -- ultralytics/nn/
shutil.copy(f'{yolo_mod_path}/nn/modules/spconv.py',
            f'{ultralytics_path}/nn/modules/spconv.py')

# tasks.py -- ultralytics/nn/
shutil.copy(f'{yolo_mod_path}/nn/tasks.py', 
            f'{ultralytics_path}/nn/tasks.py')

# loss.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/utils/loss.py',
            f'{ultralytics_path}/utils/loss.py')

# loss_logger.py -- ultralytics/utils/
shutil.copy(f'{yolo_mod_path}/utils/loss_logger.py',
            f'{ultralytics_path}/utils/loss_logger.py')
# Out:
# 'D:/deep-learning/ultralytics/ultralytics/utils/loss_logger.py'

# %%
from ultralytics import YOLO
from ultralytics.utils import SETTINGS
SETTINGS['wandb'] = True
SETTINGS['tensorboard'] = True
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from ultralytics import YOLO
#       2 from ultralytics.utils import SETTINGS
#       3 SETTINGS['wandb'] = True
#       4 SETTINGS['tensorboard'] = True
#
# File D:\deep-learning\ultralytics\ultralytics\__init__.py:38, in __getattr__(name)
#      36 """Lazy-import model classes on first access."""
#      37 if name in MODELS:
# ---> 38     return getattr(importlib.import_module("ultralytics.models"), name)
#      39 raise AttributeError(f"module {__name__} has no attribute {name}")
#
# File c:\Users\s2\anaconda3\envs\deep-learning\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File D:\deep-learning\ultralytics\ultralytics\models\__init__.py:3
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
# ----> 3 from .fastsam import FastSAM
#       4 from .nas import NAS
#       5 from .rtdetr import RTDETR
#
# File D:\deep-learning\ultralytics\ultralytics\models\fastsam\__init__.py:3
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
# ----> 3 from .model import FastSAM
#       4 from .predict import FastSAMPredictor
#       5 from .val import FastSAMValidator
#
# File D:\deep-learning\ultralytics\ultralytics\models\fastsam\model.py:8
#       5 from pathlib import Path
#       6 from typing import Any
# ----> 8 from ultralytics.engine.model import Model
#      10 from .predict import FastSAMPredictor
#      11 from .val import FastSAMValidator
#
# File D:\deep-learning\ultralytics\ultralytics\engine\model.py:14
#      11 from PIL import Image
#      13 from ultralytics.cfg import TASK2DATA, get_cfg, get_save_dir
# ---> 14 from ultralytics.engine.results import Results
#      15 from ultralytics.nn.tasks import guess_model_task, load_checkpoint, yaml_model_load
#      16 from ultralytics.utils import (
#      17     ARGV,
#      18     ASSETS,
#    (...)     25     checks,
#      26 )
#
# File D:\deep-learning\ultralytics\ultralytics\engine\results.py:18
#      15 import numpy as np
#      16 import torch
# ---> 18 from ultralytics.data.augment import LetterBox
#      19 from ultralytics.utils import LOGGER, DataExportMixin, SimpleClass, ops
#      20 from ultralytics.utils.plotting import Annotator, colors, save_one_box
#
# File D:\deep-learning\ultralytics\ultralytics\data\__init__.py:3
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
# ----> 3 from .base import BaseDataset
#       4 from .build import build_dataloader, build_grounding, build_yolo_dataset, load_inference_source
#       5 from .dataset import (
#       6     ClassificationDataset,
#       7     GroundingDataset,
#    (...)     11     YOLOMultiModalDataset,
#      12 )
#
# File D:\deep-learning\ultralytics\ultralytics\data\base.py:18
#      15 import numpy as np
#      16 from torch.utils.data import Dataset
# ---> 18 from ultralytics.data.utils import FORMATS_HELP_MSG, HELP_URL, IMG_FORMATS, check_file_speeds
#      19 from ultralytics.utils import DEFAULT_CFG, LOCAL_RANK, LOGGER, NUM_THREADS, TQDM
#      20 from ultralytics.utils.patches import imread
#
# File D:\deep-learning\ultralytics\ultralytics\data\utils.py:20
#      17 import numpy as np
#      18 from PIL import Image, ImageOps
# ---> 20 from ultralytics.nn.autobackend import check_class_names
#      21 from ultralytics.utils import (
#      22     ASSETS_URL,
#      23     DATASETS_DIR,
#    (...)     33     is_dir_writeable,
#      34 )
#      35 from ultralytics.utils.checks import check_file, check_font, is_ascii
#
# File D:\deep-learning\ultralytics\ultralytics\nn\__init__.py:3
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
# ----> 3 from .tasks import (
#       4     BaseModel,
#       5     ClassificationModel,
#       6     DetectionModel,
#       7     SegmentationModel,
#       8     guess_model_scale,
#       9     guess_model_task,
#      10     load_checkpoint,
#      11     parse_model,
#      12     torch_safe_load,
#      13     yaml_model_load,
#      14 )
#      16 __all__ = (
#      17     "BaseModel",
#      18     "ClassificationModel",
#    (...)     26     "yaml_model_load",
#      27 )
#
# File D:\deep-learning\ultralytics\ultralytics\nn\tasks.py:14
#      11 import torch.nn as nn
#      13 from ultralytics.nn.autobackend import check_class_names
# ---> 14 from ultralytics.nn.modules import (
#      15     AIFI,
#      16     C1,
#      17     C2,
#      18     C2PSA,
#      19     C3,
#      20     C3TR,
#      21     ELAN1,
#      22     OBB,
#      23     OBB26,
#      24     PSA,
#      25     SPP,
#      26     SPPELAN,
#      27     SPPF,
#      28     A2C2f,
#      29     AConv,
#      30     ADown,
#      31     Bottleneck,
#      32     BottleneckCSP,
#      33     C2f,
#      34     C2f_EMA,
#      35     C2fAttn,
#      36     C2fCIB,
#      37     C2fPSA,
#      38     C3Ghost,
#      39     C3k2,
#      40     C3x,
#      41     CBFuse,
#      42     CBLinear,
#      43     Classify,
#      44     Concat,
#      45     Conv,
#      46     Conv2,
#      47     ConvTranspose,
#      48     Detect,
#      49     DWConv,
#      50     DWConvTranspose2d,
#      51     Focus,
#      52     GhostBottleneck,
#      53     GhostConv,
#      54     HGBlock,
#      55     HGStem,
#      56     ImagePoolingAttn,
#      57     Index,
#      58     LRPCHead,
#      59     Pose,
#      60     Pose26,
#      61     RepC3,
#      62     RepConv,
#      63     RepNCSPELAN4,
#      64     RepVGGDW,
#      65     ResNetLayer,
#      66     RTDETRDecoder,
#      67     SCDown,
#      68     Segment,
#      69     Segment26,
#      70     TorchVision,
#      71     WorldDetect,
#      72     YOLOEDetect,
#      73     YOLOESegment,
#      74     YOLOESegment26,
#      75     v10Detect,
#      76     AFFM,
#      77     EFE,
#      78     EdgeFEBlock,
#      79     ShapeConv,
#      80     SimAM,
#      81     CircleConv,
#      82     TriangleConv,
#      83     DySample,
#      84     CBAM,
#      85     BiFPNAdd,
#      86     WeightedConcatN,
#      87     SPConvC2f,
#      88     C2f_Unscaled
#      89 )
#      90 from ultralytics.utils import DEFAULT_CFG_DICT, LOGGER, WINDOWS, YAML, colorstr, emojis
#      91 from ultralytics.utils.checks import check_requirements, check_suffix, check_yaml
#
# ImportError: cannot import name 'C2f_Unscaled' from 'ultralytics.nn.modules' (D:\deep-learning\ultralytics\ultralytics\nn\modules\__init__.py)

# %%
configs = {
    "data": dataset_path,
    "epochs": 100,
    "imgsz": 640,
    "batch": 16,
    "amp": True,
    "device": "0",
    "optimizer": 'SGD',
    "lr0": 0.01,
    "workers": 4,
    "patience": 15,
    "val": True,
    "project": project_name
}

# %%
import os
os.environ['YOLO_IOU_LOSS']        = 'CIoU'
os.environ['YOLO_IOU_MONOTONOUS']  = 'none'
# os.environ['YOLO_IOU_INNER_RATIO'] = '0.7'

# %% [markdown]
# ## YOLO Training

# %%
# from wandb.integration.ultralytics import add_wandb_callback
from ultralytics.utils.loss_logger import log_loss_config
from ultralytics.nn.modules.spconv import SPConvFreezeCallback

# with wandb.init(project=configs["project"], name=model_name, job_type="train") as run:
model = YOLO(yolo_path, task='detect', verbose=True)
model.add_callback('on_pretrain_routine_end', log_loss_config)
SPConvFreezeCallback.attach(model)
model_results = model.train(
    data    = configs["data"],
    epochs  = configs["epochs"],
    imgsz   = configs["imgsz"],
    batch   = configs["batch"], 
    device  = configs["device"],
    amp     = configs["amp"],
    workers      = configs["workers"],
    optimizer    = configs["optimizer"],
    lr0          = configs["lr0"],
    project      = configs["project"],
    name         = f"{model_name}/train",
    exist_ok     = True,
    save_period  = 10,
    verbose      = True,
    patience     = configs["patience"],
    val          = configs["val"]
)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  3     70272  ultralytics.nn.modules.spconv.SPConvC2f      [64, 64, 3, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  6    526336  ultralytics.nn.modules.spconv.SPConvC2f      [128, 128, 6, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  6   2101248  ultralytics.nn.modules.spconv.SPConvC2f      [256, 256, 6, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2147008  ultralytics.nn.modules.head.Detect           [80, 16, None, [128, 256, 512]]
# YOLOv8s-spconv summary: 170 layers, 12,849,248 parameters, 12,084,304 gradients, 39.4 GFLOPs
#
# New https://pypi.org/project/ultralytics/8.4.56 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:/deep-learning/datasets/cctsdb2021-full, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../cfg/yolov8s-spconv.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=YOLOv8s Traffic Detection, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# TensorBoard: Start with 'tensorboard --logdir D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\train', view at http://localhost:6006/
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: zakiasmara11 (azaki-its-team) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.27.0
# Run data is saved locally in <code>D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\train\wandb\run-20260528_041000-train_20260528_041000</code>
# Syncing run <strong><a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260528_041000' target="_blank">train</a></strong> to <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection</a>
#  View run at <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260528_041000' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260528_041000</a>
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  3     70272  ultralytics.nn.modules.spconv.SPConvC2f      [64, 64, 3, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  6    526336  ultralytics.nn.modules.spconv.SPConvC2f      [128, 128, 6, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  6   2101248  ultralytics.nn.modules.spconv.SPConvC2f      [256, 256, 6, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.head.Detect           [3, 16, None, [128, 256, 512]]
# YOLOv8s-spconv summary: 170 layers, 12,819,449 parameters, 12,054,505 gradients, 39.2 GFLOPs
#
# WARNING setting 'requires_grad=True' for frozen layer 'model.2.m.0.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# WARNING setting 'requires_grad=True' for frozen layer 'model.2.m.1.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# WARNING setting 'requires_grad=True' for frozen layer 'model.2.m.2.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# WARNING setting 'requires_grad=True' for frozen layer 'model.4.m.0.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# WARNING setting 'requires_grad=True' for frozen layer 'model.4.m.1.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# WARNING setting 'requires_grad=True' for frozen layer 'model.4.m.2.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# WARNING setting 'requires_grad=True' for frozen layer 'model.4.m.3.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# WARNING setting 'requires_grad=True' for frozen layer 'model.6.m.0.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# WARNING setting 'requires_grad=True' for frozen layer 'model.6.m.1.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# WARNING setting 'requires_grad=True' for frozen layer 'model.6.m.2.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# WARNING setting 'requires_grad=True' for frozen layer 'model.6.m.3.cv1.conv.weight'. See ultralytics.engine.trainer for customization of frozen layers.
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 815.9392.1 MB/s, size: 58.6 KB)
# train: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\train.cache... 16356 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 16356/16356 3.6Git/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1963.1829.1 MB/s, size: 210.3 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 349.5Mit/s 0.0s
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Plotting labels to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\train\labels.jpg...
#
# Loss config
#   type        : CIoU
#   monotonous  : None  (v1  no focusing)
#   inner_ratio : 0.7
#
#
# [SP-C2f] Re-applied cv1 freeze to 11 ShapePriorBottleneck layers
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# c:\Users\s2\anaconda3\envs\deep-learning\Lib\site-packages\torch\jit\_trace.py:1022: UserWarning: The input to trace is already a ScriptModule, tracing it is a no-op. Returning the object as is.
#   traced_func = _trace_impl(
#       1/100       4.6G      3.986      5.718      2.192          5        640: 100% ━━━━━━━━━━━━ 1023/1023 3.7it/s 4:37<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.239      0.128     0.0688     0.0263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.83G      2.074      1.763      1.141         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:32<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.526      0.328      0.319      0.147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.83G      1.703      1.286      1.022          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.8it/s 4:28<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.6it/s 7.1s0.1s
#                    all       1500       3228      0.489      0.347      0.344      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.83G      1.542      1.055     0.9682          8        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:21<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.1it/s 7.7s0.2s
#                    all       1500       3228      0.662      0.433       0.49      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.83G      1.395     0.9079     0.9409          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.7it/s 4:35<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.714      0.509       0.55      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.83G      1.312     0.8225     0.9199          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.7it/s 4:36<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.729      0.518      0.581      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.83G      1.268     0.7768     0.9032          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:22<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228       0.78      0.559      0.633      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.83G      1.217     0.7333     0.8933         13        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.795      0.591      0.663      0.389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.83G       1.18     0.6962     0.8847         11        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.766      0.586      0.651      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.83G      1.159     0.6708     0.8826         14        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.5s0.2s
#                    all       1500       3228      0.766      0.625      0.654      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.83G       1.13     0.6499     0.8775         13        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.809      0.651      0.707      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.83G      1.109     0.6285     0.8736         13        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.795      0.695      0.743      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.83G      1.093     0.6153     0.8685         27        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.803      0.671      0.724      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.83G      1.077     0.6002     0.8668         18        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.859      0.667      0.732      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.83G      1.049     0.5812     0.8627          9        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.839      0.678      0.737      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.83G      1.049     0.5782     0.8603          9        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.856      0.679      0.751       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.83G      1.037     0.5664     0.8585         11        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.863      0.684      0.753      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.83G      1.021     0.5547      0.855         22        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.871       0.69      0.761      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.83G      1.009     0.5479     0.8522         20        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.1s
#                    all       1500       3228      0.867      0.688      0.762      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.83G      1.004     0.5384     0.8501         22        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.862      0.693      0.758      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.83G     0.9979     0.5346     0.8486         10        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:18<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.6it/s 7.1s0.2s
#                    all       1500       3228      0.868      0.693      0.756      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      4.83G     0.9807     0.5221     0.8485          8        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:17<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.6it/s 7.1s0.1s
#                    all       1500       3228      0.869        0.7      0.757      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      4.83G     0.9742     0.5208     0.8497          9        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:17<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.7it/s 7.0s0.1s
#                    all       1500       3228      0.882       0.71       0.78      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      4.83G      0.968     0.5123     0.8454         11        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:17<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.6it/s 7.1s0.1s
#                    all       1500       3228      0.867      0.699      0.766      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      4.83G     0.9622     0.5057     0.8439         15        640: 100% ━━━━━━━━━━━━ 1023/1023 4.0it/s 4:17<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.6it/s 7.1s0.1s
#                    all       1500       3228      0.887      0.713      0.782      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      4.83G     0.9541     0.5003     0.8445          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:19<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.887      0.715      0.781      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      4.83G     0.9507     0.4969      0.842         19        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228       0.87      0.729      0.791      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      4.83G     0.9442     0.4935     0.8414         15        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.877      0.721      0.789      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      4.83G     0.9401     0.4887     0.8399         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.886      0.717       0.79      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      4.83G     0.9283     0.4818     0.8396         19        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.5s0.2s
#                    all       1500       3228      0.902      0.712      0.794      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      4.83G     0.9257     0.4766     0.8414         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.877      0.729      0.793      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      4.83G     0.9192     0.4726      0.839         18        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.882      0.731      0.794      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      4.83G     0.9106     0.4668     0.8382         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228       0.88      0.745       0.81      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      4.83G     0.9115     0.4648     0.8354          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.6s0.2s
#                    all       1500       3228      0.886      0.736      0.808       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      4.83G     0.8982     0.4604     0.8362         18        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:21<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.882      0.759      0.806      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      4.83G      0.898     0.4599     0.8344         14        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.887      0.746      0.803      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      4.83G     0.8922     0.4525     0.8324         20        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.901       0.75      0.808      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      4.83G     0.8895     0.4495     0.8315         18        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.896      0.751      0.808      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      4.83G      0.885     0.4493     0.8315          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.895      0.753      0.804      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      4.83G     0.8835     0.4456     0.8279         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:21<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.914      0.738      0.807      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      4.83G     0.8801      0.443     0.8275          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228        0.9      0.755      0.812      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      4.83G     0.8696     0.4379     0.8314         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.904      0.756      0.811       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      4.83G     0.8673     0.4346     0.8272         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.5s0.2s
#                    all       1500       3228      0.899      0.756      0.813      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      4.83G     0.8638     0.4302     0.8266         14        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.5s0.2s
#                    all       1500       3228      0.898      0.757      0.815       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      4.83G     0.8577     0.4274     0.8265         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.894      0.761      0.814      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      4.83G     0.8538     0.4264      0.826          4        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.901      0.754      0.814       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      4.83G     0.8532      0.425     0.8276         19        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.901       0.76      0.814      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      4.83G     0.8453     0.4175     0.8262          4        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.903       0.76      0.815      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      4.83G      0.841     0.4163     0.8235         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.905      0.755      0.814      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      4.83G     0.8406     0.4164      0.824         14        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.903      0.754      0.814      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      4.83G     0.8387     0.4112      0.824          8        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:21<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.904      0.755      0.814      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      4.83G     0.8324     0.4104     0.8229         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:21<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.906      0.757      0.814      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      4.83G      0.832     0.4103       0.82         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:21<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.1s
#                    all       1500       3228      0.908      0.757      0.816      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      4.83G     0.8233     0.4039     0.8209         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.909      0.755      0.817      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      4.83G     0.8246      0.404     0.8249          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.906      0.758      0.816      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      4.83G     0.8233     0.4023       0.82          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:21<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.911      0.756      0.818      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      4.83G     0.8169     0.3965     0.8206         14        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:21<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.887      0.769      0.818      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      4.83G     0.8135     0.3946     0.8168         16        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.912      0.753      0.818      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      4.83G     0.8067     0.3925     0.8196          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.912      0.756       0.82      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      4.83G     0.8039       0.39     0.8183          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.913      0.758      0.819      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      4.83G     0.8003     0.3879     0.8163         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:21<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.914      0.756       0.82      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      4.83G     0.7978     0.3842     0.8168         21        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.916      0.755      0.821      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      4.83G     0.7989      0.385     0.8159          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.916      0.754      0.821       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      4.83G     0.7977     0.3837     0.8159         24        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:21<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.917      0.754      0.821       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      4.83G     0.7903     0.3811     0.8161         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.5s0.2s
#                    all       1500       3228       0.92      0.756      0.821      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      4.83G      0.784     0.3753     0.8157         15        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.916      0.758      0.822      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      4.83G     0.7871     0.3784     0.8142         24        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.913      0.759      0.822      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      4.83G     0.7863     0.3761     0.8159         12        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.915      0.758      0.822      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      4.83G     0.7737     0.3701     0.8128         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.919      0.756      0.822      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      4.83G     0.7768      0.372     0.8119          8        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.919      0.756      0.822      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      4.83G     0.7715     0.3662     0.8131          5        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228       0.92      0.758      0.822      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      4.83G     0.7674     0.3657     0.8108         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.921      0.756      0.822      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      4.83G     0.7632     0.3629     0.8088         13        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.5s0.2s
#                    all       1500       3228      0.921      0.756      0.822      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      4.83G     0.7573     0.3592       0.81         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.921      0.757      0.822      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      4.83G     0.7548     0.3551     0.8106         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.921      0.757      0.822      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      4.83G     0.7558     0.3559     0.8107         17        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.921      0.757      0.821      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      4.83G     0.7496     0.3533     0.8076         16        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.2it/s 7.5s0.2s
#                    all       1500       3228      0.923      0.757      0.822      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      4.83G     0.7522     0.3527      0.807          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.922      0.757      0.821      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      4.83G      0.741     0.3487     0.8103          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.922      0.758      0.821      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      4.83G     0.7432      0.347     0.8081          9        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.922      0.757      0.821      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      4.83G      0.739     0.3462     0.8078          3        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.922      0.757      0.821      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      4.83G     0.7351      0.342     0.8063          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.3s0.2s
#                    all       1500       3228      0.922      0.757      0.821      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      4.83G     0.7274     0.3391     0.8047         16        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.922      0.758      0.822      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      4.83G     0.7276     0.3381     0.8054         14        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.921      0.757      0.821      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      4.83G     0.7223     0.3346     0.8042         11        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.919      0.759      0.821      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      4.83G     0.7189     0.3342     0.8053         15        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.5s0.2s
#                    all       1500       3228      0.919      0.759      0.821      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      4.83G     0.7117     0.3314     0.8034         10        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.918       0.76      0.821      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      4.83G     0.7142     0.3311     0.8031         15        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228       0.92      0.761      0.822      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      4.83G     0.7147     0.3295     0.8024         13        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.919      0.761      0.822      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.83G     0.7057     0.3265     0.8014          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.4s0.2s
#                    all       1500       3228      0.917      0.762      0.822      0.534
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.83G     0.6773     0.3099     0.8027          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.916      0.763      0.822      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      4.83G     0.6664     0.3042      0.801          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.919       0.76      0.822      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.83G     0.6648      0.303     0.7987          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.5it/s 7.2s0.2s
#                    all       1500       3228      0.916      0.761      0.822      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.83G     0.6549     0.2975     0.7991          5        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.918      0.761      0.821      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.83G     0.6531     0.2964     0.7994          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.919       0.76      0.821      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.83G     0.6497     0.2954     0.7984          7        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.913      0.762      0.821      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.83G     0.6419     0.2903     0.7985          4        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.4s0.2s
#                    all       1500       3228      0.914      0.762       0.82      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.83G     0.6423     0.2902     0.7979          4        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.3it/s 7.5s0.2s
#                    all       1500       3228      0.917      0.759       0.82      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.83G     0.6355     0.2859     0.7969          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.918       0.76       0.82      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.83G     0.6293     0.2827     0.7949          6        640: 100% ━━━━━━━━━━━━ 1023/1023 3.9it/s 4:20<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 6.4it/s 7.3s0.2s
#                    all       1500       3228      0.914      0.762       0.82      0.533
#
# 100 epochs completed in 7.454 hours.
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\train\weights\last.pt, 27.5MB
# Optimizer stripped from D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\train\weights\best.pt, 27.5MB
#
# Validating D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\train\weights\best.pt...
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8s-spconv summary (fused): 93 layers, 12,807,769 parameters, 0 gradients, 38.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 47/47 5.7it/s 8.3s0.2s
#                    all       1500       3228      0.918       0.76      0.822      0.535
#              mandatory        525        718      0.883      0.685      0.743      0.489
#            prohibitory       1043       2177      0.949      0.739      0.824      0.551
#                warning        288        333      0.923      0.856      0.897      0.564
# Speed: 0.1ms preprocess, 2.5ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\train
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# wandb: WARNING Tried to log to step 100 that is less than the current step 101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>▃█████▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>lr/pg1</td><td>▃████▇▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▃▃▃▃▃▂▁▁▁▁</td></tr><tr><td>lr/pg2</td><td>█▅▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>metrics/mAP50(B)</td><td>▁▄▅▆▆▇▇▇▇▇██████████████████████████████</td></tr><tr><td>metrics/mAP50-95(B)</td><td>▁▃▄▆▆▇▇▇▇▇▇▇▇███████████████████████████</td></tr><tr><td>metrics/precision(B)</td><td>▁▄▆▆▇▇▇█▇███████████████████████████████</td></tr><tr><td>metrics/recall(B)</td><td>▁▃▅▆▆▇▇▇▇▇▇█████████████████████████████</td></tr><tr><td>model/GFLOPs</td><td>▁</td></tr><tr><td>model/parameters</td><td>▁</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>▁</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>0.0002</td></tr><tr><td>lr/pg1</td><td>0.0002</td></tr><tr><td>lr/pg2</td><td>0.0002</td></tr><tr><td>metrics/mAP50(B)</td><td>0.81971</td></tr><tr><td>metrics/mAP50-95(B)</td><td>0.53298</td></tr><tr><td>metrics/precision(B)</td><td>0.9138</td></tr><tr><td>metrics/recall(B)</td><td>0.76235</td></tr><tr><td>model/GFLOPs</td><td>39.203</td></tr><tr><td>model/parameters</td><td>12819449</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>2.79</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">train</strong> at: <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260528_041000' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection/runs/train_20260528_041000</a><br> View project at: <a href='https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection' target="_blank">https://wandb.ai/azaki-its-team/YOLOv8s%20Traffic%20Detection</a><br>Synced 5 W&B file(s), 23 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\train\wandb\run-20260528_041000-train_20260528_041000\logs</code>

# %% [markdown]
# ## Test Set Validation

# %%
import os

# Resolve best-weight paths
weights = f"{output_path}/{model_name}/train/weights/best.pt"

# Load best checkpoints
best_weights = YOLO(weights)

# Run validation on the test split
val_model = best_weights.val(
    data   = f"{configs["data"]}/dataset.yaml",
    split  = "test",
    imgsz  = configs["imgsz"],
    batch  = configs["batch"],
    device = configs["device"],
    plots  = True,
    project = configs["project"],
    name    = f"{model_name}/test",
    exist_ok = True,
    verbose  = True,
)

print(f"\n=== {model_name} — Test Set Results ===")
print(f"  mAP50   : {val_model.box.map50:.4f}")
print(f"  mAP50-95: {val_model.box.map:.4f}")
print(f"  Precision: {val_model.box.mp:.4f}")
print(f"  Recall   : {val_model.box.mr:.4f}")
# Out:
# Ultralytics 8.4.51  Python-3.14.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8s-spconv summary (fused): 93 layers, 12,807,769 parameters, 0 gradients, 38.9 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 2381.1786.3 MB/s, size: 212.0 KB)
# val: Scanning D:\deep-learning\datasets\cctsdb2021-full\labels\test.cache... 1500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1500/1500 629.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 94/94 7.9it/s 11.9s0.1s
#                    all       1500       3228      0.919       0.76      0.822      0.537
#              mandatory        525        718      0.883      0.685      0.744      0.493
#            prohibitory       1043       2177      0.949      0.738      0.824      0.553
#                warning        288        333      0.924      0.856      0.897      0.565
# Speed: 0.8ms preprocess, 4.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to D:\deep-learning\yolo-test\notebooks\runs\detect\YOLOv8s Traffic Detection\YOLOv8s + SPConv\test
#
# === YOLOv8s + SPConv — Test Set Results ===
#   mAP50   : 0.8217
#   mAP50-95: 0.5370
#   Precision: 0.9188
#   Recall   : 0.7596

# %% [markdown]
# ## Metrics Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# Helper to load results.csv produced by Ultralytics during training
def load_results(run_dir, run_name):
    csv_path = os.path.join(run_dir, run_name, "results.csv")
    df = pd.read_csv(csv_path)
    df.columns = df.columns.str.strip()  # strip whitespace from column names
    return df

df_result = load_results(output_path, f"{model_name}/train")

def plot_training_curves(df, model_name):
    metrics = [
        ("train/box_loss",  "Train Box Loss"),
        ("train/cls_loss",  "Train Cls Loss"),
        ("train/dfl_loss",  "Train DFL Loss"),
        ("metrics/mAP50(B)",    "mAP@50"),
        ("metrics/mAP50-95(B)", "mAP@50-95"),
        ("metrics/precision(B)", "Precision"),
        ("metrics/recall(B)",    "Recall"),
        ("val/box_loss",   "Val Box Loss"),
    ]

    ncols = 4
    nrows = 2
    fig, axes = plt.subplots(nrows, ncols, figsize=(20, 10))
    fig.suptitle(f"Training Curves -- {model_name}", fontsize=16, fontweight='bold')

    for ax, (col, title) in zip(axes.flat, metrics):
        epochs = df["epoch"] if "epoch" in df.columns else range(len(df))
        if col in df.columns:
            ax.plot(epochs, df[col], label=model_name, color="#1f77b4", linewidth=2)
        ax.set_title(title, fontsize=12)
        ax.set_xlabel("Epoch")
        ax.legend(fontsize=9)
        ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{output_path}/{model_name}/training_curves.png", dpi=150, bbox_inches='tight')
    plt.show()
    print("Saved → training_curves.png")

plot_training_curves(df_result, model_name)
# Out:
# Saved → training_curves.png

# %%
# ── Bar chart: Final metric comparison ──────────────────────────────────────

def get_final_metrics(val_result):
    return {
        "Precision":  val_result.box.mp,
        "Recall":     val_result.box.mr,
        "mAP@50":     val_result.box.map50,
        "mAP@50-95":  val_result.box.map,
    }

metrics_result = get_final_metrics(val_model)

labels  = list(metrics_result.keys())
vals_res = list(metrics_result.values())

x   = range(len(labels))
w   = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
bars1 = ax.bar([i - w/2 for i in x], vals_res, w, label=model_name, color='#1f77b4', alpha=0.85)

ax.set_xticks(list(x))
ax.set_xticklabels(labels, fontsize=13)
ax.set_ylabel("Score", fontsize=13)
ax.set_title(f"Test Set Metric {model_name}", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f"{bar.get_height():.3f}", ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/metric_bar.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → metric_bar.png")
# Out:
# Saved → metric_bar.png

# %%
# ── Per-class mAP comparison ─────────────────────────────────────────────────
import numpy as np

def get_per_class_ap(val_result):
    """Extract per-class AP50 from validation result."""
    maps  = val_result.box.maps      # per-class mAP50-95
    ap50s = val_result.box.ap50      # per-class mAP50, if available
    names = val_result.names         # {idx: class_name}
    class_names = [names[i] for i in sorted(names.keys())]
    return class_names, ap50s if ap50s is not None else maps

cls_names, ap50_model = get_per_class_ap(val_model)

x = np.arange(len(cls_names))
w = 0.35

fig, ax = plt.subplots(figsize=(max(14, len(cls_names) * 0.9), 6))
ax.bar(x - w/2, ap50_model, w, label=model_name, color='#1f77b4', alpha=0.85)
ax.set_xticks(x)
ax.set_xticklabels(cls_names, rotation=45, ha='right', fontsize=10)
ax.set_ylabel("AP@50")
ax.set_title("Per-class AP@50 — Test Set", fontsize=14, fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim(0, 1.05)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/per_class_ap50.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → per_class_ap50.png")
# Out:
# Saved → per_class_ap50.png

# %%
# ── Confusion matrices (saved by Ultralytics during val with plots=True) ─────
from IPython.display import Image, display

def show_image(path, title=""):
    if os.path.exists(path):
        print(f"\n{title}")
        display(Image(filename=path, width=700))
    else:
        print(f"[WARNING] Not found: {path}")

show_image(f"{output_path}/{model_name}/train/confusion_matrix_normalized.png",
           f"Confusion Matrix — {model_name} (Test Set)")
# Out:
# Confusion Matrix — YOLOv8s + SPConv (Test Set)

# %% [markdown]
# ## Visual Inspection on Test Images

# %%
import glob
import random
from PIL import Image as PILImage
import numpy as np

# ── Gather test images ───────────────────────────────────────────────────────
test_img_dir = os.path.join(dataset_path, "images", "test")
all_test_imgs = glob.glob(os.path.join(test_img_dir, "*.jpg")) + \
                glob.glob(os.path.join(test_img_dir, "*.png"))

random.seed(42)
sample_imgs = random.sample(all_test_imgs, min(8, len(all_test_imgs)))
print(f"Selected {len(sample_imgs)} test images for visual inspection.")
# Out:
# Selected 8 test images for visual inspection.

# %%
# ── Side-by-side predictions: Baseline | ES-YOLO ────────────────────────────

def predict_and_plot(imgs, model, model_name, n_cols=2, conf=0.25, save_path=None):
    n_imgs = len(imgs)
    n_rows = n_imgs

    fig, axes = plt.subplots(n_rows, n_cols * 2 + 1, figsize=(26, n_rows * 4))
    fig.suptitle(f"Visual Inspection — {model_name}", fontsize=15, fontweight='bold')

    # Column headers
    col_titles = ["Image", model_name, "Prediction"]

    for row_idx, img_path in enumerate(imgs):
        # Run predictions
        res = model.predict(img_path, conf=conf, imgsz=640, verbose=False)[0]

        orig_img   = PILImage.open(img_path).convert("RGB")
        plotted = PILImage.fromarray(res.plot()[:, :, ::-1])

        col_data = [orig_img, plotted]
        titles   = ["Original", model_name]

        for col_idx, (img_data, title) in enumerate(zip(col_data, titles)):
            ax = axes[row_idx, col_idx] if n_rows > 1 else axes[col_idx]
            ax.imshow(img_data)
            ax.axis('off')
            if row_idx == 0:
                ax.set_title(title, fontsize=12, fontweight='bold', pad=6)

        # Hide unused subplots if any
        for c in range(len(col_data), axes.shape[1] if n_rows > 1 else len(axes)):
            extra = axes[row_idx, c] if n_rows > 1 else axes[c]
            extra.axis('off')

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=120, bbox_inches='tight')
        print(f"Saved → {save_path}")
    plt.show()

predict_and_plot(
    sample_imgs, best_weights, model_name,
    conf=0.25,
    save_path=f"{output_path}/{model_name}/visual_inspection_comparison.png"
)
# Out:
# Saved → ./runs/detect/YOLOv8s Traffic Detection/YOLOv8s + SPConv/visual_inspection_comparison.png

# %%
# ── Confidence score distribution on test set ───────────────────────────────

def collect_confidences(model, img_list, conf_thresh=0.01):
    confs = []
    for p in img_list:
        res = model.predict(p, conf=conf_thresh, imgsz=640, verbose=False)[0]
        if res.boxes is not None and len(res.boxes):
            confs.extend(res.boxes.conf.cpu().numpy().tolist())
    return confs

confs_model = collect_confidences(best_weights, all_test_imgs)

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 5), sharey=False)
fig.suptitle("Detection Confidence Distribution — Test Set", fontsize=14, fontweight='bold')

axes.hist(confs_model, bins=40, color="#1f77b4", alpha=0.8, edgecolor='white')
axes.set_title(f"{model_name}  (n={len(confs_model)} detections)", fontsize=12)
axes.set_xlabel("Confidence Score")
axes.set_ylabel("Count")
axes.axvline(0.25, color='red', linestyle='--', linewidth=1.5, label='thresh=0.25')
axes.legend()
axes.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f"{output_path}/{model_name}/confidence_distribution.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved → confidence_distribution.png")
# Out:
# Saved → confidence_distribution.png

# %%
# ── Precision-Recall Curves (saved by Ultralytics) ──────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxPR_curve.png",
           f"PR Curve — {model_name} (Test Set)")
# Out:
# PR Curve — YOLOv8s + SPConv (Test Set)

# %%
# ── F1 Curves (saved by Ultralytics) ─────────────────────────────────────────

show_image(f"{output_path}/{model_name}/train/BoxF1_curve.png",
           f"F1-Confidence Curve — {model_name} (Test Set)")
# Out:
# F1-Confidence Curve — YOLOv8s + SPConv (Test Set)

# %% [markdown]
# ## Final Summary

# %%
# ── Summary comparison table ─────────────────────────────────────────────────
import pandas as pd
from IPython.display import display

summary = pd.DataFrame({
    "Model":      [model_name],
    "Precision":  [val_model.box.mp],
    "Recall":     [val_model.box.mr],
    "mAP@50":     [val_model.box.map50],
    "mAP@50-95":  [val_model.box.map],
}).set_index("Model").round(4)

# Highlight best value per column
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: #d4edda; font-weight: bold; color:#000000' if v else '' for v in is_max]

print("\n===== Test Set Performance Summary =====")
display(summary.style.apply(highlight_max, axis=0))
# Out:
# ===== Test Set Performance Summary =====
# <style type="text/css">
# #T_44b50_row0_col0, #T_44b50_row0_col1, #T_44b50_row0_col2, #T_44b50_row0_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
#   color: #000000;
# }
# </style>
# <table id="T_44b50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44b50_level0_col0" class="col_heading level0 col0" >Precision</th>
#       <th id="T_44b50_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_44b50_level0_col2" class="col_heading level0 col2" >mAP@50</th>
#       <th id="T_44b50_level0_col3" class="col_heading level0 col3" >mAP@50-95</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44b50_level0_row0" class="row_heading level0 row0" >YOLOv8s + SPConv</th>
#       <td id="T_44b50_row0_col0" class="data row0 col0" >0.918800</td>
#       <td id="T_44b50_row0_col1" class="data row0 col1" >0.759600</td>
#       <td id="T_44b50_row0_col2" class="data row0 col2" >0.821700</td>
#       <td id="T_44b50_row0_col3" class="data row0 col3" >0.537000</td>
#     </tr>
#   </tbody>
# </table>
