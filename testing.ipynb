# %%
x = 1

# %%
import sys
# Add the ultralytics repository to the path
sys.path.insert(0, r"d:\Zaki\Computer Science\CV\FP\ultralytics")

# %%
from ultralytics import YOLO
print("YOLO imported successfully!")
# Out:
# YOLO imported successfully!

# %%
impo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import ultralytics.ultralytics
#
# ModuleNotFoundError: No module named 'ultralytics.ultralytics'
